# %% [markdown]
# ##### <p style="text-align: center;"> ![alt text](./utilities/cilss.png)</p>
# # <p style="text-align: center;">AGHRYMET RCC-WAS</p>
# #### &copy; Mandela HOUNGNIBO 2024 (Find more [here](https://github.com/hmandela/WASS2S))

# %% [markdown]
# ## Library

# %%
from wass2s import *
import datetime
import importlib
from pathlib import Path
import warnings
import gc
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Set forecast working directory

# %%
# Set forecast working directory
dir_s2s = "./Agro_PRESAGG_2026_ic_1"
logopath = './utilities/cilss.png'#'./utilities/agrhymet_logo_combined_reversed.png'
fcst_labels = ["Early", "Near-Normal", "Late"]
dist_method="bestfit" # nonparam or bestfit

# %%
dir_s2s = Path(dir_s2s)
os.makedirs(dir_s2s, exist_ok=True)
### Save consolidated results
hdcst_consolidated = {}
fcst_consolidated = {}
scores_consolidated = {}
### Save score
dir_save_score = f"{dir_s2s}/scores"
os.makedirs(dir_save_score, exist_ok=True)
### Save forecasts
dir_to_forecast = f"{dir_s2s}/forecasts"
os.makedirs(dir_to_forecast, exist_ok=True)

# %% [markdown]
# #### Set Climatological Years

# %%
# Set Climatological Years
clim_year_start = 1994 #1991
clim_year_end = 2016 #2020

# %% [markdown]
# ## Download Observation and Process

# %% [markdown]
# #### Load Downloader

# %%
# Load WAS_S2S downloader class
downloader = WAS_Download()

# %%
# Filter observation names to identify precipitation-related models
variables_obs = [key for key in downloader.AgroObsName().keys() if "PRCP" in key]

# Specify the directory to save downloaded model data
dir_to_save_Obs = f"{dir_s2s}/Observation"

# Define the observation period (years 1993 to 2016)
year_start = 1991
year_end = 2025

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent_obs = [12, -3.5, 4, 1.5]   # [Northern, Western, Southern and Eastern] 

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
plot_map([extent_obs[1],extent_obs[3],extent_obs[2],extent_obs[0]], title="Data Download Area", fig_size=(4,3))

# %%
downloader.WAS_Download_AgroIndicators_daily(dir_to_save_Obs, variables_obs, year_start, year_end, extent_obs, force_download=force_download)
downloader.WAS_Download_AgroIndicators_daily(dir_to_save_Obs, variables_obs, datetime.datetime.now().year, datetime.datetime.now().year, extent_obs, force_download=force_download)
# Out:
# Agro_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1991_2025.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2026_2026.nc already exists. Skipping download.

# %%
#### Process predictant
rainfall = prepare_predictand(dir_to_save_Obs, variables_obs, year_start, year_end, daily=True, ds=False)
rainfall_for_forecast_year = prepare_predictand(dir_to_save_Obs, variables_obs, datetime.datetime.now().year, datetime.datetime.now().year, daily=True, ds=False)
season_str = agrometparam = "Onset"
season_obs = [datetime.datetime.now().month+1]

# %% [markdown]
# ## Compute Onset

# %%
### Choose number of cores according your computer
nb_cores = 4

# %%
## Onset criteria
user_criteria = onset_criteria
user_criteria
# Out:
# {0: {'zone_name': 'Sahel100_0mm',
#   'start_search': '06-01',
#   'cumulative': 15,
#   'number_dry_days': 25,
#   'thrd_rain_day': 0.85,
#   'end_search': '09-01'},
#  1: {'zone_name': 'Sahel200_100mm',
#   'start_search': '05-15',
#   'cumulative': 15,
#   'number_dry_days': 25,
#   'thrd_rain_day': 0.85,
#   'end_search': '08-15'},
#  2: {'zone_name': 'Sahel400_200mm',
#   'start_search': '05-01',
#   'cumulative': 15,
#   'number_dry_days': 20,
#   'thrd_rain_day': 0.85,
#   'end_search': '07-31'},
#  3: {'zone_name': 'Sahel600_400mm',
#   'start_search': '03-15',
#   'cumulative': 20,
#   'number_dry_days': 20,
#   'thrd_rain_day': 0.85,
#   'end_search': '07-31'},
#  4: {'zone_name': 'Soudan',
#   'start_search': '03-15',
#   'cumulative': 20,
#   'number_dry_days': 10,
#   'thrd_rain_day': 0.85,
#   'end_search': '07-31'},
#  5: {'zone_name': 'Golfe_Of_Guinea',
#   'start_search': '02-01',
#   'cumulative': 20,
#   'number_dry_days': 10,
#   'thrd_rain_day': 0.85,
#   'end_search': '06-15'}}

# %%
user_criteria[0]["end_search"] = '05-15'
user_criteria[0]["start_search"] = '02-01'

# %% [markdown]
# ##### Compute onset for gridded products

# %%
# load onset class
was_onset = WAS_compute_onset(user_criteria)
onset = was_onset.compute(daily_data=rainfall, nb_cores=nb_cores)

# %%
plot_date(onset.mean(dim='T'))

# %% [markdown]
# #### Process Onset in combining with Ground-Observation

# %%
# ## Path to the CPT file
cpt_input_file_path = "./Onset_2025.csv"

# %%
# Read CSV
df = pd.read_csv(cpt_input_file_path, na_values=-999.0, encoding="latin1")
onset_df = df[(df['STATION'] == 'LAT') | (df['STATION'] == 'LON') | 
                 (pd.to_numeric(df['STATION'], errors='coerce').between(year_start, year_end))]
verify_station_network(onset_df, extent_obs)

# %%
### ## Instantiate WAS_Merging class
path_ = Path(dir_s2s / "onset_predictand.nc")
data_merger = WAS_Merging(onset_df, onset, date_month_day= '02-01')
if path_.is_file():
    onset__ = xr.load_dataarray(path_)
else:
    onset__, _ = data_merger.simple_bias_adjustment(do_cross_validation=False)
    onset__.to_netcdf(path_)

# %%
data_merger.plot_merging_comparaison(onset_df, onset , onset__)

# %%
#### Verify last year in cpt file matches year_start before uncomment this line below
onset = onset__
onset.name = "Onset"
plot_date(onset.mean(dim='T'))

# %% [markdown]
# #### Identify the parametric distribution that best fits the observations

# %%
if dist_method=="nonparam":
    pass
else:
    transf = WAS_TransformData(rainfall.sel(T=slice(str(clim_year_start),str(clim_year_end))), 
                      distribution_map={'norm': 1, 'lognorm': 2, 'gamma': 4,}, #'norm': 1, 'lognorm': 2, 'expon': 3, 'gamma': 4, 'weibull_min': 5, 't_dist': 6, "poisson":7, "nbinom":8 
                                n_clusters=1000)
    best_code_da, best_shape_da, best_loc_da, best_scale_da, _ = transf.fit_best_distribution(mode="grid")

# %%
if dist_method=="bestfit":
    transf.plot_best_fit_map(best_code_da,
                             {'norm': 1, 'lognorm': 2, 'expon': 3, 'gamma': 4,
                              'weibull_min': 5, 't_dist': 6, "poisson":7, "nbinom":8},
                             show_plot=True)

# %% [markdown]
# # 1st - Approach: Choice of Best Dynamical models and weighted Average

# %%
# Filter model names to identify precipitation-related models
center_variable = ['BOM_2.PRCP',
 'ECMWF_51.PRCP',
 'UKMO_604.PRCP',
 # 'UKMO_603.PRCP',
 # 'METEOFRANCE_8.PRCP',
 'METEOFRANCE_9.PRCP',
 # 'DWD_21.PRCP',
 'DWD_22.PRCP',
 # 'CMCC_35.PRCP',
 'NCEP_2.PRCP',
 # 'JMA_3.PRCP',
 # 'ECCC_4.PRCP',
 # 'ECCC_5.PRCP'
                  ]
# center_variable = [key for key in downloader.ModelsName().keys() if "PRCP" in key]

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/daily_model_data"

# Define the month for model initialization (June)
month_of_initialization = "01"
day_of_initialization ="01"

# Define lead times corresponding to seasonal forecast targets
leadtime_hour = [str(i) for i in range(24, 5161, 24)] 

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent_obs = [12, -3.5, 4, 1.5]  # [Northern, Western, Southern and Eastern] 

# Define if you want to download forecast or hindcast
forecast = None
ensemble_mean = 'mean',
# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
file_path_hdcst = downloader.WAS_Download_Models_Daily(dir_to_save_model,center_variable,month_of_initialization, day_of_initialization, leadtime_hour, year_start_model, year_end_model, extent_obs, forecast, ensemble_mean, force_download,)
# Out:
# Agro_PRESAGG_2026_ic_1/daily_model_data/hindcast_bom2_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/hindcast_ecmwf51_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/hindcast_ukmo604_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/hindcast_meteo_france9_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/hindcast_dwd22_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/hindcast_ncep2_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.

# %%
forecast = 2026

# %%
file_path_fcst = downloader.WAS_Download_Models_Daily(dir_to_save_model,center_variable,month_of_initialization, day_of_initialization, leadtime_hour, year_start_model, year_end_model, extent_obs, forecast, ensemble_mean, force_download,)
# Out:
# Agro_PRESAGG_2026_ic_1/daily_model_data/forecast_bom2_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/forecast_ecmwf51_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/forecast_ukmo604_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/forecast_meteo_france9_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/forecast_dwd22_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1/daily_model_data/forecast_ncep2_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.

# %% [markdown]
# #### Models bias correction

# %%
hindcast_files, forecast_files = pre_process_biophysical_model(dir_s2s, file_path_hdcst, 
file_path_fcst, rainfall, rainfall_for_forecast_year, month_of_initialization,
 year_start_model, year_end_model, forecast, param="PRCP")
# Out:
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteo_france9_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/forecast_meteo_france9_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_PRCP_JanIc.nc already exists.

# %%
hindcast_files
# Out:
# {'bom2': 'Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_PRCP_JanIc.nc',
#  'ecmwf51': 'Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_PRCP_JanIc.nc',
#  'ukmo604': 'Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_PRCP_JanIc.nc',
#  'meteo_france9': 'Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteo_france9_PRCP_JanIc.nc',
#  'dwd22': 'Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_PRCP_JanIc.nc',
#  'ncep2': 'Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_PRCP_JanIc.nc'}

# %%
forecast_files
# Out:
# {'bom2': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_PRCP_JanIc.nc',
#  'ecmwf51': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_PRCP_JanIc.nc',
#  'ukmo604': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_PRCP_JanIc.nc',
#  'meteo_france9': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_meteo_france9_PRCP_JanIc.nc',
#  'dwd22': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_PRCP_JanIc.nc',
#  'ncep2': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_PRCP_JanIc.nc'}

# %%
hindcast_files_cor, forecast_files_cor = proceed_seasonal_daily_bias_correction(dir_to_save_model, 
                                                                                rainfall.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                hindcast_files, 
                                                                                forecast_files, 
                                                                                varname="PRCP", wet_day=0.1)
# Out:
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_bom2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_bom2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_ecmwf51_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_ecmwf51_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_ukmo604_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_ukmo604_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_meteo_france9_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_meteo_france9_PRCP_JanIc.nc already exists.

# %% [markdown]
# ## Verify Bias Correction

# %%
import xskillscore as xs
for i in hindcast_files_cor.keys():
    hcst_cor = xr.open_dataset(hindcast_files_cor[i])["corrected"]
    hcst = xr.open_dataset(hindcast_files[i])["PRCP"]
    observation = rainfall.interp(Y=hcst.Y, X=hcst.X, method="linear", kwargs={"fill_value": "extrapolate"})
    dry_wet, extrem = qmap.evaluate_bias_correction(observation,
                                              hcst,
                                              hcst_cor,
                                              wet_threshold=0.1,
                                              extreme_quantiles=[0.95, 0.99])
    print(i)
    mae = xr.concat([xs.mae(observation.sel(T=slice("1993","2016")), hcst, dim="T"),
              xs.mae(observation.sel(T=slice("1993","2016")), hcst_cor, dim="T")],
              dim="mae")
    mae = mae.assign_coords(mae=["model", "model corrigé"])
    mae.plot(col="mae")
    qmap.plot_fraction_group(dry_wet, "dry_fraction_", extent=extent_obs)
    qmap.plot_fraction_group(dry_wet, "wet_fraction_", extent=extent_obs)
    qmap.plot_mean_wet_group(dry_wet, extent=extent_obs)
    qmap.plot_extreme_quantiles_group(extrem, extent=extent_obs)
# Out:
# bom2
# ecmwf51
# ukmo604
# meteo_france9
# dwd22
# ncep2

# %% [markdown]
# #### Compute Onset for models

# %%
hindcast_files
# Out:
# {'bom2': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_Onset_JanIc.nc',
#  'ecmwf51': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_Onset_JanIc.nc',
#  'ukmo604': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_Onset_JanIc.nc',
#  'meteo_france9': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_meteo_france9_Onset_JanIc.nc',
#  'dwd22': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_Onset_JanIc.nc',
#  'ncep2': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_Onset_JanIc.nc'}

# %%
forecast_files
# Out:
# {'bom2': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_Onset_JanIc.nc',
#  'ecmwf51': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_Onset_JanIc.nc',
#  'ukmo604': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_Onset_JanIc.nc',
#  'meteo_france9': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_meteo_france9_Onset_JanIc.nc',
#  'dwd22': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_Onset_JanIc.nc',
#  'ncep2': 'Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_Onset_JanIc.nc'}

# %%
hindcast_files, forecast_files = process_model_for_other_params(was_onset, dir_s2s, hindcast_files_cor, forecast_files_cor, rainfall, 
rainfall_for_forecast_year, month_of_initialization, year_start_model, year_end_model, forecast, nb_cores=4, agrometparam=agrometparam)
# Out:
# 2026-02-11 10:33:43,784 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/worker.py", line 1251, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:51034 remote=tcp://127.0.0.1:36289>: Stream is closed
# 2026-02-11 10:34:05,547 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/worker.py", line 1251, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:56944 remote=tcp://127.0.0.1:41347>: Stream is closed
# 2026-02-11 10:35:58,991 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/worker.py", line 1251, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:39834 remote=tcp://127.0.0.1:45365>: Stream is closed
# 2026-02-11 10:36:55,990 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/worker.py", line 1251, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:58236 remote=tcp://127.0.0.1:46673>: Stream is closed
# 2026-02-11 10:37:45,185 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/worker.py", line 1251, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:42168 remote=tcp://127.0.0.1:44467>: Stream is closed
# 2026-02-11 10:37:45,186 - distributed.worker - ERROR - Failed to communicate with scheduler during heartbeat.
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 225, in read
#     frames_nosplit_nbytes_bin = await stream.read_bytes(fmt_size)
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/worker.py", line 1251, in heartbeat
#     response = await retry_operation(
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 459, in retry_operation
#     return await retry(
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/utils_comm.py", line 438, in retry
#     return await coro()
#            ^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1395, in send_recv_from_rpc
#     return await send_recv(comm=comm, op=key, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/core.py", line 1154, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 236, in read
#     convert_stream_closed_error(self, e)
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/distributed/comm/tcp.py", line 142, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:42164 remote=tcp://127.0.0.1:44467>: Stream is closed

# %%
was_verify = WAS_Verification(dist_method=dist_method,mae_rmse_crps_thrsd=50)

# %% [markdown]
# #### Validation of GCM

# %%
score = ["Pearson", "MAE"]

# %%
os.makedirs(dir_save_score, exist_ok=True)
scores = {}
for i in score:
    scores[i] = was_verify.gcm_validation_compute(hindcast_files, onset, i, month_of_initialization, clim_year_start, clim_year_end, dir_save_score, lead_time = None, ensemble_mean=None, gridded=True)
    print(was_verify.scores[i][0])
    was_verify.plot_models_score(scores[i], i, dir_save_score)
# Out:
# Pearson Correlation
# Mean Absolute Error

# %% [markdown]
# ## Choice of best GCM models

# %%
best_models = get_best_models(center_variable, scores, metric='MAE', threshold=10, top_n=5, agroparam=True, gcm=False)
best_models
# Out:
# ['BOM_2.PRCP',
#  'ECMWF_51.PRCP',
#  'UKMO_604.PRCP',
#  'METEOFRANCE_9.PRCP',
#  'DWD_22.PRCP']

# %% [markdown]
# ### MLP

# %%
# from scipy.stats import loguniform
model = WAS_mme_MLP(
    hidden_layer_sizes_range=[
        (2,2), (3,2), (2,4), (4,2),
        (5,2), (5,5), (5,5,5),
        (8,4), (16,8), (24,16),
        # (32,24), (32,24,16),
        # (15,10,5,2),
        # (30,), (50,),              # Moderate baseline
        # (60, 30), (100, 50),       # Compression funnels
        # (30, 15, 5)                # Deep funnel for complex non-linearities
    ],
    learning_rate_init_range=loguniform(1e-4, 1e-1),
    activation_options=['tanh', 'identity'],        
    solver_options=['adam','sgd'],#, 'lbfgs'],  # sgd, lbfgs         
    alpha_range=loguniform(1e-5, 1e-1),   
    search_method='bayesian',                              
    random_state=42,
    n_iter_search=25,  
    max_iter=2000,
    cv_folds=5,
    n_clusters=1,
    dist_method=dist_method,
    optuna_n_jobs=-1,
    optuna_timeout=600
)

# %% [markdown]
# #### Cross-validation

# %%
# all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), gcm=True, ELM_ELR=True, dir_to_save_model=dir_to_save_model, best_models=best_models, scores=scores, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))),
                                                                            hdcsted=hindcast_files, 
                                                                            fcsted=forecast_files, scores= scores, score_metric='MAE', gcm=False, agroparam=True, ELM_ELR=False, best_models=best_models, dir_to_save_model=dir_to_save_model, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization,  year_forecast=forecast)

# %%
best_params, cluster = model.compute_hyperparameters(all_model_hdcst, obs, clim_year_start, clim_year_end)

# %%
best_params #= {'activation': 'lin', 'neurons': 200, 'norm': 37.38460883888426}

# %%
cluster.plot()

# %%
was_mme_gcm = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start, 
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster,
                                                                  best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start,
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster
                                                                     )    
hdcst_consolidated['SV-ML-CMME_MLP'] = hindcast_det_gcm
hdcst_consolidated_prob['SV-ML-CMME_MLP'] = hindcast_prob_gcm

# %%
was_verify = WAS_Verification(dist_method=dist_method, mae_rmse_crps_thrsd=250)

# %% [markdown]
# #### Verification

# %%
score = ['Pearson', 'MAE']
model_name = "MLP" #"Extreme Learning Machine" # Extreme Learning Machine "MultiLayer Perceptron" XGBoost Random Forest

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det_gcm
    )
    scores_consolidated[i] = {'SV-ML-CMME_MLP': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ##### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob_gcm,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'SV-ML-CMME_MLP': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# #### Forecast

# %%
if dist_method=="bestfit":
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, all_model_fcst, best_params=best_params, cluster_da=cluster, 
                                                        best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, 
                                                        all_model_fcst, best_params=best_params, cluster_da=cluster
                                                       )
    
fcst_consolidated['SV-ML-CMME_MLP'] = forecast_det_gcm
fcst_consolidated_prob['SV-ML-CMME_MLP'] = forecast_prob_gcm
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_gcm.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels, reverse_cmap=True)
gc.collect()

# %% [markdown]
# ### Extreme Learning

# %%
model = WAS_mme_hpELM(neurons_range=[5, 10, 25, 50, 100, 200],# 400, 600, 800, 1000, 1500],    
                        activation_options=['sigm', 'tanh', 'lin'],# lin, 'rbf_l1', 'rbf_l2' 'rbf_linf'],
                        norm_range=loguniform(1e-2, 1e2),            
                        random_state=42,
                        n_iter_search=100,                             
                        cv_folds=5,
                        dist_method=dist_method,
                        search_method='bayesian',
                        n_clusters=1,
                        n_trials_bayesian=100,
                        bayesian_sampler='tpe', #random or tpe
                        )

# %% [markdown]
# #### Cross-validation

# %%
# all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), gcm=True, ELM_ELR=True, dir_to_save_model=dir_to_save_model, best_models=best_models, scores=scores, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), hdcsted=hindcast_files, fcsted=forecast_files, scores= scores, score_metric='MAE', gcm=True, agroparam=False, ELM_ELR=False, best_models=best_models, dir_to_save_model=dir_to_save_model, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)

# %%
best_params, cluster = model.compute_hyperparameters(all_model_hdcst, obs, clim_year_start, clim_year_end)

# %%
best_params #= {'activation': 'lin', 'neurons': 200, 'norm': 37.38460883888426}

# %%
cluster.plot()

# %%
was_mme_gcm = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start, 
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster,
                                                                  best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start,
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster
                                                                     )    
hdcst_consolidated['SV-ML-CMME_ELM'] = hindcast_det_gcm
hdcst_consolidated_prob['SV-ML-CMME_ELM'] = hindcast_prob_gcm

# %% [markdown]
# #### Verification

# %%
score = ['Pearson', 'MAE']
model_name = "Extreme Learning Machine" #"Extreme Learning Machine" # Extreme Learning Machine "MultiLayer Perceptron" XGBoost Random Forest

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det_gcm
    )
    scores_consolidated[i] = {'SV-ML-CMME_ELM': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ##### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob_gcm,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'SV-ML-CMME_ELM': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# #### Forecast

# %%
if dist_method=="bestfit":
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, all_model_fcst, best_params=best_params, cluster_da=cluster, 
                                                        best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, 
                                                        all_model_fcst, best_params=best_params, cluster_da=cluster
                                                       )
    
fcst_consolidated['SV-ML-CMME_ELM'] = forecast_det_gcm
fcst_consolidated_prob['SV-ML-CMME_ELM'] = forecast_prob_gcm
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_gcm.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels, reverse_cmap=True)
gc.collect()

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### XGBoost

# %%
model = WAS_mme_XGBoosting(
    search_method='bayesian',#'random',  # Use randomized search for efficiency
    n_estimators_range=[25, 50, 100, 200, 300, 500],# 600, 700, 1000, 1500],# 3000, 5000],  # Optimized for climate data
    learning_rate_range=[0.01, 0.05, 0.1],  # Finer low values
    max_depth_range=[2, 3, 4, 5],  # Conservative depths
    min_child_weight_range=[1, 2, 5, 10],
    subsample_range=[0.6, 0.8, 1.0],
    colsample_bytree_range=[0.5, 0.7, 0.9, 1.0],
    gamma_range=[0, 0.001, 0.01, 0.1, 0.5, 1.0],  # ADDED: Regularization
    reg_alpha_range=[0, 0.1, 0.5, 1.0],  # ADDED: L1 regularization
    reg_lambda_range=[1, 3, 5, 10],  # ADDED: L2 regularization
    random_state=42,
    dist_method=dist_method,  # Use non-parametric for probabilities
    n_iter_search=100,  # Increase iterations for better search
    cv_folds=5,
    n_clusters=2,  # Number of homogeneous zones
    optuna_n_jobs=-1,  # Use all cores if using bayesian optimization
    optuna_timeout=1200  # 20 minute timeout
)

# %% [markdown]
# #### Cross-validation

# %%
# all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), gcm=True, ELM_ELR=True, dir_to_save_model=dir_to_save_model, best_models=best_models, scores=scores, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), hdcsted=hindcast_files, fcsted=forecast_files, scores= scores, score_metric='MAE', gcm=True, agroparam=False, ELM_ELR=False, best_models=best_models, dir_to_save_model=dir_to_save_model, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)

# %%
best_params, cluster = model.compute_hyperparameters(all_model_hdcst, obs, clim_year_start, clim_year_end)

# %%
best_params #= {'activation': 'lin', 'neurons': 200, 'norm': 37.38460883888426}

# %%
cluster.plot()

# %%
was_mme_gcm = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start, 
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster,
                                                                  best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start,
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster
                                                                     )    
hdcst_consolidated['SV-ML-CMME_XGBOOST'] = hindcast_det_gcm
hdcst_consolidated_prob['SV-ML-CMME_XGBOOST'] = hindcast_prob_gcm

# %% [markdown]
# #### Verification

# %%
score = ['Pearson', 'MAE']
model_name = "XGBoost" #"Extreme Learning Machine" # Extreme Learning Machine "MultiLayer Perceptron" XGBoost Random Forest

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det_gcm
    )
    scores_consolidated[i] = {'SV-ML-CMME_XGBOOST': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ##### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob_gcm,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'SV-ML-CMME_XGBOOST': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# #### Forecast

# %%
if dist_method=="bestfit":
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, all_model_fcst, best_params=best_params, cluster_da=cluster, 
                                                        best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, 
                                                        all_model_fcst, best_params=best_params, cluster_da=cluster
                                                       )
    
fcst_consolidated['SV-ML-CMME_XGBOOST'] = forecast_det_gcm
fcst_consolidated_prob['SV-ML-CMME_XGBOOST'] = forecast_prob_gcm
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_gcm.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels, reverse_cmap=True)
gc.collect()

# %% [markdown]
# # 2nd - Approach: CCA-Based Calibration VWIND

# %%
# Filter model names to identify precipitation-related models
center_variable = [key for key in downloader.ModelsName().keys() if "VGRD_850" in key]
center_variable.remove('UKMO_603.VGRD_850')
center_variable.remove('UKMO_604.VGRD_850')

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/model_data"

# Define the month for model initialization (June)
month_of_initialization = "12"

# Define lead times corresponding to seasonal forecast targets (JAS season in this case)
lead_time = ["01", "02", "03"]  # July-August-September forecast period

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent = [50, -60, -50, 30]  # [Northern, Western, Southern and Eastern] 


# Define if you want to download forecast or hindcast
forecast = None

# Define if you want all members of ensemble or doing an ensemble mean
ensemble_mean = "mean"

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
hindcast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)
# Out:
# 2026-02-11 22:13:55,578 INFO Request ID is 94554fe0-8c2a-411d-a623-8ec63970698a
# 2026-02-11 22:13:55,789 INFO status has been updated to accepted
# 2026-02-11 22:32:25,685 INFO status has been updated to successful
# 4543712395874d7167d5205b02fa02a0.nc:   0%|          | 0.00/46.2M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for bom 2 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-11 22:35:55,339 INFO Request ID is e724d37f-8c68-4b3c-b648-36d2a63a1eb4
# 2026-02-11 22:35:55,723 INFO status has been updated to accepted
# 2026-02-11 22:36:30,549 INFO status has been updated to successful
# ec62c7fba034dd1118e78baecd2acdb8.nc:   0%|          | 0.00/42.2M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ecmwf 51 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-11 22:40:15,160 INFO Request ID is bf1accc1-1ab9-47ab-a720-a6f2f60cb487
# 2026-02-11 22:40:15,367 INFO status has been updated to accepted
# 2026-02-11 22:54:41,534 INFO status has been updated to successful
# fb02911aeeb7df37a7103d08ecec6e9f.nc:   0%|          | 0.00/58.8M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ukmo 604 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-11 22:59:19,091 INFO Request ID is 3c5a2483-4e9a-42bb-b26a-535ea733ea8a
# 2026-02-11 22:59:19,289 INFO status has been updated to accepted
# 2026-02-11 22:59:34,028 INFO status has been updated to successful
# aac33884f96bc65a79d283ab9696d5a9.nc:   0%|          | 0.00/51.5M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance8_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance8_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for meteo_france 8 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance8_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-11 23:03:23,008 INFO Request ID is 75056d88-7b33-4816-84a1-fb0b4c8d79ec
# 2026-02-11 23:03:23,933 INFO status has been updated to accepted
# 2026-02-11 23:03:46,692 INFO status has been updated to successful
# 8d94417bfe16cf06cc9916cd4ba7511c.nc:   0%|          | 0.00/55.1M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance9_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance9_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for meteo_france 9 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance9_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-11 23:07:29,744 INFO Request ID is de730f81-2c9e-45e1-ba09-a6b4fc65b6c2
# 2026-02-11 23:07:30,137 INFO status has been updated to accepted
# 2026-02-11 23:30:02,828 INFO status has been updated to successful
# 4a689813fa859b418dcb23aec75989e1.nc:   0%|          | 0.00/63.2M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd21_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd21_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for dwd 21 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd21_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-11 23:34:23,926 INFO Request ID is ef50a5cb-5feb-4a10-95fe-c6a621f5a4a5
# 2026-02-11 23:34:24,127 INFO status has been updated to accepted
# 2026-02-11 23:34:38,492 INFO status has been updated to successful
# 498691a64daf8097f7757635cb6180d1.nc:   0%|          | 0.00/60.7M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for dwd 22 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-11 23:39:01,467 INFO Request ID is bcfccbd1-fb19-4fbb-b38b-7e70ad0a0991
# 2026-02-11 23:39:01,776 INFO status has been updated to accepted
# 2026-02-11 23:39:15,842 INFO status has been updated to running
# 2026-02-11 23:39:23,647 INFO status has been updated to successful
# cc3797b9a6aae2976dbed7f0b8787ab6.nc:   0%|          | 0.00/81.7M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmcc35_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmcc35_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for cmcc 35 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmcc35_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-11 23:43:58,629 INFO Request ID is 9648dcfc-1f27-4998-b7e3-072134a6c01e
# 2026-02-11 23:43:58,854 INFO status has been updated to accepted
# 2026-02-11 23:58:28,567 INFO status has been updated to successful
# 59bcd00ae574b2d1ec457d81c37197a0.nc:   0%|          | 0.00/41.2M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ncep 2 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:02:51,508 INFO Request ID is ae278e12-5cc9-4c99-b2ec-d023f908a4f7
# 2026-02-12 00:02:51,745 INFO status has been updated to accepted
# 2026-02-12 00:03:01,247 INFO status has been updated to running
# 2026-02-12 00:03:06,589 INFO status has been updated to successful
# c1ab045a9c5c598bcecdd4c8fbc4c00f.nc:   0%|          | 0.00/11.0M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_jma3_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_jma3_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for jma 3 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_jma3_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:05:07,165 INFO Request ID is a860cdf7-83d9-4fae-b5f5-30b67f0087bd
# 2026-02-12 00:05:07,380 INFO status has been updated to accepted
# 2026-02-12 00:05:21,949 INFO status has been updated to running
# 2026-02-12 00:05:29,735 INFO status has been updated to successful
# 9806eb0795b16793e01698be1182dbb9.nc:   0%|          | 0.00/38.1M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc4_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc4_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 4 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc4_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:07:17,366 INFO Request ID is 3be531c1-d670-43eb-bdae-c5cfd20072d4
# 2026-02-12 00:07:17,553 INFO status has been updated to accepted
# 2026-02-12 00:07:26,383 INFO status has been updated to running
# 2026-02-12 00:07:31,626 INFO status has been updated to successful
# e3cc22eef236a8cf199cd85ae3e52505.nc:   0%|          | 0.00/38.5M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc5_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc5_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 5 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc5_VGRD_850_DecIc_JanFebMar_01.nc
# URL returned status code 404. Skipping download.
# failed to download cfsv2_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download cfsv2_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download cmc1_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download cmc1_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download cmc2_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download cmc2_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download gfdl_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download gfdl_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download nasa_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download nasa_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_ccsm4_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_ccsm4_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_cesm1_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_cesm1_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download nmme_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download nmme_VGRD_850_hcst_Decic_1-3_1991-2020.txt

# %%
forecast = 2025

# %%
forecast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)
# Out:
# 2026-02-12 00:10:05,588 INFO Request ID is a2a4106a-5825-4f6e-b9e5-736d677dfb9f
# 2026-02-12 00:10:05,778 INFO status has been updated to accepted
# 2026-02-12 00:10:19,788 INFO status has been updated to running
# 2026-02-12 00:10:27,753 INFO status has been updated to successful
# 274d0a22e8fe5e5915aaed6d8c62fbca.nc:   0%|          | 0.00/7.91M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for bom 2 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:10:40,174 INFO Request ID is 0247dd9b-17a8-45a6-b039-de1e56614bf5
# 2026-02-12 00:10:40,415 INFO status has been updated to accepted
# 2026-02-12 00:10:54,666 INFO status has been updated to running
# 2026-02-12 00:11:02,459 INFO status has been updated to successful
# b4070510160c9a258b930733fef1fb90.nc:   0%|          | 0.00/3.33M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ecmwf 51 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:11:13,909 INFO Request ID is aa771ebd-83f8-4059-bd14-f5c314713baf
# 2026-02-12 00:11:14,098 INFO status has been updated to accepted
# 2026-02-12 00:11:28,268 INFO status has been updated to running
# 2026-02-12 00:11:36,088 INFO status has been updated to successful
# 22c3e87d02d4ee6086868a44c11fd727.nc:   0%|          | 0.00/4.76M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ukmo 604 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:11:53,521 INFO Request ID is 6083a648-b4ba-484b-986a-6fc2513dd115
# 2026-02-12 00:11:53,678 INFO status has been updated to accepted
# 2026-02-12 00:12:15,431 INFO status has been updated to failed
# Failed to download data for VGRD_850: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/6083a648-b4ba-484b-986a-6fc2513dd115/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['50', '-60', '-50', '30'], 'fcmonth': ['01', '02', '03'], 'origin': ['lfpw'], 'levelist': ['850'], 'type': ['fcmean'], 'system': ['8'], 'param': ['132'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['pl'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# 2026-02-12 00:12:16,765 INFO Request ID is 7d3b5ea5-bbab-4e0d-b63d-822b93470723
# 2026-02-12 00:12:16,920 INFO status has been updated to accepted
# 2026-02-12 00:12:38,908 INFO status has been updated to successful
# 2cb348ff0332335829f25df99bd6a550.nc:   0%|          | 0.00/3.35M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_meteofrance9_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_meteofrance9_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for meteo_france 9 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/forecast_meteofrance9_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:12:45,987 INFO Request ID is e6c63b3b-967a-4e6e-80c8-ac79953eaab0
# 2026-02-12 00:12:46,165 INFO status has been updated to accepted
# 2026-02-12 00:13:08,487 INFO status has been updated to failed
# Failed to download data for VGRD_850: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/e6c63b3b-967a-4e6e-80c8-ac79953eaab0/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['50', '-60', '-50', '30'], 'fcmonth': ['01', '02', '03'], 'origin': ['edzw'], 'levelist': ['850'], 'type': ['fcmean'], 'system': ['21'], 'param': ['132'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['pl'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# 2026-02-12 00:13:11,021 INFO Request ID is 27c7c0d3-f93a-414a-a24f-41008e227d7e
# 2026-02-12 00:13:11,211 INFO status has been updated to accepted
# 2026-02-12 00:13:33,361 INFO status has been updated to successful
# 59f961867c3bb8dc541f5a8aac92afbe.nc:   0%|          | 0.00/3.94M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for dwd 22 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:13:51,701 INFO Request ID is 61283596-4f90-4fd6-b827-c3e0cd03aa13
# 2026-02-12 00:13:51,882 INFO status has been updated to accepted
# 2026-02-12 00:14:05,914 INFO status has been updated to failed
# Failed to download data for VGRD_850: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/61283596-4f90-4fd6-b827-c3e0cd03aa13/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['50', '-60', '-50', '30'], 'fcmonth': ['01', '02', '03'], 'origin': ['cmcc'], 'levelist': ['850'], 'type': ['fcmean'], 'system': ['35'], 'param': ['132'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['pl'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# 2026-02-12 00:14:07,121 INFO Request ID is 2d36881e-1653-44b0-a558-8b9c660fbf17
# 2026-02-12 00:14:07,283 INFO status has been updated to accepted
# 2026-02-12 00:14:29,101 INFO status has been updated to successful
# 86ff47c2c37577fdd9faa609da6f3759.nc:   0%|          | 0.00/10.2M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ncep 2 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:14:54,690 INFO Request ID is 2e39159d-1e09-43d3-80dc-f1fa6b7558ad
# 2026-02-12 00:14:54,891 INFO status has been updated to accepted
# 2026-02-12 00:15:28,535 INFO status has been updated to successful
# 62eac66a4ff332afc83739a751227989.nc:   0%|          | 0.00/6.40M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_jma3_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_jma3_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for jma 3 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/forecast_jma3_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:15:42,794 INFO Request ID is 8534e014-57d4-4e91-890c-21d7167ea34e
# 2026-02-12 00:15:42,976 INFO status has been updated to accepted
# 2026-02-12 00:16:05,332 INFO status has been updated to running
# 2026-02-12 00:16:16,896 INFO status has been updated to successful
# bb4389fb6d9bdd4c94081e9943f20320.nc:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc4_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc4_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 4 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc4_VGRD_850_DecIc_JanFebMar_01.nc
# 2026-02-12 00:16:36,110 INFO Request ID is 5d9b1fc3-857c-4a4c-a268-f03005fe917d
# 2026-02-12 00:16:36,269 INFO status has been updated to accepted
# 2026-02-12 00:16:45,524 INFO status has been updated to running
# 2026-02-12 00:16:50,760 INFO status has been updated to successful
# 92d9ecf46bad2e9089ea7f432a222c3c.nc:   0%|          | 0.00/1.59M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc5_VGRD_850_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc5_VGRD_850_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 5 VGRD_850 to Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc5_VGRD_850_DecIc_JanFebMar_01.nc
# URL returned status code 404. Skipping download.
# failed to download cfsv2_VGRD_850_fcst_Decic_1-3_2026-2026.txt
# URL returned status code 404. Skipping download.
# failed to download cmc1_VGRD_850_fcst_Decic_1-3_2026-2026.txt
# URL returned status code 404. Skipping download.
# failed to download cmc2_VGRD_850_fcst_Decic_1-3_2026-2026.txt
# URL returned status code 404. Skipping download.
# failed to download gfdl_VGRD_850_fcst_Decic_1-3_2026-2026.txt
# URL returned status code 404. Skipping download.
# failed to download nasa_VGRD_850_fcst_Decic_1-3_2026-2026.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_ccsm4_VGRD_850_fcst_Decic_1-3_2026-2026.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_cesm1_VGRD_850_fcst_Decic_1-3_2026-2026.txt
# URL returned status code 404. Skipping download.
# failed to download nmme_VGRD_850_fcst_Decic_1-3_2026-2026.txt

# %%
hindcast_files = {k: hindcast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
forecast_files = {k: forecast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
common_keys = {k.lower() for k in hindcast_files} & {k.lower() for k in forecast_files}
center_variable = [
    item
    for item in center_variable
    if any(item.lower().startswith(k) for k in list(common_keys))
                ]

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initialize the WAS_CCA class (default)

# %%
n_modes = 3
# define zone as dict : {'zone_name_key': ('Explicit_Zone_name', lon_min, lon_max, lat_min, lat_max)} 
defined_zone = {'A': ('A', -60, 30, -50, 50)}

# %%
plot_map([extent[1],extent[3],extent[2],extent[0]], sst_indices = defined_zone, title="Predictors Area",fig_size=(6,4))

# %% [markdown]
# ##### Modes of CCA for each model

# %%
was_cca = WAS_CCA_old(n_modes=n_modes, n_pca_modes=8, dist_method=dist_method)
was_cv = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
predictors = {}
for i in center_variable:
    predictors[i] = retrieve_single_zone_for_PCR(dir_to_save_model, defined_zone, i, year_start_model, year_end_model, clim_year_start=clim_year_start, clim_year_end=clim_year_end, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, standardize=True)
    predictor = predictors[i].isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(f"CCA Modes for model {i}")
    was_cca.plot_cca_results(X=predictor, Y=onset.sel(T=slice(str(year_start_model),str(year_end_model))) , clim_year_start=clim_year_start, clim_year_end=clim_year_end)

# %% [markdown]
# #### Cross validation

# %%
hindcast_det_dynam_all = {}
hindcast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                          predictor, clim_year_start, clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))).sel(T=slice(str(year_start_model),str(year_end_model))), predictor, clim_year_start, clim_year_end)

# %% [markdown]
# #### Verification (individual)

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "CCA-based"

# %%
cca_scores = {}
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_deterministic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_det_dynam_all[key]
        )
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_probabilistic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_prob_dynam_all[key],
            clim_year_start,
            clim_year_end)
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# #### Forecast (individual)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
forecast_det_dynam_all = {}
forecast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor_f = predictor.isel(T=[-1])
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f)
    model_name = f"CCA_{key.split('.')[0]}"    
    plot_prob_forecasts(f"{dir_to_forecast}",
                        forecast_prob_dynam_all[key].drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}", 
                        hspace=0.1, labels=fcst_labels, reverse_cmap=True)

# %% [markdown]
# ### Select best Statistico-Dynamical models

# %%
#### Select some models
best_models = get_best_models(center_variable, cca_scores, metric='GROC', threshold=0.6, top_n=4, gcm=False)
best_models

# %%
for key in best_models:
    hdcst_consolidated[f'{key}_snd.approach'] = hindcast_det_dynam_all[key]
    fcst_consolidated[f'{key}_snd.approach'] = forecast_det_dynam_all[key]
    hdcst_consolidated_prob[f'{key}_snd.approach'] = hindcast_prob_dynam_all[key]
    fcst_consolidated_prob[f'{key}_snd.approach'] = forecast_prob_dynam_all[key]
    
for metric, models in cca_scores.items():
    for model in list(models):                    # list() pour éviter RuntimeError
        if not any(model.startswith(p) for p in best_models):
            del models[model]

for key in cca_scores:
    scores_consolidated.setdefault(key, {}).update(cca_scores[key])

# %% [markdown]
# # 2nd - Approach: CCA-Based Calibration SST

# %%
# Filter model names to identify precipitation-related models
center_variable = [key for key in downloader.ModelsName().keys() if "SST" in key]
# center_variable.remove('NASA_1.SST')
center_variable.remove('UKMO_603.SST')
center_variable.remove('UKMO_604.SST')
center_variable.remove('NMME_1.SST')
# center_variable.remove('CMC2_1.SST')
# center_variable.remove('METEOFRANCE_8.SST')

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/model_data"

# Define the month for model initialization (June)
month_of_initialization = "12"

# Define lead times corresponding to seasonal forecast targets (JAS season in this case)
lead_time = ["01", "02", "03"]  # July-August-September forecast period

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent = [60, -180, -60, 180]  # [Northern, Western, Southern and Eastern] 

# Define if you want to download forecast or hindcast
forecast = None

# Define if you want all members of ensemble or doing an ensemble mean
ensemble_mean = "mean"

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
hindcast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)
# Out:
# 2026-02-12 00:17:06,314 INFO Request ID is 1dc2a1fc-d9ef-4039-b974-bf6c4d531652
# 2026-02-12 00:17:06,497 INFO status has been updated to accepted
# 2026-02-12 00:17:20,655 INFO status has been updated to successful
# 8c1d99c3632d403a0da5ea99f3490a3f.nc:   0%|          | 0.00/123M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for bom 2 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 00:25:46,062 INFO Request ID is bb40b70d-f19a-4fc2-85c1-23567d6eb618
# 2026-02-12 00:25:46,264 INFO status has been updated to accepted
# 2026-02-12 00:26:00,426 INFO status has been updated to running
# 2026-02-12 00:26:08,209 INFO status has been updated to successful
# 7b893a633a918a71677e28b08e7ef1c0.nc:   0%|          | 0.00/112M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ecmwf 51 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 00:35:25,664 INFO Request ID is 860efafa-5930-4909-a47c-fa96a4cfa096
# 2026-02-12 00:35:25,838 INFO status has been updated to accepted
# 2026-02-12 00:35:34,676 INFO status has been updated to running
# 2026-02-12 00:35:40,117 INFO status has been updated to successful
# 89e9fe68b981f4cf88340b978bf06c45.nc:   0%|          | 0.00/131M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ukmo 604 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 00:44:03,676 INFO Request ID is 688ea4a6-fa94-411b-9a73-5fc3ee236f27
# 2026-02-12 00:44:04,167 INFO status has been updated to accepted
# 2026-02-12 00:44:26,020 INFO status has been updated to successful
# ffed66f5346003943dfe6b1a2e6b07ba.nc:   0%|          | 0.00/113M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance8_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance8_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for meteo_france 8 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance8_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 00:51:21,579 INFO Request ID is b88e9e6c-1ea0-4562-80b0-52308f7df659
# 2026-02-12 00:51:21,757 INFO status has been updated to accepted
# 2026-02-12 00:51:30,614 INFO status has been updated to running
# 2026-02-12 00:51:35,854 INFO status has been updated to successful
# 4750fb07eb005b8e7583a0e54e5eea71.nc:   0%|          | 0.00/140M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance9_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance9_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for meteo_france 9 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance9_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 01:01:26,225 INFO Request ID is 9fb8276a-7254-4762-9a4d-e35ad5ec5011
# 2026-02-12 01:01:26,433 INFO status has been updated to accepted
# 2026-02-12 01:01:40,576 INFO status has been updated to successful
# 48d4a1a7b9ac0d28571b09c906f55a93.nc:   0%|          | 0.00/132M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd21_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd21_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for dwd 21 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd21_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 01:11:03,831 INFO Request ID is 19e0a4ac-ae5e-4349-a7d8-c47450619a4f
# 2026-02-12 01:11:04,025 INFO status has been updated to accepted
# 2026-02-12 01:11:18,611 INFO status has been updated to successful
# cc9c3489ab49f6164c2ca250b41f6bd7.nc:   0%|          | 0.00/131M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for dwd 22 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 01:18:31,349 INFO Request ID is 8bd9887c-bb1a-4887-a0cd-ae46c2218133
# 2026-02-12 01:18:31,832 INFO status has been updated to accepted
# 2026-02-12 01:19:22,524 INFO status has been updated to running
# 2026-02-12 01:19:48,315 INFO status has been updated to successful
# b52ff1097b35ed3af9d8729e8e4c3d87.nc:   0%|          | 0.00/174M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmcc35_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmcc35_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for cmcc 35 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmcc35_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 01:31:12,702 INFO Request ID is 7e5c2db4-23af-42b4-b19a-20ae09ca71a3
# 2026-02-12 01:31:12,899 INFO status has been updated to accepted
# 2026-02-12 01:31:34,908 INFO status has been updated to successful
# 742ce3a32f1ea3d8b005ed2abb1e9e00.nc:   0%|          | 0.00/107M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ncep 2 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 01:39:19,214 INFO Request ID is 01b161af-2242-4281-9107-af1aa7cc015d
# 2026-02-12 01:39:19,382 INFO status has been updated to accepted
# 2026-02-12 01:39:41,337 INFO status has been updated to running
# 2026-02-12 01:39:53,401 INFO status has been updated to successful
# 7d91c1a93d79e0604235dfa70544a20a.nc:   0%|          | 0.00/26.1M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_jma3_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_jma3_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for jma 3 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_jma3_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 01:41:17,866 INFO Request ID is 7dc6c8fe-344c-4744-9f52-34edf9b95d56
# 2026-02-12 01:41:18,046 INFO status has been updated to accepted
# 2026-02-12 01:41:32,103 INFO status has been updated to successful
# 6c27509d641f37317c4b9ee4cddc6598.nc:   0%|          | 0.00/84.0M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc4_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc4_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 4 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc4_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 01:47:06,867 INFO Request ID is a6bc49ec-7cce-4cd9-ae9d-3066333ec99b
# 2026-02-12 01:47:07,071 INFO status has been updated to accepted
# 2026-02-12 01:47:21,306 INFO status has been updated to successful
# 1fd8af0150ac7b00f572e02756d94156.nc:   0%|          | 0.00/84.0M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc5_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc5_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 5 SST to Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc5_SST_DecIc_JanFebMar_01.nc
# cfsv2_sst_hcst_Decic_1-3_1992-2021.txt: 22.6MB [01:02, 360kB/s]
# URL returned status code 404. Skipping download.
# failed to download cfsv2_sst_hcst_Decic_1-3_1991-2020.txt
# Download finished for cfsv2 1 sst to Agro_PRESAGG_2026_ic_1/model_data/hindcast_cfsv21_SST_DecIc_JanFebMar_01.nc
# cmc1_sst_hcst_Decic_1-3_1992-2021.txt: 22.6MB [01:15, 301kB/s]
# URL returned status code 404. Skipping download.
# failed to download cmc1_sst_hcst_Decic_1-3_1991-2020.txt
# Download finished for cmc1 1 sst to Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmc11_SST_DecIc_JanFebMar_01.nc
# cmc2_sst_hcst_Decic_1-3_1992-2021.txt: 22.7MB [00:45, 495kB/s]
# URL returned status code 404. Skipping download.
# failed to download cmc2_sst_hcst_Decic_1-3_1991-2020.txt
# Download finished for cmc2 1 sst to Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmc21_SST_DecIc_JanFebMar_01.nc
# URL returned status code 404. Skipping download.
# failed to download gfdl_sst_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download gfdl_sst_hcst_Decic_1-3_1991-2020.txt
# nasa_sst_hcst_Decic_1-3_1992-2021.txt: 22.6MB [01:39, 228kB/s]
# URL returned status code 404. Skipping download.
# failed to download nasa_sst_hcst_Decic_1-3_1991-2020.txt
# Download finished for nasa 1 sst to Agro_PRESAGG_2026_ic_1/model_data/hindcast_nasa1_SST_DecIc_JanFebMar_01.nc
# ncar_ccsm4_sst_hcst_Decic_1-3_1992-2021.txt: 22.7MB [01:00, 374kB/s]
# URL returned status code 404. Skipping download.
# failed to download ncar_ccsm4_sst_hcst_Decic_1-3_1991-2020.txt
# Download finished for ncar_ccsm4 1 sst to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncarccsm41_SST_DecIc_JanFebMar_01.nc
# ncar_cesm1_sst_hcst_Decic_1-3_1992-2021.txt: 22.7MB [01:14, 306kB/s]
# URL returned status code 404. Skipping download.
# failed to download ncar_cesm1_sst_hcst_Decic_1-3_1991-2020.txt
# Download finished for ncar_cesm1 1 sst to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncarcesm11_SST_DecIc_JanFebMar_01.nc
# nmme_sst_hcst_Decic_1-3_1992-2021.txt: 22.7MB [00:42, 530kB/s]
# URL returned status code 404. Skipping download.
# failed to download nmme_sst_hcst_Decic_1-3_1991-2020.txt
# Download finished for nmme 1 sst to Agro_PRESAGG_2026_ic_1/model_data/hindcast_nmme1_SST_DecIc_JanFebMar_01.nc

# %%
forecast = 2025

# %%
forecast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)
# Out:
# 2026-02-12 01:59:45,067 INFO Request ID is 75f27e21-57c4-44f2-b2b4-51e6ac74bc6e
# 2026-02-12 01:59:45,264 INFO status has been updated to accepted
# 2026-02-12 01:59:54,235 INFO status has been updated to successful
# 13600909149f09168fd8adfb1b35cd95.nc:   0%|          | 0.00/23.1M [00:00<?, ?B/s]
# Recovering from connection error [('Connection broken: IncompleteRead(14172160 bytes read, 10028551 more expected)', IncompleteRead(14172160 bytes read, 10028551 more expected))], attempt 1 of 500
# Retrying in 120 seconds
# 13600909149f09168fd8adfb1b35cd95.nc:  56%|#####6    | 13.0M/23.1M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for bom 2 SST to Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 02:10:53,082 INFO Request ID is 9ff858e4-9014-42fd-a20e-4bc5e0df26f0
# 2026-02-12 02:10:53,247 INFO status has been updated to accepted
# 2026-02-12 02:11:15,259 INFO status has been updated to successful
# 3841b1d01fc9e9642848c28bf8dcbb52.nc:   0%|          | 0.00/9.38M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ecmwf 51 SST to Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 02:11:28,450 INFO Request ID is f223a9f8-9dfb-4006-a6d8-f308c9bc4538
# 2026-02-12 02:11:28,614 INFO status has been updated to accepted
# 2026-02-12 02:11:37,518 INFO status has been updated to running
# 2026-02-12 02:11:43,046 INFO status has been updated to successful
# fd71daaca69fc7790bed2dad9549cddb.nc:   0%|          | 0.00/11.6M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ukmo 604 SST to Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 02:12:02,422 INFO Request ID is 4dc60cdb-40b7-4c20-8185-df3795a81b76
# 2026-02-12 02:12:02,599 INFO status has been updated to accepted
# 2026-02-12 02:12:16,816 INFO status has been updated to failed
# Failed to download data for SST: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/4dc60cdb-40b7-4c20-8185-df3795a81b76/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['60', '-180', '-60', '180'], 'fcmonth': ['01', '02', '03'], 'origin': ['lfpw'], 'type': ['fcmean'], 'system': ['8'], 'param': ['34'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['sfc'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# 2026-02-12 02:12:18,316 INFO Request ID is 76a35c5f-0185-4175-be73-5becf759e5fc
# 2026-02-12 02:12:18,477 INFO status has been updated to accepted
# 2026-02-12 02:12:33,082 INFO status has been updated to running
# 2026-02-12 02:12:40,877 INFO status has been updated to successful
# 562d75b48c0e80180354bf54026645fb.nc:   0%|          | 0.00/9.62M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_meteofrance9_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_meteofrance9_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for meteo_france 9 SST to Agro_PRESAGG_2026_ic_1/model_data/forecast_meteofrance9_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 02:12:55,685 INFO Request ID is ec79d97e-57e9-48fb-9d93-cd2a4ae49ebc
# 2026-02-12 02:12:55,905 INFO status has been updated to accepted
# 2026-02-12 02:13:10,311 INFO status has been updated to failed
# Failed to download data for SST: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/ec79d97e-57e9-48fb-9d93-cd2a4ae49ebc/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['60', '-180', '-60', '180'], 'fcmonth': ['01', '02', '03'], 'origin': ['edzw'], 'type': ['fcmean'], 'system': ['21'], 'param': ['34'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['sfc'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# 2026-02-12 02:13:12,042 INFO Request ID is fe2cf754-38c6-4212-9c23-0830d060c56f
# 2026-02-12 02:13:12,226 INFO status has been updated to accepted
# 2026-02-12 02:13:26,942 INFO status has been updated to successful
# 9b38f4bd8761ba4789ca50cf18a452cc.nc:   0%|          | 0.00/9.12M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for dwd 22 SST to Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 02:13:41,439 INFO Request ID is 92f56125-5e94-43b4-a6f8-d94d84819e02
# 2026-02-12 02:13:42,143 INFO status has been updated to accepted
# 2026-02-12 02:13:51,163 INFO status has been updated to running
# 2026-02-12 02:13:56,527 INFO status has been updated to failed
# Failed to download data for SST: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/92f56125-5e94-43b4-a6f8-d94d84819e02/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['60', '-180', '-60', '180'], 'fcmonth': ['01', '02', '03'], 'origin': ['cmcc'], 'type': ['fcmean'], 'system': ['35'], 'param': ['34'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['sfc'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# 2026-02-12 02:13:58,415 INFO Request ID is 031d6cd3-4fc4-4f6e-8025-3abf8a85ff31
# 2026-02-12 02:13:58,632 INFO status has been updated to accepted
# 2026-02-12 02:14:20,877 INFO status has been updated to successful
# 156d995c2d9bffc7248749fac50c6ea3.nc:   0%|          | 0.00/24.2M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ncep 2 SST to Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 02:14:50,725 INFO Request ID is 6acf6bf9-4bb6-404a-b3a9-d14078fa66b9
# 2026-02-12 02:14:51,027 INFO status has been updated to accepted
# 2026-02-12 02:15:13,082 INFO status has been updated to successful
# a24f66ecb07c5d7447b6dcc66a1142a.nc:   0%|          | 0.00/18.8M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_jma3_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_jma3_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for jma 3 SST to Agro_PRESAGG_2026_ic_1/model_data/forecast_jma3_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 02:15:43,831 INFO Request ID is 18bf2361-d8c2-4526-ba84-74378c4a7a79
# 2026-02-12 02:15:44,034 INFO status has been updated to accepted
# 2026-02-12 02:15:52,904 INFO status has been updated to running
# 2026-02-12 02:15:58,222 INFO status has been updated to successful
# 1af6015b1b4d3cedbb88171dc8f55b6.nc:   0%|          | 0.00/3.39M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc4_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc4_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 4 SST to Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc4_SST_DecIc_JanFebMar_01.nc
# 2026-02-12 02:16:11,255 INFO Request ID is c355a01d-c946-49c3-9145-b1b6f2b54c39
# 2026-02-12 02:16:11,441 INFO status has been updated to accepted
# 2026-02-12 02:16:26,813 INFO status has been updated to running
# 2026-02-12 02:16:34,579 INFO status has been updated to successful
# 9b145c0524ee943d28afa1018fb42970.nc:   0%|          | 0.00/3.35M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc5_SST_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc5_SST_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 5 SST to Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc5_SST_DecIc_JanFebMar_01.nc
# cfsv2_sst_fcst_Decic_1-3_2026-2026.txt: 754kB [00:00, 845kB/s]
# Download finished for cfsv2 1 sst to Agro_PRESAGG_2026_ic_1/model_data/forecast_cfsv21_SST_DecIc_JanFebMar_01.nc
# cmc1_sst_fcst_Decic_1-3_2026-2026.txt: 755kB [00:00, 893kB/s]
# Download finished for cmc1 1 sst to Agro_PRESAGG_2026_ic_1/model_data/forecast_cmc11_SST_DecIc_JanFebMar_01.nc
# cmc2_sst_fcst_Decic_1-3_2026-2026.txt: 755kB [00:01, 519kB/s]
# Download finished for cmc2 1 sst to Agro_PRESAGG_2026_ic_1/model_data/forecast_cmc21_SST_DecIc_JanFebMar_01.nc
# URL returned status code 404. Skipping download.
# failed to download gfdl_sst_fcst_Decic_1-3_2026-2026.txt
# Download finished for gfdl 1 sst to Agro_PRESAGG_2026_ic_1/model_data/forecast_gfdl1_SST_DecIc_JanFebMar_01.nc
# URL returned status code 404. Skipping download.
# failed to download nasa_sst_fcst_Decic_1-3_2026-2026.txt
# Download finished for nasa 1 sst to Agro_PRESAGG_2026_ic_1/model_data/forecast_nasa1_SST_DecIc_JanFebMar_01.nc
# ncar_ccsm4_sst_fcst_Decic_1-3_2026-2026.txt: 756kB [00:03, 210kB/s]
# Download finished for ncar_ccsm4 1 sst to Agro_PRESAGG_2026_ic_1/model_data/forecast_ncarccsm41_SST_DecIc_JanFebMar_01.nc
# ncar_cesm1_sst_fcst_Decic_1-3_2026-2026.txt: 755kB [00:03, 196kB/s]
# Download finished for ncar_cesm1 1 sst to Agro_PRESAGG_2026_ic_1/model_data/forecast_ncarcesm11_SST_DecIc_JanFebMar_01.nc
# nmme_sst_fcst_Decic_1-3_2026-2026.txt: 755kB [00:00, 830kB/s]
# Download finished for nmme 1 sst to Agro_PRESAGG_2026_ic_1/model_data/forecast_nmme1_SST_DecIc_JanFebMar_01.nc

# %%
hindcast_files = {k: hindcast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
forecast_files = {k: forecast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
common_keys = {k.lower() for k in hindcast_files} & {k.lower() for k in forecast_files}
center_variable = [
    item
    for item in center_variable
    if any(item.lower().startswith(k) for k in list(common_keys))
                ]

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initialize the WAS_CCA class (default)

# %%
n_modes = 3
# define zone as dict : {'zone_name_key': ('Explicit_Zone_name', lon_min, lon_max, lat_min, lat_max)} 
defined_zone = {'A': ('A', -150, 150, -35, 35)}

# %%
plot_map([extent[1],extent[3],extent[2],extent[0]], sst_indices = defined_zone, title="Predictors Area",fig_size=(6,4))

# %% [markdown]
# ##### Modes of CCA for each model

# %%
was_cca = WAS_CCA_old(n_modes=n_modes, n_pca_modes=8, dist_method=dist_method)
was_cv = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
predictors = {}
for i in center_variable:
    predictors[i] = retrieve_single_zone_for_PCR(dir_to_save_model, defined_zone, i, year_start_model, year_end_model, clim_year_start=clim_year_start, clim_year_end=clim_year_end, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, standardize=True)
    predictor = predictors[i].isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(f"CCA Modes for model {i}")
    was_cca.plot_cca_results(X=predictor, Y=onset.sel(T=slice(str(year_start_model),str(year_end_model))) , clim_year_start=clim_year_start, clim_year_end=clim_year_end)

# %% [markdown]
# #### Cross validation

# %%
hindcast_det_dynam_all = {}
hindcast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                          predictor, clim_year_start, clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))).sel(T=slice(str(year_start_model),str(year_end_model))), predictor, clim_year_start, clim_year_end)

# %% [markdown]
# #### Verification (individual)

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "CCA-based"

# %%
cca_scores = {}
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_deterministic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_det_dynam_all[key]
        )
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_probabilistic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_prob_dynam_all[key],
            clim_year_start,
            clim_year_end)
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# #### Forecast (individual)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
forecast_det_dynam_all = {}
forecast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor_f = predictor.isel(T=[-1])
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f)
    model_name = f"CCA_{key.split('.')[0]}"    
    plot_prob_forecasts(f"{dir_to_forecast}",
                        forecast_prob_dynam_all[key].drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}", 
                        hspace=0.1, labels=fcst_labels, reverse_cmap=True)

# %% [markdown]
# ### Select best Statistico-Dynamical models

# %%
#### Select some models
best_models = get_best_models(center_variable, cca_scores, metric='GROC', threshold=0.6, top_n=4, gcm=False)
best_models

# %%
for key in best_models:
    hdcst_consolidated[f'{key}_snd.approach'] = hindcast_det_dynam_all[key]
    fcst_consolidated[f'{key}_snd.approach'] = forecast_det_dynam_all[key]
    hdcst_consolidated_prob[f'{key}_snd.approach'] = hindcast_prob_dynam_all[key]
    fcst_consolidated_prob[f'{key}_snd.approach'] = forecast_prob_dynam_all[key]
    
for metric, models in cca_scores.items():
    for model in list(models):                    # list() pour éviter RuntimeError
        if not any(model.startswith(p) for p in best_models):
            del models[model]

for key in cca_scores:
    scores_consolidated.setdefault(key, {}).update(cca_scores[key])

# %% [markdown]
# # 2nd - Approach: CCA-Based Calibration PRCP

# %%
# Filter model names to identify precipitation-related models
center_variable = [key for key in downloader.ModelsName().keys() if "PRCP" in key]
# center_variable.remove('NASA_1.SST')
center_variable.remove('UKMO_603.PRCP')
center_variable.remove('UKMO_604.PRCP')
# center_variable.remove('DWD_21.SST')
# center_variable.remove('CMC2_1.SST')
# center_variable.remove('METEOFRANCE_8.SST')

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/model_data"

# Define the month for model initialization (June)
month_of_initialization = "12"

# Define lead times corresponding to seasonal forecast targets (JAS season in this case)
lead_time = ["01", "02", "03"]  # July-August-September forecast period

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent = [30, -30, -20, 30]  # [Northern, Western, Southern and Eastern] 

# Define if you want to download forecast or hindcast
forecast = None

# Define if you want all members of ensemble or doing an ensemble mean
ensemble_mean = "mean"

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
hindcast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)
# Out:
# 2026-02-12 02:17:11,384 INFO Request ID is 85246773-0755-455d-9ba4-e216768c3043
# 2026-02-12 02:17:11,565 INFO status has been updated to accepted
# 2026-02-12 02:17:20,669 INFO status has been updated to running
# 2026-02-12 02:17:25,888 INFO status has been updated to successful
# 55616931516d208fe9fca3dc85b4a5e6.nc:   0%|          | 0.00/11.2M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for bom 2 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_bom2_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:17:48,803 INFO Request ID is 41502ff0-26ad-45f7-ac6c-9c3b18fa4791
# 2026-02-12 02:17:49,006 INFO status has been updated to accepted
# 2026-02-12 02:18:03,227 INFO status has been updated to successful
# e48952890a2712e46c09a78b779c6f06.nc:   0%|          | 0.00/11.3M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ecmwf 51 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ecmwf51_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:18:22,267 INFO Request ID is e79a5a0a-3b07-4e8e-bacc-6b83ad69cb14
# 2026-02-12 02:18:22,467 INFO status has been updated to accepted
# 2026-02-12 02:18:31,352 INFO status has been updated to running
# 2026-02-12 02:18:36,621 INFO status has been updated to successful
# 2172cf89606cc97078d755a6c77f9f82.nc:   0%|          | 0.00/13.1M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ukmo 604 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ukmo604_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:18:55,264 INFO Request ID is 7fce2c3f-a049-4294-8f21-ca5ed313c80e
# 2026-02-12 02:18:55,509 INFO status has been updated to accepted
# 2026-02-12 02:19:29,882 INFO status has been updated to successful
# ac0dd7143fa8b96e1fd1edbb41b1dcb9.nc:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance8_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance8_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for meteo_france 8 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance8_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:19:54,852 INFO Request ID is 8889abb5-9b1a-4dd1-98aa-a8292b3ad037
# 2026-02-12 02:19:55,057 INFO status has been updated to accepted
# 2026-02-12 02:20:09,279 INFO status has been updated to successful
# 4d74dc1f2c72643e7eedc985518b7157.nc:   0%|          | 0.00/12.1M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance9_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance9_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for meteo_france 9 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_meteofrance9_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:20:25,672 INFO Request ID is be0957d4-cf5c-4413-b299-bdc910ca5fa9
# 2026-02-12 02:20:25,858 INFO status has been updated to accepted
# 2026-02-12 02:20:47,886 INFO status has been updated to successful
# 5b2c0679cf59c9bd373818c6001a91e4.nc:   0%|          | 0.00/20.2M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd21_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd21_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for dwd 21 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd21_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:21:32,227 INFO Request ID is 8d91af54-afe4-4193-967a-164574456564
# 2026-02-12 02:21:32,414 INFO status has been updated to accepted
# 2026-02-12 02:21:41,383 INFO status has been updated to running
# 2026-02-12 02:21:46,684 INFO status has been updated to successful
# 463bcaf13d43b8a8bc801e0a68d5b001.nc:   0%|          | 0.00/18.1M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for dwd 22 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_dwd22_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:22:22,336 INFO Request ID is 41833222-83c2-4db5-b657-e475794c10a4
# 2026-02-12 02:22:22,527 INFO status has been updated to accepted
# 2026-02-12 02:22:44,687 INFO status has been updated to successful
# 42a7db4196255f2db483d12308081387.nc:   0%|          | 0.00/27.2M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmcc35_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmcc35_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for cmcc 35 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmcc35_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:23:24,086 INFO Request ID is a1657158-4ca8-4940-8d99-67ec3bf8ce49
# 2026-02-12 02:23:24,271 INFO status has been updated to accepted
# 2026-02-12 02:23:46,154 INFO status has been updated to successful
# 48841f9a109401a70a97fe05c63c2149.nc:   0%|          | 0.00/11.6M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ncep 2 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncep2_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:24:08,524 INFO Request ID is df0da57a-38bd-4f05-bd35-35a92c1a2992
# 2026-02-12 02:24:08,740 INFO status has been updated to accepted
# 2026-02-12 02:24:23,046 INFO status has been updated to running
# 2026-02-12 02:24:30,829 INFO status has been updated to successful
# d9d8800eca0adfe101f1b00d4b10a009.nc:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_jma3_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_jma3_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for jma 3 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_jma3_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:24:37,188 INFO Request ID is afd747d8-0888-440e-8a41-2061afd88d04
# 2026-02-12 02:24:37,402 INFO status has been updated to accepted
# 2026-02-12 02:25:10,899 INFO status has been updated to successful
# 45cdceb8668bc38511a7da7e467e07e7.nc:   0%|          | 0.00/12.8M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc4_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc4_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 4 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc4_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:25:32,523 INFO Request ID is 40db8928-5810-4a9e-a6dc-9df60fbc1cf3
# 2026-02-12 02:25:32,713 INFO status has been updated to accepted
# 2026-02-12 02:25:47,335 INFO status has been updated to successful
# dfa67f39bd66f943555674bc7859bded.nc:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc5_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc5_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 5 PRCP to Agro_PRESAGG_2026_ic_1/model_data/hindcast_eccc5_PRCP_DecIc_JanFebMar_01.nc
# cfsv2_precip_hcst_Decic_1-3_1992-2021.txt: 22.6MB [01:20, 281kB/s]
# URL returned status code 404. Skipping download.
# failed to download cfsv2_precip_hcst_Decic_1-3_1991-2020.txt
# Download finished for cfsv2 1 precip to Agro_PRESAGG_2026_ic_1/model_data/hindcast_cfsv21_PRCP_DecIc_JanFebMar_01.nc
# cmc1_precip_hcst_Decic_1-3_1992-2021.txt: 22.7MB [01:07, 335kB/s]
# URL returned status code 404. Skipping download.
# failed to download cmc1_precip_hcst_Decic_1-3_1991-2020.txt
# Download finished for cmc1 1 precip to Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmc11_PRCP_DecIc_JanFebMar_01.nc
# cmc2_precip_hcst_Decic_1-3_1992-2021.txt: 22.6MB [01:18, 290kB/s]
# URL returned status code 404. Skipping download.
# failed to download cmc2_precip_hcst_Decic_1-3_1991-2020.txt
# Download finished for cmc2 1 precip to Agro_PRESAGG_2026_ic_1/model_data/hindcast_cmc21_PRCP_DecIc_JanFebMar_01.nc
# URL returned status code 404. Skipping download.
# failed to download gfdl_precip_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download gfdl_precip_hcst_Decic_1-3_1991-2020.txt
# nasa_precip_hcst_Decic_1-3_1992-2021.txt: 22.7MB [01:57, 193kB/s]
# URL returned status code 404. Skipping download.
# failed to download nasa_precip_hcst_Decic_1-3_1991-2020.txt
# Download finished for nasa 1 precip to Agro_PRESAGG_2026_ic_1/model_data/hindcast_nasa1_PRCP_DecIc_JanFebMar_01.nc
# ncar_ccsm4_precip_hcst_Decic_1-3_1992-2021.txt: 22.2MB [01:12, 308kB/s]
# URL returned status code 404. Skipping download.
# failed to download ncar_ccsm4_precip_hcst_Decic_1-3_1991-2020.txt
# Download finished for ncar_ccsm4 1 precip to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncarccsm41_PRCP_DecIc_JanFebMar_01.nc
# ncar_cesm1_precip_hcst_Decic_1-3_1992-2021.txt: 22.3MB [01:03, 353kB/s]
# URL returned status code 404. Skipping download.
# failed to download ncar_cesm1_precip_hcst_Decic_1-3_1991-2020.txt
# Download finished for ncar_cesm1 1 precip to Agro_PRESAGG_2026_ic_1/model_data/hindcast_ncarcesm11_PRCP_DecIc_JanFebMar_01.nc
# nmme_precip_hcst_Decic_1-3_1992-2021.txt: 22.4MB [02:00, 186kB/s]
# URL returned status code 404. Skipping download.
# failed to download nmme_precip_hcst_Decic_1-3_1991-2020.txt
# Download finished for nmme 1 precip to Agro_PRESAGG_2026_ic_1/model_data/hindcast_nmme1_PRCP_DecIc_JanFebMar_01.nc

# %%
forecast = 2025

# %%
forecast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)
# Out:
# 2026-02-12 02:36:41,583 INFO Request ID is 0f501631-a78c-452d-9409-a479ef4ea18c
# 2026-02-12 02:36:41,756 INFO status has been updated to accepted
# 2026-02-12 02:37:04,323 INFO status has been updated to successful
# c9cd622b6802ea29304a8604974ba454.nc:   0%|          | 0.00/1.86M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for bom 2 PRCP to Agro_PRESAGG_2026_ic_1/model_data/forecast_bom2_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:37:28,108 INFO Request ID is 05de8a90-9435-4a14-81a3-1dbd6998a5d1
# 2026-02-12 02:37:28,307 INFO status has been updated to accepted
# 2026-02-12 02:37:45,884 INFO status has been updated to successful
# 49b95ea7b5d7fc97f4688618bbd841f6.nc:   0%|          | 0.00/769k [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ecmwf 51 PRCP to Agro_PRESAGG_2026_ic_1/model_data/forecast_ecmwf51_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:37:57,263 INFO Request ID is fe812af3-a9ab-4107-ad13-b22e63c15721
# 2026-02-12 02:37:57,566 INFO status has been updated to accepted
# 2026-02-12 02:38:12,169 INFO status has been updated to running
# 2026-02-12 02:38:19,980 INFO status has been updated to successful
# f9d667fe0eba08093488ea4d58fda47b.nc:   0%|          | 0.00/970k [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ukmo 604 PRCP to Agro_PRESAGG_2026_ic_1/model_data/forecast_ukmo604_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:38:27,329 INFO Request ID is 580967de-4b87-4bde-ba61-36e0c36fd88c
# 2026-02-12 02:38:27,633 INFO status has been updated to accepted
# 2026-02-12 02:38:36,660 INFO status has been updated to running
# 2026-02-12 02:38:41,970 INFO status has been updated to failed
# Failed to download data for PRCP: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/580967de-4b87-4bde-ba61-36e0c36fd88c/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['30', '-30', '-20', '30'], 'fcmonth': ['01', '02', '03'], 'origin': ['lfpw'], 'type': ['fcmean'], 'system': ['8'], 'param': ['172228'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['sfc'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# 2026-02-12 02:38:43,993 INFO Request ID is 723a41f4-094d-4483-8f8a-273ddc9883f3
# 2026-02-12 02:38:44,403 INFO status has been updated to accepted
# 2026-02-12 02:39:06,814 INFO status has been updated to running
# 2026-02-12 02:39:19,573 INFO status has been updated to successful
# 13cc3696f0b15559a7bfd3ff27b44d17.nc:   0%|          | 0.00/810k [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_meteofrance9_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_meteofrance9_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for meteo_france 9 PRCP to Agro_PRESAGG_2026_ic_1/model_data/forecast_meteofrance9_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:39:35,378 INFO Request ID is f2c7efbe-c3d8-4bbb-9af9-ba72820579f9
# 2026-02-12 02:39:35,584 INFO status has been updated to accepted
# 2026-02-12 02:39:59,531 INFO status has been updated to failed
# Failed to download data for PRCP: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/f2c7efbe-c3d8-4bbb-9af9-ba72820579f9/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['30', '-30', '-20', '30'], 'fcmonth': ['01', '02', '03'], 'origin': ['edzw'], 'type': ['fcmean'], 'system': ['21'], 'param': ['172228'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['sfc'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# 2026-02-12 02:40:06,608 INFO Request ID is 4435ff78-89f4-4cd7-8782-97986def8c11
# 2026-02-12 02:40:06,946 INFO status has been updated to accepted
# 2026-02-12 02:40:23,989 INFO status has been updated to successful
# 569843c814c108600508ef9672d74fcd.nc:   0%|          | 0.00/1.18M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for dwd 22 PRCP to Agro_PRESAGG_2026_ic_1/model_data/forecast_dwd22_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:40:28,779 INFO Request ID is b35846ff-21f0-4926-a01a-8c7e320ab272
# 2026-02-12 02:40:28,954 INFO status has been updated to accepted
# 2026-02-12 02:40:51,082 INFO status has been updated to failed
# Failed to download data for PRCP: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/b35846ff-21f0-4926-a01a-8c7e320ab272/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['30', '-30', '-20', '30'], 'fcmonth': ['01', '02', '03'], 'origin': ['cmcc'], 'type': ['fcmean'], 'system': ['35'], 'param': ['172228'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['sfc'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# 2026-02-12 02:40:53,462 INFO Request ID is 1f12372b-8f56-4df4-ae04-332e714386e4
# 2026-02-12 02:40:53,666 INFO status has been updated to accepted
# 2026-02-12 02:41:16,236 INFO status has been updated to successful
# 7350ff9091851a4d04300d21028258b1.nc:   0%|          | 0.00/1.73M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for ncep 2 PRCP to Agro_PRESAGG_2026_ic_1/model_data/forecast_ncep2_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:41:25,329 INFO Request ID is bb2d1bad-20b9-46f2-95c6-dca9ef959db5
# 2026-02-12 02:41:25,582 INFO status has been updated to accepted
# 2026-02-12 02:41:34,761 INFO status has been updated to running
# 2026-02-12 02:41:40,213 INFO status has been updated to successful
# 15f2c8b7bf9685cb4241a2592a1b9f2.nc:   0%|          | 0.00/1.07M [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_jma3_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_jma3_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for jma 3 PRCP to Agro_PRESAGG_2026_ic_1/model_data/forecast_jma3_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:41:56,934 INFO Request ID is 0372b325-e7a0-4c86-b312-8e2f0439bd2d
# 2026-02-12 02:41:57,210 INFO status has been updated to accepted
# 2026-02-12 02:42:30,972 INFO status has been updated to running
# 2026-02-12 02:42:48,540 INFO status has been updated to successful
# fb45b093f28eef50c939091e47159423.nc:   0%|          | 0.00/559k [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc4_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc4_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 4 PRCP to Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc4_PRCP_DecIc_JanFebMar_01.nc
# 2026-02-12 02:42:55,111 INFO Request ID is 333977e8-0516-41cd-9fe0-e99d23e8cccb
# 2026-02-12 02:42:55,271 INFO status has been updated to accepted
# 2026-02-12 02:43:04,945 INFO status has been updated to running
# 2026-02-12 02:43:10,203 INFO status has been updated to successful
# fa9dd5e99c9d882beab7c6deefb6fbd3.nc:   0%|          | 0.00/514k [00:00<?, ?B/s]
# Downloaded: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc5_PRCP_DecIc_JanFebMar_01.nc
# Deleted not process file: Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc5_PRCP_DecIc_JanFebMar_01.nc
# Download finished, combined dataset for eccc 5 PRCP to Agro_PRESAGG_2026_ic_1/model_data/forecast_eccc5_PRCP_DecIc_JanFebMar_01.nc
# cfsv2_precip_fcst_Decic_1-3_2026-2026.txt: 753kB [00:01, 568kB/s]
# Download finished for cfsv2 1 precip to Agro_PRESAGG_2026_ic_1/model_data/forecast_cfsv21_PRCP_DecIc_JanFebMar_01.nc
# cmc1_precip_fcst_Decic_1-3_2026-2026.txt: 755kB [00:02, 257kB/s]
# Download finished for cmc1 1 precip to Agro_PRESAGG_2026_ic_1/model_data/forecast_cmc11_PRCP_DecIc_JanFebMar_01.nc
# cmc2_precip_fcst_Decic_1-3_2026-2026.txt: 754kB [00:01, 381kB/s]
# Download finished for cmc2 1 precip to Agro_PRESAGG_2026_ic_1/model_data/forecast_cmc21_PRCP_DecIc_JanFebMar_01.nc
# URL returned status code 404. Skipping download.
# failed to download gfdl_precip_fcst_Decic_1-3_2026-2026.txt
# nasa_precip_fcst_Decic_1-3_2026-2026.txt: 753kB [00:01, 476kB/s]
# Download finished for nasa 1 precip to Agro_PRESAGG_2026_ic_1/model_data/forecast_nasa1_PRCP_DecIc_JanFebMar_01.nc
# ncar_ccsm4_precip_fcst_Decic_1-3_2026-2026.txt: 740kB [00:02, 251kB/s]
# Download finished for ncar_ccsm4 1 precip to Agro_PRESAGG_2026_ic_1/model_data/forecast_ncarccsm41_PRCP_DecIc_JanFebMar_01.nc
# ncar_cesm1_precip_fcst_Decic_1-3_2026-2026.txt: 743kB [00:01, 440kB/s]
# Download finished for ncar_cesm1 1 precip to Agro_PRESAGG_2026_ic_1/model_data/forecast_ncarcesm11_PRCP_DecIc_JanFebMar_01.nc
# nmme_precip_fcst_Decic_1-3_2026-2026.txt: 748kB [00:02, 334kB/s]
# Download finished for nmme 1 precip to Agro_PRESAGG_2026_ic_1/model_data/forecast_nmme1_PRCP_DecIc_JanFebMar_01.nc

# %%
hindcast_files = {k: hindcast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
forecast_files = {k: forecast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
common_keys = {k.lower() for k in hindcast_files} & {k.lower() for k in forecast_files}
center_variable = [
    item
    for item in center_variable
    if any(item.lower().startswith(k) for k in list(common_keys))
                ]

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initialize the WAS_CCA class (default)

# %%
n_modes = 3
# define zone as dict : {'zone_name_key': ('Explicit_Zone_name', lon_min, lon_max, lat_min, lat_max)} 
defined_zone = {'A': ('A', -20, 30, -30, 30)}

# %%
plot_map([extent[1],extent[3],extent[2],extent[0]], sst_indices = defined_zone, title="Predictors Area",fig_size=(6,4))

# %% [markdown]
# ##### Modes of CCA for each model

# %%
was_cca = WAS_CCA_old(n_modes=n_modes, n_pca_modes=8, dist_method=dist_method)
was_cv = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
predictors = {}
for i in center_variable:
    predictors[i] = retrieve_single_zone_for_PCR(dir_to_save_model, defined_zone, i, year_start_model, year_end_model, clim_year_start=clim_year_start, clim_year_end=clim_year_end, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, standardize=True)
    predictor = predictors[i].isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(f"CCA Modes for model {i}")
    was_cca.plot_cca_results(X=predictor, Y=onset.sel(T=slice(str(year_start_model),str(year_end_model))) , clim_year_start=clim_year_start, clim_year_end=clim_year_end)

# %% [markdown]
# #### Cross validation

# %%
hindcast_det_dynam_all = {}
hindcast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                          predictor, clim_year_start, clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))).sel(T=slice(str(year_start_model),str(year_end_model))), predictor, clim_year_start, clim_year_end)

# %% [markdown]
# #### Verification (individual)

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "CCA-based"

# %%
cca_scores = {}
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_deterministic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_det_dynam_all[key]
        )
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_probabilistic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_prob_dynam_all[key],
            clim_year_start,
            clim_year_end)
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# #### Forecast (individual)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
forecast_det_dynam_all = {}
forecast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor_f = predictor.isel(T=[-1])
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f)
    model_name = f"CCA_{key.split('.')[0]}"    
    plot_prob_forecasts(f"{dir_to_forecast}",
                        forecast_prob_dynam_all[key].drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}", 
                        hspace=0.1, labels=fcst_labels, reverse_cmap=True)

# %% [markdown]
# ### Select best Statistico-Dynamical models

# %%
#### Select some models
best_models = get_best_models(center_variable, cca_scores, metric='GROC', threshold=0.6, top_n=4, gcm=False)
best_models

# %%
for key in best_models:
    hdcst_consolidated[f'{key}_snd.approach'] = hindcast_det_dynam_all[key]
    fcst_consolidated[f'{key}_snd.approach'] = forecast_det_dynam_all[key]
    hdcst_consolidated_prob[f'{key}_snd.approach'] = hindcast_prob_dynam_all[key]
    fcst_consolidated_prob[f'{key}_snd.approach'] = forecast_prob_dynam_all[key]
    
for metric, models in cca_scores.items():
    for model in list(models):                    # list() pour éviter RuntimeError
        if not any(model.startswith(p) for p in best_models):
            del models[model]

for key in cca_scores:
    scores_consolidated.setdefault(key, {}).update(cca_scores[key])

# %% [markdown]
# # 4th - Analog-based seasonal forecast

# %% [markdown]
# ## Analog bias_based

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = WAS_Analog(
    dir_to_save=f"{dir_s2s}/analog",
    year_start=1990,
    year_forecast=2025,          # target forecast year
    month_of_initialization=12,   # May initialisation
    predictor_vars=[{'reanalysis_name': 'NOAA', 'model_name': 'ECMWF_51', 'variable': 'SST', 'area': [40, -180, -35, 100]},
                    # {'reanalysis_name': 'ERA5', 'model_name': 'NCEP_2', 'variable': 'SLP', 'area': [80, -60, -80, 60]},
                    # {'reanalysis_name': 'ERA5', 'model_name': 'NCEP_2', 'variable': 'VGRD_850', 'area': [30, -45, -20, 15]}
                   ],
    method_analog="bias_based",
    standardize=True,
    rolling=3,
    lead_time=[1,2,3],
    clim_year_start=clim_year_start, 
    clim_year_end=clim_year_end,
    dist_method=dist_method
)

# %% [markdown]
# #### Cross-validation

# %%
was_analog_cv = WAS_Cross_Validator(n_splits=len(onset.get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_analog_det, hindcast_analog_prob = was_analog_cv.cross_validate(model, onset, clim_year_start=clim_year_start, clim_year_end=clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_analog_det, hindcast_analog_prob = was_analog_cv.cross_validate(model, onset, clim_year_start=clim_year_start, clim_year_end=clim_year_end)    
hdcst_consolidated['fourth.approach'] = hindcast_analog_det.sel(T=slice(str(year_start_model),str(year_end_model)))
hdcst_consolidated_prob['fourth.approach'] = hindcast_analog_prob.sel(T=slice(str(year_start_model),str(year_end_model)))
# Out:
# Cross-validation ongoing
#   0%|                                                    | 0/35 [00:00<?, ?it/s]
# Starting download for NOAA ERSST (v6) for 1990-2025
# Downloading ersst.v6.199001.nc...
# Downloading ersst.v6.199002.nc...
# Downloading ersst.v6.199003.nc...
# Downloading ersst.v6.199004.nc...
# Downloading ersst.v6.199005.nc...
# Downloading ersst.v6.199006.nc...
# Downloading ersst.v6.199007.nc...
# Downloading ersst.v6.199008.nc...
# Downloading ersst.v6.199009.nc...
# Downloading ersst.v6.199010.nc...
# Downloading ersst.v6.199011.nc...
# Downloading ersst.v6.199012.nc...
# Downloading ersst.v6.199101.nc...
# Downloading ersst.v6.199102.nc...
# Downloading ersst.v6.199103.nc...
# Downloading ersst.v6.199104.nc...
# Downloading ersst.v6.199105.nc...
# Downloading ersst.v6.199106.nc...
# Downloading ersst.v6.199107.nc...
# Downloading ersst.v6.199108.nc...
# Downloading ersst.v6.199109.nc...
# Downloading ersst.v6.199110.nc...
# Downloading ersst.v6.199111.nc...
# Downloading ersst.v6.199112.nc...
# Downloading ersst.v6.199201.nc...
# Downloading ersst.v6.199202.nc...
# Downloading ersst.v6.199203.nc...
# Downloading ersst.v6.199204.nc...
# Downloading ersst.v6.199205.nc...
# Downloading ersst.v6.199206.nc...
# Downloading ersst.v6.199207.nc...
# Downloading ersst.v6.199208.nc...
# Downloading ersst.v6.199209.nc...
# Downloading ersst.v6.199210.nc...
# Downloading ersst.v6.199211.nc...
# Downloading ersst.v6.199212.nc...
# Downloading ersst.v6.199301.nc...
# Downloading ersst.v6.199302.nc...
# Downloading ersst.v6.199303.nc...
# Downloading ersst.v6.199304.nc...
# Downloading ersst.v6.199305.nc...
# Downloading ersst.v6.199306.nc...
# Downloading ersst.v6.199307.nc...
# Downloading ersst.v6.199308.nc...
# Downloading ersst.v6.199309.nc...
# Downloading ersst.v6.199310.nc...
# Downloading ersst.v6.199311.nc...
# Downloading ersst.v6.199312.nc...
# Downloading ersst.v6.199401.nc...
# Downloading ersst.v6.199402.nc...
# Downloading ersst.v6.199403.nc...
# Downloading ersst.v6.199404.nc...
# Downloading ersst.v6.199405.nc...
# Downloading ersst.v6.199406.nc...
# Downloading ersst.v6.199407.nc...
# Downloading ersst.v6.199408.nc...
# Downloading ersst.v6.199409.nc...
# Downloading ersst.v6.199410.nc...
# Downloading ersst.v6.199411.nc...
# Downloading ersst.v6.199412.nc...
# Downloading ersst.v6.199501.nc...
# Downloading ersst.v6.199502.nc...
# Downloading ersst.v6.199503.nc...
# Downloading ersst.v6.199504.nc...
# Downloading ersst.v6.199505.nc...
# Downloading ersst.v6.199506.nc...
# Downloading ersst.v6.199507.nc...
# Downloading ersst.v6.199508.nc...
# Downloading ersst.v6.199509.nc...
# Downloading ersst.v6.199510.nc...
# Downloading ersst.v6.199511.nc...
# Downloading ersst.v6.199512.nc...
# Downloading ersst.v6.199601.nc...
# Downloading ersst.v6.199602.nc...
# Downloading ersst.v6.199603.nc...
# Downloading ersst.v6.199604.nc...
# Downloading ersst.v6.199605.nc...
# Downloading ersst.v6.199606.nc...
# Downloading ersst.v6.199607.nc...
# Downloading ersst.v6.199608.nc...
# Downloading ersst.v6.199609.nc...
# Downloading ersst.v6.199610.nc...
# Downloading ersst.v6.199611.nc...
# Downloading ersst.v6.199612.nc...
# Downloading ersst.v6.199701.nc...
# Downloading ersst.v6.199702.nc...
# Downloading ersst.v6.199703.nc...
# Downloading ersst.v6.199704.nc...
# Downloading ersst.v6.199705.nc...
# Downloading ersst.v6.199706.nc...
# Downloading ersst.v6.199707.nc...
# Downloading ersst.v6.199708.nc...
# Downloading ersst.v6.199709.nc...
# Downloading ersst.v6.199710.nc...
# Downloading ersst.v6.199711.nc...
# Downloading ersst.v6.199712.nc...
# Downloading ersst.v6.199801.nc...
# Downloading ersst.v6.199802.nc...
# Downloading ersst.v6.199803.nc...
# Downloading ersst.v6.199804.nc...
# Downloading ersst.v6.199805.nc...
# Downloading ersst.v6.199806.nc...
# Downloading ersst.v6.199807.nc...
# Downloading ersst.v6.199808.nc...
# Downloading ersst.v6.199809.nc...
# Downloading ersst.v6.199810.nc...
# Downloading ersst.v6.199811.nc...
# Downloading ersst.v6.199812.nc...
# Downloading ersst.v6.199901.nc...
# Downloading ersst.v6.199902.nc...
# Downloading ersst.v6.199903.nc...
# Downloading ersst.v6.199904.nc...
# Downloading ersst.v6.199905.nc...
# Downloading ersst.v6.199906.nc...
# Downloading ersst.v6.199907.nc...
# Downloading ersst.v6.199908.nc...
# Downloading ersst.v6.199909.nc...
# Downloading ersst.v6.199910.nc...
# Downloading ersst.v6.199911.nc...
# Downloading ersst.v6.199912.nc...
# Downloading ersst.v6.200001.nc...
# Downloading ersst.v6.200002.nc...
# Downloading ersst.v6.200003.nc...
# Downloading ersst.v6.200004.nc...
# Downloading ersst.v6.200005.nc...
# Downloading ersst.v6.200006.nc...
# Downloading ersst.v6.200007.nc...
# Downloading ersst.v6.200008.nc...
# Downloading ersst.v6.200009.nc...
# Downloading ersst.v6.200010.nc...
# Downloading ersst.v6.200011.nc...
# Downloading ersst.v6.200012.nc...
# Downloading ersst.v6.200101.nc...
# Downloading ersst.v6.200102.nc...
# Downloading ersst.v6.200103.nc...
# Downloading ersst.v6.200104.nc...
# Downloading ersst.v6.200105.nc...
# Downloading ersst.v6.200106.nc...
# Downloading ersst.v6.200107.nc...
# Downloading ersst.v6.200108.nc...
# Downloading ersst.v6.200109.nc...
# Downloading ersst.v6.200110.nc...
# Downloading ersst.v6.200111.nc...
# Downloading ersst.v6.200112.nc...
# Downloading ersst.v6.200201.nc...
# Downloading ersst.v6.200202.nc...
# Downloading ersst.v6.200203.nc...
# Downloading ersst.v6.200204.nc...
# Downloading ersst.v6.200205.nc...
# Downloading ersst.v6.200206.nc...
# Downloading ersst.v6.200207.nc...
# Downloading ersst.v6.200208.nc...
# Downloading ersst.v6.200209.nc...
# Downloading ersst.v6.200210.nc...
# Downloading ersst.v6.200211.nc...
# Downloading ersst.v6.200212.nc...
# Downloading ersst.v6.200301.nc...
# Downloading ersst.v6.200302.nc...
# Downloading ersst.v6.200303.nc...
# Downloading ersst.v6.200304.nc...
# Downloading ersst.v6.200305.nc...
# Downloading ersst.v6.200306.nc...
# Downloading ersst.v6.200307.nc...
# Downloading ersst.v6.200308.nc...
# Downloading ersst.v6.200309.nc...
# Downloading ersst.v6.200310.nc...
# Downloading ersst.v6.200311.nc...
# Downloading ersst.v6.200312.nc...
# Downloading ersst.v6.200401.nc...
# Downloading ersst.v6.200402.nc...
# Downloading ersst.v6.200403.nc...
# Downloading ersst.v6.200404.nc...
# Downloading ersst.v6.200405.nc...
# Downloading ersst.v6.200406.nc...
# Downloading ersst.v6.200407.nc...
# Downloading ersst.v6.200408.nc...
# Downloading ersst.v6.200409.nc...
# Downloading ersst.v6.200410.nc...
# Downloading ersst.v6.200411.nc...
# Downloading ersst.v6.200412.nc...
# Downloading ersst.v6.200501.nc...
# Downloading ersst.v6.200502.nc...
# Downloading ersst.v6.200503.nc...
# Downloading ersst.v6.200504.nc...
# Downloading ersst.v6.200505.nc...
# Downloading ersst.v6.200506.nc...
# Downloading ersst.v6.200507.nc...
# Downloading ersst.v6.200508.nc...
# Downloading ersst.v6.200509.nc...
# Downloading ersst.v6.200510.nc...
# Downloading ersst.v6.200511.nc...
# Downloading ersst.v6.200512.nc...
# Downloading ersst.v6.200601.nc...
# Downloading ersst.v6.200602.nc...
# Downloading ersst.v6.200603.nc...
# Downloading ersst.v6.200604.nc...
# Downloading ersst.v6.200605.nc...
# Downloading ersst.v6.200606.nc...
# Downloading ersst.v6.200607.nc...
# Downloading ersst.v6.200608.nc...
# Downloading ersst.v6.200609.nc...
# Downloading ersst.v6.200610.nc...
# Downloading ersst.v6.200611.nc...
# Downloading ersst.v6.200612.nc...
# Downloading ersst.v6.200701.nc...
# Downloading ersst.v6.200702.nc...
# Downloading ersst.v6.200703.nc...
# Downloading ersst.v6.200704.nc...
# Downloading ersst.v6.200705.nc...
# Downloading ersst.v6.200706.nc...
# Downloading ersst.v6.200707.nc...
# Downloading ersst.v6.200708.nc...
# Downloading ersst.v6.200709.nc...
# Downloading ersst.v6.200710.nc...
# Downloading ersst.v6.200711.nc...
# Downloading ersst.v6.200712.nc...
# Downloading ersst.v6.200801.nc...
# Downloading ersst.v6.200802.nc...
# Downloading ersst.v6.200803.nc...
# Failed to download or process NOAA/SST: HTTPSConnectionPool(host='www.ncei.noaa.gov', port=443): Read timed out.
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/urllib3/response.py", line 748, in _error_catcher
#     yield
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/urllib3/response.py", line 873, in _raw_read
#     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/urllib3/response.py", line 856, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/http/client.py", line 479, in read
#     s = self.fp.read(amt)
#         ^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/socket.py", line 720, in readinto
#     return self._sock.recv_into(b)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/ssl.py", line 1252, in recv_into
#     return self.read(nbytes, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/ssl.py", line 1104, in read
#     return self._sslobj.read(len, buffer)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/requests/models.py", line 820, in generate
#     yield from self.raw.stream(chunk_size, decode_content=True)
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/urllib3/response.py", line 1060, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/urllib3/response.py", line 949, in read
#     data = self._raw_read(amt)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/urllib3/response.py", line 872, in _raw_read
#     with self._error_catcher():
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/contextlib.py", line 158, in __exit__
#     self.gen.throw(value)
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/urllib3/response.py", line 753, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='www.ncei.noaa.gov', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/user/Documents/AICCRA_AGRHYMET_2024/My_ML_training/WAS_S2S_/WASS2S/wass2s/was_analog.py", line 708, in download_reanalysis
#     r = requests.get(url, timeout=30)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/requests/sessions.py", line 746, in send
#     r.content
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/requests/models.py", line 902, in content
#     self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/miniconda3/envs/WASS2S/lib/python3.12/site-packages/requests/models.py", line 826, in generate
#     raise ConnectionError(e)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='www.ncei.noaa.gov', port=443): Read timed out.
# Recovering from connection error [HTTPSConnectionPool(host='cds.climate.copernicus.eu', port=443): Max retries exceeded with url: /api/catalogue/v1/messages (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7326a1536180>: Failed to resolve 'cds.climate.copernicus.eu' ([Errno -3] Temporary failure in name resolution)"))], attempt 1 of 500
# Retrying in 120 seconds
# 2026-02-12 02:54:52,377 INFO Request ID is 97345da5-0970-41c9-90f4-a9f88abb8857
# 2026-02-12 02:54:52,577 INFO status has been updated to accepted
# 2026-02-12 02:55:14,792 INFO status has been updated to running
# 2026-02-12 02:55:26,376 INFO status has been updated to successful
# 4a1dc1a2a24052fe626302e41cf90488.nc:   0%|          | 0.00/6.68M [00:00<?, ?B/s]
# Downloaded forecast: Agro_PRESAGG_2026_ic_1/analog/forecast_ecmwf51_SST_2025_DecIc_JanFebMar_1_40-180-35100.nc
# Saved processed hindcast to Agro_PRESAGG_2026_ic_1/analog/forecast_ecmwf51_SST_2025_DecIc_JanFebMar_1_40-180-35100.nc
# 2026-02-12 02:55:36,892 INFO Request ID is 2d9c8886-14d0-4c6a-8175-3b4c491ce572
# 2026-02-12 02:55:37,101 INFO status has been updated to accepted
# 2026-02-12 02:55:51,531 INFO status has been updated to successful
# dc2dc5abef06d8a8ab3332689070dff8.nc:   0%|          | 0.00/55.0M [00:00<?, ?B/s]
# Downloaded hindcast: Agro_PRESAGG_2026_ic_1/analog/hindcast_ecmwf51_SST_1994_2016DecIc_JanFebMar_1_40-180-35100.nc
#   0%|                                                    | 0/35 [14:09<?, ?it/s]
# Saved processed hindcast to Agro_PRESAGG_2026_ic_1/analog/hindcast_ecmwf51_SST_1994_2016DecIc_JanFebMar_1_40-180-35100.nc
# Processing variables: ['SST']
# Skipping SST: data not available.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[95], line 2
#       1 if dist_method=="bestfit":
# ----> 2     hindcast_analog_det, hindcast_analog_prob = was_analog_cv.cross_validate(model, onset, clim_year_start=clim_year_start, clim_year_end=clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
#       3 else:
#       4     hindcast_analog_det, hindcast_analog_prob = was_analog_cv.cross_validate(model, onset, clim_year_start=clim_year_start, clim_year_end=clim_year_end)
#
# File ~/Documents/AICCRA_AGRHYMET_2024/My_ML_training/WAS_S2S_/WASS2S/wass2s/was_cross_validate.py:304, in WAS_Cross_Validator.cross_validate(self, model, Predictant, Predictor, clim_year_start, clim_year_end, **model_params)
#     302 print("Cross-validation ongoing")
#     303 for i, (train_index, test_index) in enumerate(tqdm(self.custom_cv.split(np.unique(Predictant['T'].dt.year), self.nb_omit), total=n_splits), start=1):
# --> 304     pred_det = model.compute_model(Predictant, train_index, test_index)
#     305     hindcast_det.append(pred_det)
#     307 hindcast_det = xr.concat(hindcast_det, dim="T")
#
# File ~/Documents/AICCRA_AGRHYMET_2024/My_ML_training/WAS_S2S_/WASS2S/wass2s/was_analog.py:1784, in WAS_Analog.compute_model(self, predictant, itrain, itest)
#    1781 if self.method_analog not in method_map:
#    1782     raise ValueError(f"Invalid analog method: {self.method_analog}. Choose 'som', 'bias_based', 'cor_based', 'pca_based', 'kmeans_based', or 'agglomerative_based'.")
# -> 1784 similar_years = method_map[self.method_analog](predictant, itrain, itest)
#    1785 predictant = predictant.copy()
#    1786 predictant['T'] = predictant['T'].astype('datetime64[ns]')
#
# File ~/Documents/AICCRA_AGRHYMET_2024/My_ML_training/WAS_S2S_/WASS2S/wass2s/was_analog.py:1300, in WAS_Analog.Bias_Based(self, predictant, itrain, ireference_year)
#    1298 ddd = ddd.get(self.predictor_vars[0]['variable'])
#    1299 if ddd is None:
# -> 1300     raise ValueError(f"Variable {self.predictor_vars[0]['variable']} not found in downloaded data.")
#    1302 predictant = predictant.copy()
#    1303 predictant['T'] = predictant['T'].astype('datetime64[ns]')
#
# ValueError: Variable SST not found in downloaded data.

# %% [markdown]
# #### Verification

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "Analogue-Based Forecasting"

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset,
        hindcast_analog_det
    )
    scores_consolidated[i] = {'fourth.approach': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset,
        hindcast_analog_prob,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'fourth.approach': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# #### Forecast

# %%
## Analysis SST evolution
model.composite_plot(onset, clim_year_start, clim_year_end, 
                     hindcast_analog_det, plot_predictor=True,
                    variable="SST", best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)

# %%
## Plot silimar years behavior
model.composite_plot(onset, clim_year_start, clim_year_end, hindcast_analog_det, plot_predictor=False, best_code_da=best_code_da,
                     best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)

# %%
if dist_method=="bestfit":
    similar_years, forecast_det_analog, forecast_prob_analog = model.forecast(onset, clim_year_start, clim_year_end, hindcast_analog_det, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    similar_years, forecast_det_analog, forecast_prob_analog = model.forecast(onset, clim_year_start, clim_year_end, hindcast_analog_det)    
fcst_consolidated['fourth.approach'] = forecast_det_analog
fcst_consolidated_prob['fourth.approach'] = forecast_prob_analog
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_analog.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels,
                    reverse_cmap=True)

# %% [markdown]
# # Consolidated Forecasts

# %%
best_models = list(hdcst_consolidated.keys())
best_models

# %% [markdown]
# #### Cross-validation

# %%
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))),hdcsted=hdcst_consolidated, fcsted=fcst_consolidated, gcm=False, ELM_ELR=False,  Prob=False, best_models=best_models, scores=scores_consolidated, model=False, score_metric="GROC")

# %%
was_mme = WAS_mme_Weighted(equal_weighted=True, dist_method=dist_method, metric="GROC", threshold=0.6)

# %%
hindcast_det, forecast_det  = was_mme.compute(obs, all_model_hdcst, all_model_fcst.isel(T=[1]), best_score, complete=True)
hindcast_prob = was_mme.compute_prob(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, hindcast_det, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)

# %% [markdown]
# #### Verification

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "Consolidated Forecast"

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det
    )
    
    r.to_dataset(name="Equaly weigthed")
    r.to_netcdf(f"{dir_s2s}/equaly_{i}.nc")
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob,
        clim_year_start,
        clim_year_end)
    r.to_dataset(name="Equaly weigthed")
    r.to_netcdf(f"{dir_s2s}/equaly_{i}.nc")
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ### Forecast

# %%
_,forecast_prob = was_mme.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, hindcast_det, forecast_det,best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
plot_prob_forecasts(dir_to_forecast, forecast_prob.drop_vars('T').squeeze(),
                    f"{model_name} {season_str}-{forecast}" ,#issued {datetime.datetime.today().strftime("%Y-%m-%d")}", 
                    reverse_cmap=True,  hspace=0.1, labels=fcst_labels, logo=logopath, logo_size=0.1)
gc.collect()

# %%
plot_det_forecasts(forecast_det.drop_vars('T').squeeze(),
                    f"{model_name} Deterministic {season_str}-{forecast}", f"{dir_to_forecast}/{model_name} {season_str}-{forecast}.png")
gc.collect()

# %%
forecast_det.to_netcdf(f'{dir_to_forecast}/Forecast_Det_PRCP{season_str}_{forecast}.nc')

# %%
forecast_prob.to_netcdf(f'{dir_to_forecast}/Forecast_Prob_PRCP{season_str}_{forecast}.nc')
