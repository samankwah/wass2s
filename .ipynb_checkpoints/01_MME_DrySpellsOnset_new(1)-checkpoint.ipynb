# %% [markdown]
# ##### <p style="text-align: center;"> ![alt text](./utilities/cilss.png)</p>
# # <p style="text-align: center;">AGHRYMET RCC-WAS</p>
# #### &copy; Mandela HOUNGNIBO 2024 (Find more [here](https://github.com/hmandela/WASS2S))

# %% [markdown]
# ## Library

# %%
from wass2s import *
import datetime
import importlib
from pathlib import Path
import warnings
import gc
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Set forecast working directory

# %%
# Set forecast working directory
dir_s2s = "./Agro_PRESAGG_2026_ic_1"
logopath = './utilities/cilss.png'#'./utilities/agrhymet_logo_combined_reversed.png'
fcst_labels = ["Short", "Near-Normal", "Long"]
dist_method="bestfit" # nonparam or bestfit

# %%
dir_s2s = Path(dir_s2s)
os.makedirs(dir_s2s, exist_ok=True)
### Save consolidated results
hdcst_consolidated = {}
hdcst_consolidated_prob = {}
fcst_consolidated = {}
fcst_consolidated_prob = {}
scores_consolidated = {}
### Save score
dir_save_score = f"{dir_s2s}/scores"
os.makedirs(dir_save_score, exist_ok=True)
### Save forecasts
dir_to_forecast = f"{dir_s2s}/forecasts"
os.makedirs(dir_to_forecast, exist_ok=True)

# %% [markdown]
# #### Set Climatological Years

# %%
# Set Climatological Years
clim_year_start = 1994 #1991
clim_year_end = 2016 #2020

# %% [markdown]
# ## Download Observation and Process

# %% [markdown]
# #### Load Downloader

# %%
# Load WAS_S2S downloader class
downloader = WAS_Download()

# %%
# Filter observation names to identify precipitation-related models
variables_obs = [key for key in downloader.AgroObsName().keys() if "PRCP" in key]

# Specify the directory to save downloaded model data
dir_to_save_Obs = f"{dir_s2s}/Observation"

# Define the observation period (years 1993 to 2016)
year_start = 1991
year_end = 2025

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent_obs = [8.5, -3.5, 4, 1.5]   # [Northern, Western, Southern and Eastern] 

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
plot_map([extent_obs[1],extent_obs[3],extent_obs[2],extent_obs[0]], title="Data Download Area", fig_size=(4,3))

# %%
downloader.WAS_Download_AgroIndicators_daily(dir_to_save_Obs, variables_obs, year_start, year_end, extent_obs, force_download=force_download)
downloader.WAS_Download_AgroIndicators_daily(dir_to_save_Obs, variables_obs, datetime.datetime.now().year, datetime.datetime.now().year, extent_obs, force_download=force_download)
# Out:
# Agro_PRESAGG_2026_ic_1\Observation\Daily_PRCP_1991_2025.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\Observation\Daily_PRCP_2026_2026.nc already exists. Skipping download.

# %%
#### Process predictant
rainfall = prepare_predictand(dir_to_save_Obs, variables_obs, year_start, year_end, daily=True, ds=False)
rainfall_for_forecast_year = prepare_predictand(dir_to_save_Obs, variables_obs, datetime.datetime.now().year, datetime.datetime.now().year, daily=True, ds=False)
season_str = agrometparam = "dryspellonset"
season_obs = [datetime.datetime.now().month+1]

# %% [markdown]
# ## Compute DrySpellOnset

# %%
### Choose number of cores according your computer
nb_cores = 2

# %%
## dryspellonset criteria
user_criteria = onset_dryspell_criteria
user_criteria
# Out:
# {0: {'zone_name': 'Sahel100_0mm',
#   'start_search': '06-01',
#   'cumulative': 15,
#   'number_dry_days': 25,
#   'thrd_rain_day': 0.85,
#   'end_search': '09-01',
#   'nbjour': 30},
#  1: {'zone_name': 'Sahel200_100mm',
#   'start_search': '05-15',
#   'cumulative': 15,
#   'number_dry_days': 25,
#   'thrd_rain_day': 0.85,
#   'end_search': '08-15',
#   'nbjour': 40},
#  2: {'zone_name': 'Sahel400_200mm',
#   'start_search': '05-01',
#   'cumulative': 15,
#   'number_dry_days': 20,
#   'thrd_rain_day': 0.85,
#   'end_search': '07-31',
#   'nbjour': 40},
#  3: {'zone_name': 'Sahel600_400mm',
#   'start_search': '03-15',
#   'cumulative': 20,
#   'number_dry_days': 20,
#   'thrd_rain_day': 0.85,
#   'end_search': '07-31',
#   'nbjour': 45},
#  4: {'zone_name': 'Soudan',
#   'start_search': '03-15',
#   'cumulative': 20,
#   'number_dry_days': 10,
#   'thrd_rain_day': 0.85,
#   'end_search': '07-31',
#   'nbjour': 50},
#  5: {'zone_name': 'Golfe_Of_Guinea',
#   'start_search': '02-01',
#   'cumulative': 20,
#   'number_dry_days': 10,
#   'thrd_rain_day': 0.85,
#   'end_search': '06-15',
#   'nbjour': 50}}

# %%
user_criteria[4]["thrd_rain_day"] = 0.85
user_criteria[5]["thrd_rain_day"] = 0.85

# %% [markdown]
# ##### Compute dryspellonset for gridded products

# %%
# load dryspellonset class
was_dryspellonset = WAS_compute_onset_dry_spell(user_criteria)
dryspellonset = was_dryspellonset.compute(daily_data=rainfall, nb_cores=nb_cores)
# Out:
# 2026-02-12 13:48:29,719 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2026-02-12 13:48:29,721 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing

# %%
dryspellonset.mean(dim='T').plot()

# %% [markdown]
# #### Process dryspellonset in combining with Ground-Observation

# %%
## Path to the CPT file
cpt_input_file_path = "./1st_Dry_Spell_2025.csv"

# %%
# Read CSV
df = pd.read_csv(cpt_input_file_path, na_values=-999.0, encoding="latin1")
dryspellonset_df = df[(df['STATION'] == 'LAT') | (df['STATION'] == 'LON') | 
                 (pd.to_numeric(df['STATION'], errors='coerce').between(year_start, year_end))]
verify_station_network(dryspellonset_df, extent_obs)

# %%
# Instantiate WAS_Merging class
data_merger = WAS_Merging(dryspellonset_df, dryspellonset, date_month_day= '02-01')
dryspellonset__, _ = data_merger.simple_bias_adjustment(do_cross_validation=False)
# Out:
# Year = 1991-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 1992-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 1993-02-01T00:00:00.000000000, number in-situ = 32
#
# Year = 1994-02-01T00:00:00.000000000, number in-situ = 31
#
# Year = 1995-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 1996-02-01T00:00:00.000000000, number in-situ = 33
#
# Year = 1997-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 1998-02-01T00:00:00.000000000, number in-situ = 32
#
# Year = 1999-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 2000-02-01T00:00:00.000000000, number in-situ = 32
#
# Year = 2001-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 2002-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 2003-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 2004-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 2005-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 2006-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 2007-02-01T00:00:00.000000000, number in-situ = 34
#
# Year = 2008-02-01T00:00:00.000000000, number in-situ = 31
#
# Year = 2009-02-01T00:00:00.000000000, number in-situ = 33
#
# Year = 2010-02-01T00:00:00.000000000, number in-situ = 32
#
# Year = 2011-02-01T00:00:00.000000000, number in-situ = 33
#
# Year = 2012-02-01T00:00:00.000000000, number in-situ = 30
#
# Year = 2013-02-01T00:00:00.000000000, number in-situ = 31
#
# Year = 2014-02-01T00:00:00.000000000, number in-situ = 33
#
# Year = 2015-02-01T00:00:00.000000000, number in-situ = 31
#
# Year = 2016-02-01T00:00:00.000000000, number in-situ = 29
#
# Year = 2017-02-01T00:00:00.000000000, number in-situ = 29
#
# Year = 2018-02-01T00:00:00.000000000, number in-situ = 32
#
# Year = 2019-02-01T00:00:00.000000000, number in-situ = 29
#
# Year = 2020-02-01T00:00:00.000000000, number in-situ = 33
#
# Year = 2021-02-01T00:00:00.000000000, number in-situ = 32
#
# Year = 2022-02-01T00:00:00.000000000, number in-situ = 33
#
# Year = 2023-02-01T00:00:00.000000000, number in-situ = 31
#
# Year = 2024-02-01T00:00:00.000000000, number in-situ = 30
#
# Year = 2025-02-01T00:00:00.000000000, number in-situ = 31

# %%
data_merger.plot_merging_comparaison(dryspellonset_df, dryspellonset , dryspellonset__)

# %%
dryspellonset = dryspellonset__

# %% [markdown]
# #### Identify the parametric distribution that best fits the observations

# %%
if dist_method=="nonparam":
    pass
else:
    transf = WAS_TransformData(rainfall.sel(T=slice(str(clim_year_start),str(clim_year_end))), 
                      distribution_map={'norm': 1, 'lognorm': 2, 'gamma': 4,}, #'norm': 1, 'lognorm': 2, 'expon': 3, 'gamma': 4, 'weibull_min': 5, 't_dist': 6, "poisson":7, "nbinom":8 
                                n_clusters=1000)
    best_code_da, best_shape_da, best_loc_da, best_scale_da, _ = transf.fit_best_distribution(mode="grid")

# %%
if dist_method=="bestfit":
    transf.plot_best_fit_map(best_code_da,
                             {'norm': 1, 'lognorm': 2, 'expon': 3, 'gamma': 4,
                              'weibull_min': 5, 't_dist': 6, "poisson":7, "nbinom":8},
                             show_plot=True)

# %% [markdown]
# # 1st - Approach: Choice of Best Dynamical models and weighted Average

# %%
# Filter model names to identify precipitation-related models
center_variable = ['NCEP_2.PRCP', 'BOM_2.PRCP', 'ECMWF_51.PRCP', 'METEOFRANCE_9.PRCP', 'UKMO_604.PRCP', 'DWD_22.PRCP']
#center_variable = [key for key in downloader.ModelsName().keys() if "PRCP" in key]

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/daily_model_data"

# Define the month for model initialization (June)
month_of_initialization = "01"
day_of_initialization ="01"

# Define lead times corresponding to seasonal forecast targets
leadtime_hour = [str(i) for i in range(24, 5161, 24)] 

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent_obs = [8.5, -3.5, 4, 1.5]  # [Northern, Western, Southern and Eastern] 

# Define if you want to download forecast or hindcast
forecast = None
ensemble_mean = 'mean',
# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
file_path_hdcst = downloader.WAS_Download_Models_Daily(dir_to_save_model,center_variable,month_of_initialization, day_of_initialization, leadtime_hour, year_start_model, year_end_model, extent_obs, forecast, ensemble_mean, force_download,)
# Out:
# Agro_PRESAGG_2026_ic_1\daily_model_data\hindcast_ncep2_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\hindcast_bom2_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\hindcast_ecmwf51_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\hindcast_meteo_france9_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\hindcast_ukmo604_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\hindcast_dwd22_PRCP_Jan01_1993_2016_24-5160.nc already exists. Skipping download.

# %%
forecast = 2026

# %%
file_path_fcst = downloader.WAS_Download_Models_Daily(dir_to_save_model,center_variable,month_of_initialization, day_of_initialization, leadtime_hour, year_start_model, year_end_model, extent_obs, forecast, ensemble_mean, force_download,)
# Out:
# Agro_PRESAGG_2026_ic_1\daily_model_data\forecast_ncep2_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\forecast_bom2_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\forecast_ecmwf51_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\forecast_meteo_france9_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\forecast_ukmo604_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\daily_model_data\forecast_dwd22_PRCP_Jan01_2026_24-5160.nc already exists. Skipping download.

# %% [markdown]
# #### Models bias correction

# %%
hindcast_files, forecast_files = pre_process_biophysical_model(dir_s2s, file_path_hdcst, 
file_path_fcst, rainfall, rainfall_for_forecast_year, month_of_initialization,
 year_start_model, year_end_model, forecast, param="PRCP")
# Out:
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_ncep2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_bom2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_ecmwf51_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_meteo_france9_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_ukmo604_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_dwd22_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_ncep2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_bom2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_ecmwf51_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_meteo_france9_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_ukmo604_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_dwd22_PRCP_JanIc.nc already exists.

# %%
hindcast_files_cor, forecast_files_cor = proceed_seasonal_daily_bias_correction(dir_to_save_model, 
                                                                                rainfall.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                hindcast_files, 
                                                                                forecast_files, 
                                                                                varname="PRCP", wet_day=0.1)
# Out:
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_ncep2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_ncep2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_bom2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_bom2_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_ecmwf51_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_ecmwf51_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_meteo_france9_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_meteo_france9_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_ukmo604_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_ukmo604_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/hindcast_dwd22_PRCP_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1/daily_model_data/corrected/forecast_dwd22_PRCP_JanIc.nc already exists.

# %% [markdown]
# ## Verify Bias Correction

# %%
import xskillscore as xs
for i in hindcast_files_cor.keys():
    hcst_cor = xr.open_dataset(hindcast_files_cor[i])["corrected"]
    hcst = xr.open_dataset(hindcast_files[i])["PRCP"]
    observation = rainfall.interp(Y=hcst.Y, X=hcst.X, method="linear", kwargs={"fill_value": "extrapolate"})
    dry_wet, extrem = qmap.evaluate_bias_correction(observation,
                                              hcst,
                                              hcst_cor,
                                              wet_threshold=0.1,
                                              extreme_quantiles=[0.95, 0.99])
    print(i)
    mae = xr.concat([xs.mae(observation.sel(T=slice("1993","2016")), hcst, dim="T"),
              xs.mae(observation.sel(T=slice("1993","2016")), hcst_cor, dim="T")],
              dim="mae")
    mae = mae.assign_coords(mae=["model", "model corrigé"])
    mae.plot(col="mae")
    qmap.plot_fraction_group(dry_wet, "dry_fraction_", extent=extent_obs)
    qmap.plot_fraction_group(dry_wet, "wet_fraction_", extent=extent_obs)
    qmap.plot_mean_wet_group(dry_wet, extent=extent_obs)
    qmap.plot_extreme_quantiles_group(extrem, extent=extent_obs)
# Out:
# ncep2
# bom2
# ecmwf51
# meteo_france9
# ukmo604
# dwd22

# %% [markdown]
# #### Compute dryspellonset for models

# %%
hindcast_files, forecast_files = process_model_for_other_params(was_dryspellonset, dir_s2s, hindcast_files_cor, forecast_files_cor, rainfall, 
rainfall_for_forecast_year, month_of_initialization, year_start_model, year_end_model, forecast, nb_cores=4, agrometparam=agrometparam)
# Out:
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_ncep2_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_bom2_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_ecmwf51_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_meteo_france9_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_ukmo604_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/hindcast_dwd22_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_ncep2_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_bom2_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_ecmwf51_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_meteo_france9_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_ukmo604_dryspellonset_JanIc.nc already exists.
# [SKIP] Agro_PRESAGG_2026_ic_1\model_data/forecast_dwd22_dryspellonset_JanIc.nc already exists.

# %%
was_verify = WAS_Verification(dist_method=dist_method,mae_rmse_crps_thrsd=50)

# %% [markdown]
# #### Validation of GCM

# %%
score = ["Pearson", "MAE"]

# %%
os.makedirs(dir_save_score, exist_ok=True)
scores = {}
for i in score:
    scores[i] = was_verify.gcm_validation_compute(hindcast_files, dryspellonset, i, month_of_initialization, clim_year_start, clim_year_end, dir_save_score, lead_time = None, ensemble_mean=None, gridded=True)
    print(was_verify.scores[i][0])
    was_verify.plot_models_score(scores[i], i, dir_save_score)
# Out:
# Pearson Correlation
# Mean Absolute Error

# %% [markdown]
# ## Choice of best GCM models

# %%
best_models = get_best_models(center_variable, scores, metric='MAE', threshold=10, top_n=5, agroparam=True, gcm=False)
best_models
# Out:
# ['NCEP_2.PRCP',
#  'BOM_2.PRCP',
#  'ECMWF_51.PRCP',
#  'METEOFRANCE_9.PRCP',
#  'UKMO_604.PRCP']

# %% [markdown]
# ### MLP

# %%
# from scipy.stats import loguniform
model = WAS_mme_MLP(
    hidden_layer_sizes_range=[
         (2,2), (3,2), (2,4), (4,2),
         (5,2), (5,5), (5,5,5),
         (8,4), (16,8), (16,8,4),
        # (15,10,5,2),
        # (30,), (50,),              # Moderate baseline
        # (60, 30), (100, 50),       # Compression funnels
        # (30, 15, 5)                # Deep funnel for complex non-linearities
    ],
    learning_rate_init_range=loguniform(1e-4, 1e-1),
    activation_options=['tanh'],# 'identity'],        
    solver_options=['adam','sgd'],#, 'lbfgs'],  # sgd, lbfgs         
    alpha_range=loguniform(1e-5, 1e-1),   
    search_method='bayesian',                              
    random_state=42,
    n_iter_search=25,  
    max_iter=2000,
    cv_folds=5,
    n_clusters=1,
    dist_method=dist_method,
    optuna_n_jobs=-1,
    optuna_timeout=600
)

# %% [markdown]
# #### Cross-validation

# %%
# all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), gcm=True, ELM_ELR=True, dir_to_save_model=dir_to_save_model, best_models=best_models, scores=scores, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), hdcsted=hindcast_files, fcsted=forecast_files, scores= scores, score_metric='MAE', gcm=False, agroparam=True, ELM_ELR=False, best_models=best_models, dir_to_save_model=dir_to_save_model, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, year_forecast=forecast)

# %%
best_params, cluster = model.compute_hyperparameters(all_model_hdcst, obs, clim_year_start, clim_year_end)
# Out:
# [I 2026-02-12 13:53:45,022] A new study created in memory with name: no-name-75dd2055-06b8-4233-80fa-0e8fa22455de
# [I 2026-02-12 13:54:19,644] Trial 1 finished with value: -1.0392813205289801 and parameters: {'hidden_layer_sizes': (2, 4), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.04416035213482201, 'alpha': 0.00015037087640883977}. Best is trial 1 with value: -1.0392813205289801.
# [I 2026-02-12 13:54:28,017] Trial 0 finished with value: -1.0363472072208484 and parameters: {'hidden_layer_sizes': (5, 5), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0002866632274020501, 'alpha': 0.0006516160673345101}. Best is trial 0 with value: -1.0363472072208484.
# [I 2026-02-12 13:54:28,855] Trial 2 finished with value: -1.0572755670831273 and parameters: {'hidden_layer_sizes': (4, 2), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.00019881105569811487, 'alpha': 2.754051467971763e-05}. Best is trial 0 with value: -1.0363472072208484.
# [I 2026-02-12 13:54:30,151] Trial 3 finished with value: -1.0661494029436462 and parameters: {'hidden_layer_sizes': (8, 4), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.013287028134050008, 'alpha': 0.00042911604731993134}. Best is trial 0 with value: -1.0363472072208484.
# [I 2026-02-12 13:54:31,842] Trial 4 finished with value: -1.0617860855162995 and parameters: {'hidden_layer_sizes': (3, 2), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.09942653234047688, 'alpha': 0.012365196507872602}. Best is trial 0 with value: -1.0363472072208484.
# [I 2026-02-12 13:54:58,289] Trial 6 finished with value: -1.0328162811909143 and parameters: {'hidden_layer_sizes': (5, 5, 5), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0001940601355869673, 'alpha': 0.0004088594600262271}. Best is trial 6 with value: -1.0328162811909143.
# [I 2026-02-12 13:55:03,446] Trial 5 finished with value: -1.06525052189595 and parameters: {'hidden_layer_sizes': (16, 8), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.007914165025474755, 'alpha': 1.8540541731264643e-05}. Best is trial 6 with value: -1.0328162811909143.
# [I 2026-02-12 13:55:12,820] Trial 7 finished with value: -1.053905061385797 and parameters: {'hidden_layer_sizes': (5, 2), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0009173736640899873, 'alpha': 0.00023907857716799023}. Best is trial 6 with value: -1.0328162811909143.
# [I 2026-02-12 13:55:32,536] Trial 8 finished with value: -1.0489236701079996 and parameters: {'hidden_layer_sizes': (4, 2), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0024385428725936164, 'alpha': 5.922803447351853e-05}. Best is trial 6 with value: -1.0328162811909143.
# [I 2026-02-12 13:55:39,914] Trial 9 finished with value: -1.068181818750841 and parameters: {'hidden_layer_sizes': (5, 2), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0012267563547901541, 'alpha': 0.0003202761922397013}. Best is trial 6 with value: -1.0328162811909143.
# [I 2026-02-12 13:55:51,219] Trial 10 finished with value: -1.048476907129864 and parameters: {'hidden_layer_sizes': (8, 4), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [01:06<00:00,  2.79s/it]

# %%
was_verify = WAS_Verification(dist_method=dist_method, mae_rmse_crps_thrsd=250)

# %% [markdown]
# #### Verification

# %%
score = ['Pearson', 'MAE']
model_name = "MLP" #"Extreme Learning Machine" # Extreme Learning Machine "MultiLayer Perceptron" XGBoost Random Forest

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det_gcm
    )
    scores_consolidated[i] = {'SV-ML-CMME_MLP': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ##### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob_gcm,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'SV-ML-CMME_MLP': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)
# Out:
# Generalized Discrimination Score
# Ranked Probability Skill Score

# %% [markdown]
# #### Forecast

# %%
if dist_method=="bestfit":
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, all_model_fcst, best_params=best_params, cluster_da=cluster, 
                                                        best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, 
                                                        all_model_fcst, best_params=best_params, cluster_da=cluster
                                                       )
    
fcst_consolidated['SV-ML-CMME_MLP'] = forecast_det_gcm
fcst_consolidated_prob['SV-ML-CMME_MLP'] = forecast_prob_gcm
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_gcm.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels, reverse_cmap=True)
gc.collect()
# Out:
# 10309

# %% [markdown]
# ### Extreme Learning

# %%
model = WAS_mme_hpELM(neurons_range=[5, 10, 25, 50, 100, 200],   # 400, 600, 800, 1000, 1500    
                        activation_options=['sigm', 'tanh', 'lin'],# lin, 'rbf_l1', 'rbf_l2' 'rbf_linf'],
                        norm_range=loguniform(1e-2, 1e2),            
                        random_state=42,
                        n_iter_search=200,                             
                        cv_folds=5,
                        dist_method=dist_method,
                        search_method='bayesian',
                        n_clusters=1,
                        n_trials_bayesian=100,
                        bayesian_sampler='tpe', #random or tpe
                        )

# %% [markdown]
# #### Cross-validation

# %%
# all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), gcm=True, ELM_ELR=True, dir_to_save_model=dir_to_save_model, best_models=best_models, scores=scores, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), hdcsted=hindcast_files, fcsted=forecast_files, scores= scores, score_metric='MAE', gcm=False, agroparam=True, ELM_ELR=False, best_models=best_models, dir_to_save_model=dir_to_save_model, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, year_forecast=forecast)

# %%
best_params, cluster = model.compute_hyperparameters(all_model_hdcst, obs, clim_year_start, clim_year_end)
# Out:
# [I 2026-02-12 14:00:02,283] A new study created in memory with name: cluster_0.0
# [I 2026-02-12 14:00:02,949] Trial 3 finished with value: -1.038309316840877 and parameters: {'neurons': 5, 'activation': 'sigm', 'norm': 4.282247258079212}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:03,002] Trial 0 finished with value: -1.0436278584195522 and parameters: {'neurons': 10, 'activation': 'tanh', 'norm': 0.10347731351702637}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:03,194] Trial 4 finished with value: -1.0387093768007412 and parameters: {'neurons': 10, 'activation': 'lin', 'norm': 6.719358519833669}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:03,250] Trial 1 finished with value: -1.0797593963843075 and parameters: {'neurons': 50, 'activation': 'tanh', 'norm': 0.0757499024110693}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:03,283] Trial 5 finished with value: -1.038706940252541 and parameters: {'neurons': 25, 'activation': 'lin', 'norm': 96.4054711943899}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:03,506] Trial 2 finished with value: -1.0775738533811219 and parameters: {'neurons': 100, 'activation': 'tanh', 'norm': 0.5753425726679413}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:03,529] Trial 7 finished with value: -1.0387130610852005 and parameters: {'neurons': 25, 'activation': 'lin', 'norm': 4.109605031598475}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:03,842] Trial 9 finished with value: -1.0429309416027182 and parameters: {'neurons': 10, 'activation': 'sigm', 'norm': 0.6698693393939645}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:03,852] Trial 8 finished with value: -1.0801248300806707 and parameters: {'neurons': 50, 'activation': 'sigm', 'norm': 0.40777197644933694}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:04,048] Trial 6 finished with value: -1.07515504510063 and parameters: {'neurons': 100, 'activation': 'tanh', 'norm': 9.316022516752222}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:04,482] Trial 13 finished with value: -1.03862756617685 and parameters: {'neurons': 5, 'activation': 'sigm', 'norm': 0.01123492805470318}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:04,700] Trial 10 finished with value: -1.0503868427453653 and parameters: {'neurons': 100, 'activation': 'sigm', 'norm': 65.40397661885756}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:04,716] Trial 12 finished with value: -1.07786878294599 and parameters: {'neurons': 50, 'activation': 'tanh', 'norm': 34.12516831963585}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:04,906] Trial 14 finished with value: -1.0386276585320262 and parameters: {'neurons': 5, 'activation': 'sigm', 'norm': 0.010046862691680323}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:05,095] Trial 11 finished with value: -1.038713321343495 and parameters: {'neurons': 200, 'activation': 'lin', 'norm': 1.7182547678375737}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:05,111] Trial 15 finished with value: -1.038627656989211 and parameters: {'neurons': 5, 'activation': 'sigm', 'norm': 0.010066709369411822}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:05,148] Trial 16 finished with value: -1.0386274381836735 and parameters: {'neurons': 5, 'activation': 'sigm', 'norm': 0.012881491206485525}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:05,240] Trial 17 finished with value: -1.0386274788387726 and parameters: {'neurons': 5, 'activation': 'sigm', 'norm': 0.012358479338206838}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:05,339] Trial 19 finished with value: -1.038618702553536 and parameters: {'neurons': 5, 'activation': 'sigm', 'norm': 0.12539072005751922}. Best is trial 3 with value: -1.038309316840877.
# [I 2026-02-12 14:00:05,356] Trial 18 finished with value: -1.0386275154405957 and parameters: {'neurons': 5, 'activation': 'sigm', 'norm': 0
:\Users\ABIGAIL\anaconda3\envs\WASS2S\Lib\shlex.py' for module 'shlex': UnicodeDecodeError
# Traceback (most recent call last):
#   File "C:\Users\ABIGAIL\anaconda3\envs\WASS2S\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ABIGAIL\anaconda3\envs\WASS2S\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ABIGAIL\anaconda3\envs\WASS2S\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'autoreload'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\ABIGAIL\anaconda3\envs\WASS2S\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ^^^^^^^^
#   File "C:\Users\ABIGAIL\anaconda3\envs\WASS2S\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1442: character maps to <undefined>

# %% [markdown]
# ### XGBoost

# %%
model = WAS_mme_XGBoosting(
    search_method='bayesian',#'random',  # Use randomized search for efficiency
    n_estimators_range=[25, 50, 100, 200, 300], #500, 600, 700, 1000, 1500],# 3000, 5000],  # Optimized for climate data
    learning_rate_range=[0.01, 0.05, 0.1],  # Finer low values
    max_depth_range=[2, 3, 4, 5],  # Conservative depths
    min_child_weight_range=[1, 2, 5, 10],
    subsample_range=[0.6, 0.8, 1.0],
    colsample_bytree_range=[0.5, 0.7, 0.9, 1.0],
    gamma_range=[0, 0.001, 0.01, 0.1, 0.5, 1.0],  # ADDED: Regularization
    reg_alpha_range=[0, 0.1, 0.5, 1.0],  # ADDED: L1 regularization
    reg_lambda_range=[1, 3, 5, 10],  # ADDED: L2 regularization
    random_state=42,
    dist_method=dist_method,  # Use non-parametric for probabilities
    n_iter_search=200,  # Increase iterations for better search
    cv_folds=5,
    n_clusters=2,  # Number of homogeneous zones
    optuna_n_jobs=-1,  # Use all cores if using bayesian optimization
    optuna_timeout=600  # 20 minute timeout
)

# %% [markdown]
# #### Cross-validation

# %%
# all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), gcm=True, ELM_ELR=True, dir_to_save_model=dir_to_save_model, best_models=best_models, scores=scores, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), hdcsted=hindcast_files, fcsted=forecast_files, scores= scores, score_metric='MAE', gcm=False, agroparam=True, ELM_ELR=False, best_models=best_models, dir_to_save_model=dir_to_save_model, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, year_forecast=forecast)

# %%
best_params, cluster = model.compute_hyperparameters(all_model_hdcst, obs, clim_year_start, clim_year_end)
# Out:
# [I 2026-02-12 14:00:46,519] A new study created in memory with name: no-name-e2cea6ea-3ad2-4b9c-9506-866de00ff076
# [I 2026-02-12 14:00:48,088] Trial 2 finished with value: -0.8160245087092225 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.5, 'gamma': 0.1, 'reg_alpha': 0.5, 'reg_lambda': 10}. Best is trial 2 with value: -0.8160245087092225.
# [I 2026-02-12 14:00:48,594] Trial 3 finished with value: -0.8196071307150259 and parameters: {'n_estimators': 25, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.6, 'colsample_bytree': 0.7, 'gamma': 0, 'reg_alpha': 0.5, 'reg_lambda': 3}. Best is trial 2 with value: -0.8160245087092225.
# [I 2026-02-12 14:00:48,745] Trial 1 finished with value: -0.8278353224098508 and parameters: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.5, 'gamma': 0.5, 'reg_alpha': 0.1, 'reg_lambda': 1}. Best is trial 2 with value: -0.8160245087092225.
# [I 2026-02-12 14:00:48,887] Trial 0 finished with value: -0.8302276643921044 and parameters: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.6, 'colsample_bytree': 0.7, 'gamma': 0.5, 'reg_alpha': 0.5, 'reg_lambda': 1}. Best is trial 2 with value: -0.8160245087092225.
# [I 2026-02-12 14:00:48,909] Trial 4 finished with value: -0.818445840782189 and parameters: {'n_estimators': 50, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 1.0, 'reg_alpha': 0.5, 'reg_lambda': 5}. Best is trial 2 with value: -0.8160245087092225.
# [I 2026-02-12 14:00:49,133] Trial 5 finished with value: -0.8154370938285085 and parameters: {'n_estimators': 25, 'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 10, 'subsample': 0.8, 'colsample_bytree': 0.7, 'gamma': 0.01, 'reg_alpha': 1.0, 'reg_lambda': 1}. Best is trial 5 with value: -0.8154370938285085.
# [I 2026-02-12 14:00:49,485] Trial 6 finished with value: -0.8179969066421597 and parameters: {'n_estimators': 50, 'learning_rate': 0.05, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.8, 'colsample_bytree': 1.0, 'gamma': 0.5, 'reg_alpha': 0, 'reg_lambda': 5}. Best is trial 5 with value: -0.8154370938285085.
# [I 2026-02-12 14:00:49,605] Trial 8 finished with value: -0.8188675702780742 and parameters: {'n_estimators': 25, 'learning_rate': 0.1, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0, 'reg_alpha': 0.5, 'reg_lambda': 5}. Best is trial 5 with value: -0.8154370938285085.
# [I 2026-02-12 14:00:50,229] Trial 7 finished with value: -0.816704807372418 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.001, 'reg_alpha': 0.1, 'reg_lambda': 1}. Best is trial 5 with value: -0.8154370938285085.
# [I 2026-02-12 14:00:50,508] Trial 10 finished with value: -0.8207832655756386 and parameters: {'n_estimators': 25, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 10, 'subsample': 1.0, 'colsample_bytree': 0.5, 'gamma': 0.001, 'reg_alpha': 0.5, 'reg_lambda': 10}. Best is trial 5 with value: -0.8154370938285085.
# [I 2026-02-12 14:00:50,591] Trial 9 finished with value: -0.83215360930148 and parameters: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'gamma': 0.5, 'reg_alpha': 1.0, 'reg_lambda': 1}. Best is trial 5 with value: -0.8154370938285085.
# [I 2026-02-12 14:00:51,617] Trial 12 finished with value: -0.819019285352082 and parameters: {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 10, 'subsample': 1.0, 'colsample_bytree': 0.5, 'gamma': 0.1, 'reg_alpha': 0, 'reg_lambda': 5}. Best is trial 5 with value: -0.8154370938285085.
# [I 2026-02-12 14:00:52,255] Trial 11 finished with value: -0.8327670502053273 and parameters: {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 2, 'min_child_weight': 1, 'subsample': 0.8, 'colsample_bytree': 0
and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.7, 'gamma': 1.0, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 117 with value: -0.8040308213357882.
# [I 2026-02-12 14:03:08,417] Trial 158 finished with value: -0.8071522591593532 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.7, 'gamma': 1.0, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 117 with value: -0.8040308213357882.
# [I 2026-02-12 14:03:08,744] Trial 159 finished with value: -0.8071522591593532 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.7, 'gamma': 1.0, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 117 with value: -0.8040308213357882.
# [I 2026-02-12 14:03:09,181] Trial 160 finished with value: -0.8071189727527738 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.7, 'gamma': 0, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 117 with value: -0.8040308213357882.
# [I 2026-02-12 14:03:09,648] Trial 161 finished with value: -0.8082281881893632 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 117 with value: -0.8040308213357882.
# [I 2026-02-12 14:03:09,772] Trial 162 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:10,054] Trial 163 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:10,288] Trial 164 finished with value: -0.8040330516892137 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.7, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:10,477] Trial 165 finished with value: -0.8040330516892137 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.7, 'gamma': 1.0, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:10,678] Trial 166 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:11,094] Trial 167 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:11,445] Trial 168 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:11,649] Trial 169 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:11,868] Trial 170 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:12,129] Trial 171 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:12,310] Trial 172 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:12,566] Trial 173 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:12,734] Trial 174 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:13,009] Trial 175 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:13,258] Trial 176 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:13,412] Trial 177 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:14,060] Trial 178 finished with value: -0.8067870680624513 and parameters: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:14,147] Trial 179 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:14,779] Trial 180 finished with value: -0.8067870680624513 and parameters: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:15,411] Trial 181 finished with value: -0.8067870680624513 and parameters: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:15,756] Trial 182 finished with value: -0.8052772754759963 and parameters: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:16,137] Trial 183 finished with value: -0.8052772754759963 and parameters: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:16,500] Trial 184 finished with value: -0.8052772754759963 and parameters: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:16,833] Trial 185 finished with value: -0.8052772754759963 and parameters: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:17,016] Trial 186 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:17,271] Trial 187 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:17,517] Trial 188 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:17,748] Trial 189 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:17,927] Trial 190 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:18,145] Trial 191 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:18,452] Trial 192 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:18,652] Trial 193 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:18,863] Trial 194 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:19,316] Trial 195 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:19,611] Trial 196 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:19,810] Trial 197 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:20,086] Trial 198 finished with value: -0.8052588379299553 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.
# [I 2026-02-12 14:03:20,239] Trial 199 finished with value: -0.8040088352338628 and parameters: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9, 'gamma': 0.01, 'reg_alpha': 0.1, 'reg_lambda': 5}. Best is trial 162 with value: -0.8040088352338628.

# %%
best_params #= {'activation': 'lin', 'neurons': 200, 'norm': 37.38460883888426}
# Out:
# {0.0: {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'max_depth': 3,
#   'min_child_weight': 10,
#   'subsample': 1.0,
#   'colsample_bytree': 0.9,
#   'gamma': 0.5,
#   'reg_alpha': 0.5,
#   'reg_lambda': 5},
#  1.0: {'n_estimators': 100,
#   'learning_rate': 0.01,
#   'max_depth': 2,
#   'min_child_weight': 2,
#   'subsample': 1.0,
#   'colsample_bytree': 0.9,
#   'gamma': 0.01,
#   'reg_alpha': 0.1,
#   'reg_lambda': 5}}

# %%
cluster.plot()

# %%
was_mme_gcm = WAS_Cross_Validator(n_splits=len(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start, 
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster,
                                                                  best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start,
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster
                                                                     )    
hdcst_consolidated['SV-ML-CMME_XGBOOST'] = hindcast_det_gcm
hdcst_consolidated_prob['SV-ML-CMME_XGBOOST'] = hindcast_prob_gcm
# Out:
# Cross-validation ongoing
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:06<00:00,  3.86it/s]

# %% [markdown]
# #### Verification

# %%
score = ['Pearson', 'MAE']
model_name = "XGBoost" #"Extreme Learning Machine" # Extreme Learning Machine "MultiLayer Perceptron" XGBoost Random Forest

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det_gcm
    )
    scores_consolidated[i] = {'SV-ML-CMME_XGBOOST': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ##### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob_gcm,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'SV-ML-CMME_XGBOOST': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)
# Out:
# Generalized Discrimination Score
# Ranked Probability Skill Score

# %% [markdown]
# #### Forecast

# %%
if dist_method=="bestfit":
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, all_model_fcst, best_params=best_params, cluster_da=cluster, 
                                                        best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, 
                                                        all_model_fcst, best_params=best_params, cluster_da=cluster
                                                       )
    
fcst_consolidated['SV-ML-CMME_XGBOOST'] = forecast_det_gcm
fcst_consolidated_prob['SV-ML-CMME_XGBOOST'] = forecast_prob_gcm
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_gcm.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels, reverse_cmap=True)
gc.collect()
# Out:
# 24561

# %% [markdown]
# # 2nd - Approach: CCA-Based Calibration VWIND

# %%
# Filter model names to identify precipitation-related models
center_variable = [key for key in downloader.ModelsName().keys() if "VGRD_850" in key]
center_variable.remove('UKMO_603.VGRD_850')
center_variable.remove('UKMO_604.VGRD_850')


# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/model_data"

# Define the month for model initialization (June)
month_of_initialization = "12"

# Define lead times corresponding to seasonal forecast targets (JAS season in this case)
lead_time = ["01", "02", "03"]  # July-August-September forecast period

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent = [50, -60, -50, 30]  # [Northern, Western, Southern and Eastern] 


# Define if you want to download forecast or hindcast
forecast = None

# Define if you want all members of ensemble or doing an ensemble mean
ensemble_mean = "mean"

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
hindcast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)
# Out:
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_bom2_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_ecmwf51_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_meteofrance8_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_meteofrance9_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_dwd21_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_dwd22_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_cmcc35_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_ncep2_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_jma3_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_eccc4_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/hindcast_eccc5_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# URL returned status code 404. Skipping download.
# failed to download cfsv2_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download cfsv2_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download cmc1_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download cmc1_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download cmc2_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download cmc2_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download gfdl_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download gfdl_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download nasa_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download nasa_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_ccsm4_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_ccsm4_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_cesm1_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download ncar_cesm1_VGRD_850_hcst_Decic_1-3_1991-2020.txt
# URL returned status code 404. Skipping download.
# failed to download nmme_VGRD_850_hcst_Decic_1-3_1992-2021.txt
# URL returned status code 404. Skipping download.
# failed to download nmme_VGRD_850_hcst_Decic_1-3_1991-2020.txt

# %%
forecast = 2025

# %%
forecast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)
# Out:
# Agro_PRESAGG_2026_ic_1\model_data/forecast_bom2_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# Agro_PRESAGG_2026_ic_1\model_data/forecast_ecmwf51_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# 2026-02-12 14:04:10,649 INFO Request ID is 0fee22c0-f126-4f14-82b5-d7b906a6947a
# 2026-02-12 14:04:10,803 INFO status has been updated to accepted
# 2026-02-12 14:04:24,904 INFO status has been updated to running
# 2026-02-12 14:04:32,648 INFO status has been updated to failed
# Failed to download data for VGRD_850: 400 Client Error: Bad Request for url: https://cds.climate.copernicus.eu/api/retrieve/v1/jobs/0fee22c0-f126-4f14-82b5-d7b906a6947a/results
# The job has failed
# MARS returned no data, please check your selection.Request submitted to the MARS server:
# [{'area': ['50', '-60', '-50', '30'], 'fcmonth': ['01', '02', '03'], 'origin': ['lfpw'], 'levelist': ['850'], 'type': ['fcmean'], 'system': ['8'], 'param': ['132'], 'time': ['all'], 'class': ['c3'], 'expect': ['any'], 'expver': ['1'], 'method': ['1'], 'number': ['all'], 'stream': ['msmm'], 'levtype': ['pl'], 'database': 'ecmwf', 'date': ['2025-12-01']}]
#
# The job failed with: MarsNoDataError
# Agro_PRESAGG_2026_ic_1\model_data/forecast_meteofrance9_VGRD_850_DecIc_JanFebMar_01.nc already exists. Skipping download.
# 2026-02-12 14:04:33,845 INFO Request ID is a16e5a52-48c0-480f-8691-1f463ef8e5dc
# 2026-02-12 14:04:34,170 INFO status has been updated to accepted

# %%
hindcast_files = {k: hindcast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
forecast_files = {k: forecast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
common_keys = {k.lower() for k in hindcast_files} & {k.lower() for k in forecast_files}
center_variable = [
    item
    for item in center_variable
    if any(item.lower().startswith(k) for k in list(common_keys))
                ]

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initialize the WAS_CCA class (default)

# %%
n_modes = 3
# define zone as dict : {'zone_name_key': ('Explicit_Zone_name', lon_min, lon_max, lat_min, lat_max)} 
defined_zone = {'A': ('A', -60, 30, -50, 50)}

# %%
plot_map([extent[1],extent[3],extent[2],extent[0]], sst_indices = defined_zone, title="Predictors Area",fig_size=(6,4))

# %% [markdown]
# ##### Modes of CCA for each model

# %%
was_cca = WAS_CCA_old(n_modes=n_modes, n_pca_modes=8, dist_method=dist_method)
was_cv = WAS_Cross_Validator(n_splits=len(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
predictors = {}
for i in center_variable:
    predictors[i] = retrieve_single_zone_for_PCR(dir_to_save_model, defined_zone, i, year_start_model, year_end_model, clim_year_start=clim_year_start, clim_year_end=clim_year_end, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, standardize=True)
    predictor = predictors[i].isel(T = slice(None,-1))
    predictor['T'] = dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(f"CCA Modes for model {i}")
    was_cca.plot_cca_results(X=predictor, Y=dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))) , clim_year_start=clim_year_start, clim_year_end=clim_year_end)

# %% [markdown]
# #### Cross validation

# %%
hindcast_det_dynam_all = {}
hindcast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                          predictor, clim_year_start, clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))).sel(T=slice(str(year_start_model),str(year_end_model))), predictor, clim_year_start, clim_year_end)

# %% [markdown]
# #### Verification (individual)

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "CCA-based"

# %%
cca_scores = {}
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_deterministic_score(
            was_verify.get_scores_metadata()[i][5],
            dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_det_dynam_all[key]
        )
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_probabilistic_score(
            was_verify.get_scores_metadata()[i][5],
            dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_prob_dynam_all[key],
            clim_year_start,
            clim_year_end)
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# #### Forecast (individual)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
forecast_det_dynam_all = {}
forecast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor_f = predictor.isel(T=[-1])
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f)
    model_name = f"CCA_{key.split('.')[0]}"    
    plot_prob_forecasts(f"{dir_to_forecast}",
                        forecast_prob_dynam_all[key].drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}", 
                        hspace=0.1, labels=fcst_labels, reverse_cmap=True)

# %% [markdown]
# ### Select best Statistico-Dynamical models

# %%
#### Select some models
best_models = get_best_models(center_variable, cca_scores, metric='GROC', threshold=0.6, top_n=4, gcm=False)
best_models

# %%
for key in best_models:
    hdcst_consolidated[f'{key}_snd.approach'] = hindcast_det_dynam_all[key]
    fcst_consolidated[f'{key}_snd.approach'] = forecast_det_dynam_all[key]
    hdcst_consolidated_prob[f'{key}_snd.approach'] = hindcast_prob_dynam_all[key]
    fcst_consolidated_prob[f'{key}_snd.approach'] = forecast_prob_dynam_all[key]
    
for metric, models in cca_scores.items():
    for model in list(models):                    # list() pour éviter RuntimeError
        if not any(model.startswith(p) for p in best_models):
            del models[model]

for key in cca_scores:
    scores_consolidated.setdefault(key, {}).update(cca_scores[key])

# %% [markdown]
# # 2nd - Approach: CCA-Based Calibration SST

# %%
# Filter model names to identify precipitation-related models
center_variable = [key for key in downloader.ModelsName().keys() if "SST" in key]
# center_variable.remove('NASA_1.SST')
center_variable.remove('UKMO_603.SST')
center_variable.remove('UKMO_604.SST')
center_variable.remove('NMME_1.SST')
# center_variable.remove('DWD_21.SST')
# center_variable.remove('CMC2_1.SST')
# center_variable.remove('METEOFRANCE_8.SST')

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/model_data"

# Define the month for model initialization (June)
month_of_initialization = "12"

# Define lead times corresponding to seasonal forecast targets (JAS season in this case)
lead_time = ["01", "02", "03"]  # July-August-September forecast period

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent = [60, -180, -60, 180]  # [Northern, Western, Southern and Eastern] 

# Define if you want to download forecast or hindcast
forecast = None

# Define if you want all members of ensemble or doing an ensemble mean
ensemble_mean = "mean"

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
hindcast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
forecast = 2025

# %%
forecast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
hindcast_files = {k: hindcast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
forecast_files = {k: forecast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
common_keys = {k.lower() for k in hindcast_files} & {k.lower() for k in forecast_files}
center_variable = [
    item
    for item in center_variable
    if any(item.lower().startswith(k) for k in list(common_keys))
                ]

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initialize the WAS_CCA class (default)

# %%
n_modes = 3
# define zone as dict : {'zone_name_key': ('Explicit_Zone_name', lon_min, lon_max, lat_min, lat_max)} 
defined_zone = {'A': ('A', -150, 150, -35, 35)}

# %%
plot_map([extent[1],extent[3],extent[2],extent[0]], sst_indices = defined_zone, title="Predictors Area",fig_size=(6,4))

# %% [markdown]
# ##### Modes of CCA for each model

# %%
was_cca = WAS_CCA_old(n_modes=n_modes, n_pca_modes=8, dist_method=dist_method)
was_cv = WAS_Cross_Validator(n_splits=len(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
predictors = {}
for i in center_variable:
    predictors[i] = retrieve_single_zone_for_PCR(dir_to_save_model, defined_zone, i, year_start_model, year_end_model, clim_year_start=clim_year_start, clim_year_end=clim_year_end, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, standardize=True)
    predictor = predictors[i].isel(T = slice(None,-1))
    predictor['T'] = dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(f"CCA Modes for model {i}")
    was_cca.plot_cca_results(X=predictor, Y=dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))) , clim_year_start=clim_year_start, clim_year_end=clim_year_end)

# %% [markdown]
# #### Cross validation

# %%
hindcast_det_dynam_all = {}
hindcast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                          predictor, clim_year_start, clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))).sel(T=slice(str(year_start_model),str(year_end_model))), predictor, clim_year_start, clim_year_end)

# %% [markdown]
# #### Verification (individual)

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "CCA-based"

# %%
cca_scores = {}
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_deterministic_score(
            was_verify.get_scores_metadata()[i][5],
            dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_det_dynam_all[key]
        )
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_probabilistic_score(
            was_verify.get_scores_metadata()[i][5],
            dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_prob_dynam_all[key],
            clim_year_start,
            clim_year_end)
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# #### Forecast (individual)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
forecast_det_dynam_all = {}
forecast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor_f = predictor.isel(T=[-1])
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f)
    model_name = f"CCA_{key.split('.')[0]}"    
    plot_prob_forecasts(f"{dir_to_forecast}",
                        forecast_prob_dynam_all[key].drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}", 
                        hspace=0.1, labels=fcst_labels, reverse_cmap=True)

# %% [markdown]
# ### Select best Statistico-Dynamical models

# %%
#### Select some models
best_models = get_best_models(center_variable, cca_scores, metric='GROC', threshold=0.6, top_n=4, gcm=False)
best_models

# %%
for key in best_models:
    hdcst_consolidated[f'{key}_snd.approach'] = hindcast_det_dynam_all[key]
    fcst_consolidated[f'{key}_snd.approach'] = forecast_det_dynam_all[key]
    hdcst_consolidated_prob[f'{key}_snd.approach'] = hindcast_prob_dynam_all[key]
    fcst_consolidated_prob[f'{key}_snd.approach'] = forecast_prob_dynam_all[key]
    
for metric, models in cca_scores.items():
    for model in list(models):                    # list() pour éviter RuntimeError
        if not any(model.startswith(p) for p in best_models):
            del models[model]

for key in cca_scores:
    scores_consolidated.setdefault(key, {}).update(cca_scores[key])

# %% [markdown]
# # 2nd - Approach: CCA-Based Calibration PRCP

# %%
# Filter model names to identify precipitation-related models
center_variable = [key for key in downloader.ModelsName().keys() if "PRCP" in key]
# center_variable.remove('NASA_1.SST')
center_variable.remove('UKMO_603.PRCP')
center_variable.remove('UKMO_604.PRCP')
center_variable.remove('NMME_1.PRCP')
# center_variable.remove('DWD_21.SST')
# center_variable.remove('CMC2_1.SST')
# center_variable.remove('METEOFRANCE_8.SST')

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/model_data"

# Define the month for model initialization (June)
month_of_initialization = "12"

# Define lead times corresponding to seasonal forecast targets (JAS season in this case)
lead_time = ["01", "02", "03"]  # July-August-September forecast period

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent = [30, -30, -20, 30]  # [Northern, Western, Southern and Eastern] 

# Define if you want to download forecast or hindcast
forecast = None

# Define if you want all members of ensemble or doing an ensemble mean
ensemble_mean = "mean"

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
hindcast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
forecast = 2025

# %%
forecast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
hindcast_files = {k: hindcast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
forecast_files = {k: forecast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
common_keys = {k.lower() for k in hindcast_files} & {k.lower() for k in forecast_files}
center_variable = [
    item
    for item in center_variable
    if any(item.lower().startswith(k) for k in list(common_keys))
                ]

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initialize the WAS_CCA class (default)

# %%
n_modes = 3
# define zone as dict : {'zone_name_key': ('Explicit_Zone_name', lon_min, lon_max, lat_min, lat_max)} 
defined_zone = {'A': ('A', -20, 30, -30, 30)}

# %%
plot_map([extent[1],extent[3],extent[2],extent[0]], sst_indices = defined_zone, title="Predictors Area",fig_size=(6,4))

# %% [markdown]
# ##### Modes of CCA for each model

# %%
was_cca = WAS_CCA_old(n_modes=n_modes, n_pca_modes=8, dist_method=dist_method)
was_cv = WAS_Cross_Validator(n_splits=len(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
predictors = {}
for i in center_variable:
    predictors[i] = retrieve_single_zone_for_PCR(dir_to_save_model, defined_zone, i, year_start_model, year_end_model, clim_year_start=clim_year_start, clim_year_end=clim_year_end, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, standardize=True)
    predictor = predictors[i].isel(T = slice(None,-1))
    predictor['T'] = dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(f"CCA Modes for model {i}")
    was_cca.plot_cca_results(X=predictor, Y=dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))) , clim_year_start=clim_year_start, clim_year_end=clim_year_end)

# %% [markdown]
# #### Cross validation

# %%
hindcast_det_dynam_all = {}
hindcast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                          predictor, clim_year_start, clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))).sel(T=slice(str(year_start_model),str(year_end_model))), predictor, clim_year_start, clim_year_end)

# %% [markdown]
# #### Verification (individual)

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "CCA-based"

# %%
cca_scores = {}
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_deterministic_score(
            was_verify.get_scores_metadata()[i][5],
            dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_det_dynam_all[key]
        )
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_probabilistic_score(
            was_verify.get_scores_metadata()[i][5],
            dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_prob_dynam_all[key],
            clim_year_start,
            clim_year_end)
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# #### Forecast (individual)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
forecast_det_dynam_all = {}
forecast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor_f = predictor.isel(T=[-1])
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f)
    model_name = f"CCA_{key.split('.')[0]}"    
    plot_prob_forecasts(f"{dir_to_forecast}",
                        forecast_prob_dynam_all[key].drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}", 
                        hspace=0.1, labels=fcst_labels, reverse_cmap=True)

# %% [markdown]
# ### Select best Statistico-Dynamical models

# %%
#### Select some models
best_models = get_best_models(center_variable, cca_scores, metric='GROC', threshold=0.6, top_n=4, gcm=False)
best_models

# %%
for key in best_models:
    hdcst_consolidated[f'{key}_snd.approach'] = hindcast_det_dynam_all[key]
    fcst_consolidated[f'{key}_snd.approach'] = forecast_det_dynam_all[key]
    hdcst_consolidated_prob[f'{key}_snd.approach'] = hindcast_prob_dynam_all[key]
    fcst_consolidated_prob[f'{key}_snd.approach'] = forecast_prob_dynam_all[key]
    
for metric, models in cca_scores.items():
    for model in list(models):                    # list() pour éviter RuntimeError
        if not any(model.startswith(p) for p in best_models):
            del models[model]

for key in cca_scores:
    scores_consolidated.setdefault(key, {}).update(cca_scores[key])

# %% [markdown]
# # 4th - Analog-based seasonal forecast

# %% [markdown]
# ## Analog bias_based

# %%
# %load_ext autoreload
# %autoreload 2

# %%
model = WAS_Analog(
    dir_to_save=f"{dir_s2s}/analog",
    year_start=1990,
    year_forecast=2025,          # target forecast year
    month_of_initialization=12,   # May initialisation
    predictor_vars=[{'reanalysis_name': 'NOAA', 'model_name': 'ECMWF_51', 'variable': 'SST', 'area': [40, -180, -35, 100]},
                    # {'reanalysis_name': 'ERA5', 'model_name': 'NCEP_2', 'variable': 'SLP', 'area': [80, -60, -80, 60]},
                    # {'reanalysis_name': 'ERA5', 'model_name': 'NCEP_2', 'variable': 'VGRD_850', 'area': [30, -45, -20, 15]}
                   ],
    method_analog="bias_based",
    standardize=True,
    rolling=3,
    lead_time=[1,2,3],
    clim_year_start=clim_year_start, 
    clim_year_end=clim_year_end,
    dist_method=dist_method
)

# %% [markdown]
# #### Cross-validation

# %%
was_analog_cv = WAS_Cross_Validator(n_splits=len(dryspellonset.get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_analog_det, hindcast_analog_prob = was_analog_cv.cross_validate(model, dryspellonset, clim_year_start=clim_year_start, clim_year_end=clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_analog_det, hindcast_analog_prob = was_analog_cv.cross_validate(model, dryspellonset, clim_year_start=clim_year_start, clim_year_end=clim_year_end)    
hdcst_consolidated['fourth.approach'] = hindcast_analog_det.sel(T=slice(str(year_start_model),str(year_end_model)))
hdcst_consolidated_prob['fourth.approach'] = hindcast_analog_prob.sel(T=slice(str(year_start_model),str(year_end_model)))

# %% [markdown]
# #### Verification

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "Analogue-Based Forecasting"

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        dryspellonset,
        hindcast_analog_det
    )
    scores_consolidated[i] = {'fourth.approach': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        dryspellonset,
        hindcast_analog_prob,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'fourth.approach': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# #### Forecast

# %%
## Analysis SST evolution
model.composite_plot(dryspellonset, clim_year_start, clim_year_end, 
                     hindcast_analog_det, plot_predictor=True,
                    variable="SST", best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)

# %%
## Plot silimar years behavior
model.composite_plot(dryspellonset, clim_year_start, clim_year_end, hindcast_analog_det, plot_predictor=False, best_code_da=best_code_da,
                     best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)

# %%
if dist_method=="bestfit":
    similar_years, forecast_det_analog, forecast_prob_analog = model.forecast(dryspellonset, clim_year_start, clim_year_end, hindcast_analog_det, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    similar_years, forecast_det_analog, forecast_prob_analog = model.forecast(dryspellonset, clim_year_start, clim_year_end, hindcast_analog_det)    
fcst_consolidated['fourth.approach'] = forecast_det_analog
fcst_consolidated_prob['fourth.approach'] = forecast_prob_analog
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_analog.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels,
                    reverse_cmap=True)

# %% [markdown]
# # Consolidated Forecasts

# %%
best_models = list(hdcst_consolidated.keys())
best_models

# %% [markdown]
# #### Cross-validation

# %%
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),hdcsted=hdcst_consolidated, fcsted=fcst_consolidated, gcm=False, ELM_ELR=False,  Prob=False, best_models=best_models, scores=scores_consolidated, model=False, score_metric="GROC")

# %%
was_mme = WAS_mme_Weighted(equal_weighted=True, dist_method=dist_method, metric="GROC", threshold=0.6)

# %%
hindcast_det, forecast_det  = was_mme.compute(obs, all_model_hdcst, all_model_fcst, best_score, complete=True)
hindcast_prob = was_mme.compute_prob(dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, hindcast_det, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)

# %% [markdown]
# #### Verification

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "Consolidated Forecast"

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det
    )
    
    r.to_dataset(name="Equaly weigthed")
    r.to_netcdf(f"{dir_s2s}/equaly_{i}.nc")
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        dryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob,
        clim_year_start,
        clim_year_end)
    r.to_dataset(name="Equaly weigthed")
    r.to_netcdf(f"{dir_s2s}/equaly_{i}.nc")
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ### Forecast

# %%
_,forecast_prob = was_mme.forecast(dryspelldryspellonset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, hindcast_det, forecast_det,best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
plot_prob_forecasts(dir_to_forecast, forecast_prob.drop_vars('T').squeeze(),
                    f"{model_name} {season_str}-{forecast}" ,#issued {datetime.datetime.today().strftime("%Y-%m-%d")}", 
                    reverse_cmap=True,  hspace=0.1, labels=fcst_labels, logo=logopath, logo_size=0.1)
gc.collect()

# %%
plot_det_forecasts(forecast_det.drop_vars('T').squeeze(),
                    f"{model_name} Deterministic {season_str}-{forecast}", f"{dir_to_forecast}/{model_name} {season_str}-{forecast}.png")
gc.collect()

# %%
forecast_det.to_netcdf(f'{dir_to_forecast}/Forecast_Det_PRCP{season_str}_{forecast}.nc')

# %%
forecast_prob.to_netcdf(f'{dir_to_forecast}/Forecast_Prob_PRCP{season_str}_{forecast}.nc')
