# %% [markdown]
# ##### <p style="text-align: center;"> ![alt text](./utilities/cilss.png)</p>
# # <p style="text-align: center;">AGHRYMET RCC-WAS</p>
# #### &copy; Mandela HOUNGNIBO 2024 (Find more [here](https://github.com/hmandela/WASS2S))

# %% [markdown]
# ## Library

# %%
from wass2s import *
import datetime
import importlib
from pathlib import Path
import warnings
import gc
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Set forecast working directory

# %%
# Set forecast working directory
dir_s2s = "./Agro_PRESAGG_2026_ic_1"
logopath = './utilities/cilss.png'#'./utilities/agrhymet_logo_combined_reversed.png'
fcst_labels = ["Early", "Near-Normal", "Late"]
dist_method="bestfit" # nonparam or bestfit

# %%
dir_s2s = Path(dir_s2s)
os.makedirs(dir_s2s, exist_ok=True)
### Save consolidated results
hdcst_consolidated = {}
fcst_consolidated = {}
scores_consolidated = {}
### Save score
dir_save_score = f"{dir_s2s}/scores"
os.makedirs(dir_save_score, exist_ok=True)
### Save forecasts
dir_to_forecast = f"{dir_s2s}/forecasts"
os.makedirs(dir_to_forecast, exist_ok=True)

# %% [markdown]
# #### Set Climatological Years

# %%
# Set Climatological Years
clim_year_start = 1994 #1991
clim_year_end = 2016 #2020

# %% [markdown]
# ## Download Observation and Process

# %% [markdown]
# #### Load Downloader

# %%
# Load WAS_S2S downloader class
downloader = WAS_Download()

# %%
# Filter observation names to identify precipitation-related models
variables_obs = [key for key in downloader.AgroObsName().keys() if "PRCP" in key]

# Specify the directory to save downloaded model data
dir_to_save_Obs = f"{dir_s2s}/Observation"

# Define the observation period (years 1993 to 2016)
year_start = 1991
year_end = 2025

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent_obs = [12, -3.5, 4, 1.5]   # [Northern, Western, Southern and Eastern] 

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
plot_map([extent_obs[1],extent_obs[3],extent_obs[2],extent_obs[0]], title="Data Download Area", fig_size=(4,3))

# %%
downloader.WAS_Download_AgroIndicators_daily(dir_to_save_Obs, variables_obs, year_start, year_end, extent_obs, force_download=force_download)
downloader.WAS_Download_AgroIndicators_daily(dir_to_save_Obs, variables_obs, datetime.datetime.now().year, datetime.datetime.now().year, extent_obs, force_download=force_download)
# Out:
# Attempt 1/3: Downloading precipitation_flux (None) data for 1991...
# 2026-02-10 11:25:34,076 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:25:34,078 INFO Request ID is d610f5bd-01f2-442c-be67-1322c125a37a
# 2026-02-10 11:25:34,334 INFO status has been updated to accepted
# 2026-02-10 11:25:43,356 INFO status has been updated to running
# 2026-02-10 11:25:48,677 INFO status has been updated to successful
# d7a4f28cb56852f1da4cfd817a96ee31.zip:   0%|          | 0.00/9.71M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1991.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1991.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 1992...
# 2026-02-10 11:26:11,023 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:26:11,025 INFO Request ID is 42bdb2fc-d0ce-47de-8fdc-13af5e4bfbee
# 2026-02-10 11:26:11,198 INFO status has been updated to accepted
# 2026-02-10 11:26:20,048 INFO status has been updated to running
# 2026-02-10 11:26:25,348 INFO status has been updated to successful
# bd5519bb35ccf4a75b7284dfc1a52adb.zip:   0%|          | 0.00/9.68M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1992.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1992.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 1993...
# 2026-02-10 11:26:36,854 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:26:36,856 INFO Request ID is 32672087-dbde-4373-bd70-ad1c93fe977d
# 2026-02-10 11:26:37,235 INFO status has been updated to accepted
# 2026-02-10 11:26:52,092 INFO status has been updated to running
# 2026-02-10 11:28:33,645 INFO status has been updated to successful
# eb6156f992c04e2d29b9ea159436c421.zip:   0%|          | 0.00/9.69M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1993.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1993.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 1994...
# 2026-02-10 11:29:06,862 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:29:06,863 INFO Request ID is 0a44c013-61c0-4cfb-8a97-160849bcb12f
# 2026-02-10 11:29:07,176 INFO status has been updated to accepted
# 2026-02-10 11:29:15,960 INFO status has been updated to running
# 2026-02-10 11:31:02,351 INFO status has been updated to successful
# 668c8ed6ebf4150a542d510feb6a9cd3.zip:   0%|          | 0.00/9.67M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1994.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1994.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 1995...
# 2026-02-10 11:31:19,028 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:31:19,030 INFO Request ID is 708e0023-0b35-4d46-b92d-47e0759c1620
# 2026-02-10 11:31:19,256 INFO status has been updated to accepted
# 2026-02-10 11:31:28,168 INFO status has been updated to running
# 2026-02-10 11:33:14,748 INFO status has been updated to successful
# 5a28ab30c3c1b70c56c2323575d20d7a.zip:   0%|          | 0.00/9.68M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1995.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1995.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 1996...
# 2026-02-10 11:33:45,455 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:33:45,456 INFO Request ID is 32aea475-b498-42bd-86bf-39c0181c8dd8
# 2026-02-10 11:33:45,654 INFO status has been updated to accepted
# 2026-02-10 11:34:00,302 INFO status has been updated to running
# 2026-02-10 11:35:41,474 INFO status has been updated to successful
# c6b13d876bb11bc70734f1ffad83ac77.zip:   0%|          | 0.00/9.71M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1996.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1996.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 1997...
# 2026-02-10 11:36:04,131 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:36:04,132 INFO Request ID is 4977b847-9653-4c0a-8778-9b52ee540258
# 2026-02-10 11:36:04,412 INFO status has been updated to accepted
# 2026-02-10 11:36:18,847 INFO status has been updated to running
# 2026-02-10 11:38:00,130 INFO status has been updated to successful
# 28c53f7846506d191436c5482500e4dc.zip:   0%|          | 0.00/9.68M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1997.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1997.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 1998...
# 2026-02-10 11:38:19,494 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:38:19,495 INFO Request ID is 2e94cffc-ffee-494c-b19b-9a3501e27355
# 2026-02-10 11:38:19,645 INFO status has been updated to accepted
# 2026-02-10 11:38:34,123 INFO status has been updated to running
# 2026-02-10 11:40:15,670 INFO status has been updated to successful
# 5072bf70e9c8b7687417a34f0d860e92.zip:   0%|          | 0.00/9.65M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1998.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1998.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 1999...
# 2026-02-10 11:40:45,388 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:40:45,389 INFO Request ID is 5f8dce40-7cd1-4e83-ad15-b767dc87e74f
# 2026-02-10 11:40:45,602 INFO status has been updated to accepted
# 2026-02-10 11:40:54,802 INFO status has been updated to running
# 2026-02-10 11:42:41,515 INFO status has been updated to successful
# e83b0940f2cdfef2e68fdbf6cd02bfe0.zip:   0%|          | 0.00/9.69M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1999.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_1999.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2000...
# 2026-02-10 11:42:52,687 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:42:52,689 INFO Request ID is bec20c96-eb3a-400a-bc05-cf1386b977b9
# 2026-02-10 11:42:52,883 INFO status has been updated to accepted
# 2026-02-10 11:43:01,899 INFO status has been updated to running
# 2026-02-10 11:44:50,036 INFO status has been updated to successful
# 9cf608428bb7413a7862afebc5082d8e.zip:   0%|          | 0.00/9.66M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2000.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2000.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2001...
# 2026-02-10 11:45:04,777 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:45:04,778 INFO Request ID is cbd5946f-6d99-43ff-b169-827561b2ac58
# 2026-02-10 11:45:05,289 INFO status has been updated to accepted
# 2026-02-10 11:45:14,325 INFO status has been updated to running
# 2026-02-10 11:47:01,340 INFO status has been updated to successful
# 1e488c74031a49c0d15c6a3d757bf538.zip:   0%|          | 0.00/9.64M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2001.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2001.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2002...
# 2026-02-10 11:47:18,475 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:47:18,476 INFO Request ID is 1f48985b-d5e7-40a7-918f-0781a106180e
# 2026-02-10 11:47:18,732 INFO status has been updated to accepted
# 2026-02-10 11:47:34,331 INFO status has been updated to running
# 2026-02-10 11:49:15,869 INFO status has been updated to successful
# b53fb610f05043a5209b70ba4b06752b.zip:   0%|          | 0.00/9.65M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2002.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2002.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2003...
# 2026-02-10 11:49:27,353 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:49:27,354 INFO Request ID is f244cb8e-f6f0-4f96-85df-011f8caacac9
# 2026-02-10 11:49:27,501 INFO status has been updated to accepted
# 2026-02-10 11:49:36,789 INFO status has been updated to running
# 2026-02-10 11:52:23,795 INFO status has been updated to successful
# 6719ada09f24233fcff2b27a8606237.zip:   0%|          | 0.00/9.67M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2003.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2003.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2004...
# 2026-02-10 11:53:01,358 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:53:01,360 INFO Request ID is a5faf48d-f213-46ac-b66a-74b907410198
# 2026-02-10 11:53:01,562 INFO status has been updated to accepted
# 2026-02-10 11:53:15,900 INFO status has been updated to running
# 2026-02-10 11:54:57,159 INFO status has been updated to successful
# 7a1cab5223a6074d77add081a66bf379.zip:   0%|          | 0.00/9.69M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2004.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2004.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2005...
# 2026-02-10 11:55:22,772 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:55:22,774 INFO Request ID is d24dffc5-99ad-42bb-89f5-685277d2929d
# 2026-02-10 11:55:23,082 INFO status has been updated to accepted
# 2026-02-10 11:55:32,078 INFO status has been updated to running
# 2026-02-10 11:57:18,688 INFO status has been updated to successful
# 86f4c42c8c421a9507070d7edccc44bd.zip:   0%|          | 0.00/9.66M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2005.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2005.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2006...
# 2026-02-10 11:57:30,957 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:57:30,959 INFO Request ID is 24827a41-2a11-477a-ac2d-09317ba9a476
# 2026-02-10 11:57:31,164 INFO status has been updated to accepted
# 2026-02-10 11:57:45,307 INFO status has been updated to running
# 2026-02-10 11:59:26,531 INFO status has been updated to successful
# 3e44ddc7daf1ea7cd8acaf9f70846b4d.zip:   0%|          | 0.00/9.65M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2006.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2006.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2007...
# 2026-02-10 11:59:46,820 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 11:59:46,821 INFO Request ID is 1f6f2d01-e565-482d-bbe3-075e08128f55
# 2026-02-10 11:59:46,965 INFO status has been updated to accepted
# 2026-02-10 11:59:55,944 INFO status has been updated to running
# 2026-02-10 12:01:42,631 INFO status has been updated to successful
# 9b63fa59668938bdcc1b51fe6b9425c5.zip:   0%|          | 0.00/9.64M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2007.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2007.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2008...
# 2026-02-10 12:02:00,755 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:02:00,756 INFO Request ID is 623abfb6-2625-4088-98c5-c04f4a0ade32
# 2026-02-10 12:02:00,904 INFO status has been updated to accepted
# 2026-02-10 12:02:17,573 INFO status has been updated to running
# 2026-02-10 12:03:59,005 INFO status has been updated to successful
# 19fd5dcdf8ab4d1b7a54ffc4f2fc447b.zip:   0%|          | 0.00/9.63M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2008.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2008.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2009...
# 2026-02-10 12:04:10,682 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:04:10,683 INFO Request ID is b43764e4-6837-4696-8a81-3ed1eaa0664c
# 2026-02-10 12:04:10,913 INFO status has been updated to accepted
# 2026-02-10 12:04:25,094 INFO status has been updated to running
# 2026-02-10 12:06:06,376 INFO status has been updated to successful
# f2859c42f1eb7f386271adaa0ac0b5e3.zip:   0%|          | 0.00/9.68M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2009.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2009.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2010...
# 2026-02-10 12:06:44,999 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:06:44,999 INFO Request ID is edbcf560-9d81-45b4-8062-ba1ceafc5ed6
# 2026-02-10 12:06:45,188 INFO status has been updated to accepted
# 2026-02-10 12:06:55,441 INFO status has been updated to running
# 2026-02-10 12:08:42,028 INFO status has been updated to successful
# ed988ae84e67327cf1930692242eddeb.zip:   0%|          | 0.00/9.68M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2010.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2010.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2011...
# 2026-02-10 12:09:00,910 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:09:00,911 INFO Request ID is 067cf9bc-9a93-468c-afb6-522ed59424bc
# 2026-02-10 12:09:01,041 INFO status has been updated to accepted
# 2026-02-10 12:09:10,198 INFO status has been updated to running
# 2026-02-10 12:10:57,083 INFO status has been updated to successful
# 6de2dba4cb85a56589fdf73570c8d166.zip:   0%|          | 0.00/9.65M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2011.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2011.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2012...
# 2026-02-10 12:11:31,665 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:11:31,665 INFO Request ID is 85ece5cb-f273-4eb0-b037-62535f7fb23f
# 2026-02-10 12:11:32,163 INFO status has been updated to accepted
# 2026-02-10 12:11:46,987 INFO status has been updated to running
# 2026-02-10 12:13:29,389 INFO status has been updated to successful
# df93e46fab99af67efeea11b672039b5.zip:   0%|          | 0.00/9.70M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2012.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2012.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2013...
# 2026-02-10 12:14:21,999 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:14:22,000 INFO Request ID is fa617af0-1108-4edd-97db-e6f994503157
# 2026-02-10 12:14:22,187 INFO status has been updated to accepted
# 2026-02-10 12:14:45,019 INFO status has been updated to running
# 2026-02-10 12:16:19,134 INFO status has been updated to successful
# 57ac911896f603880468c7def05a619b.zip:   0%|          | 0.00/9.67M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2013.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2013.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2014...
# 2026-02-10 12:16:53,431 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:16:53,432 INFO Request ID is cc9c4127-e3b3-40f9-ba5e-93e3bfb4813f
# 2026-02-10 12:16:53,693 INFO status has been updated to accepted
# 2026-02-10 12:17:07,983 INFO status has been updated to running
# 2026-02-10 12:18:49,133 INFO status has been updated to successful
# d3189364a9a631f48bfb71c4553e9a67.zip:   0%|          | 0.00/9.69M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2014.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2014.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2015...
# 2026-02-10 12:19:08,086 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:19:08,088 INFO Request ID is 7e5304ed-0dea-4c42-8317-b1b41f10986a
# 2026-02-10 12:19:08,305 INFO status has been updated to accepted
# 2026-02-10 12:19:17,714 INFO status has been updated to running
# 2026-02-10 12:21:04,738 INFO status has been updated to successful
# 730b2535601c16ec87b2518119161297.zip:   0%|          | 0.00/9.63M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2015.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2015.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2016...
# 2026-02-10 12:21:53,872 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:21:53,873 INFO Request ID is eaacd088-53ac-4665-b881-7381f82b293a
# 2026-02-10 12:21:54,164 INFO status has been updated to accepted
# 2026-02-10 12:22:09,175 INFO status has been updated to running
# 2026-02-10 12:22:17,002 INFO status has been updated to accepted
# 2026-02-10 12:22:28,578 INFO status has been updated to running
# 2026-02-10 12:23:51,255 INFO status has been updated to successful
# ef8c40453585ddb2240474e7f126cff7.zip:   0%|          | 0.00/9.67M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2016.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2016.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2017...
# 2026-02-10 12:24:38,946 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:24:38,948 INFO Request ID is 5659bf1a-54df-4150-9672-c2b71faf2544
# 2026-02-10 12:24:39,128 INFO status has been updated to accepted
# 2026-02-10 12:24:53,626 INFO status has been updated to running
# 2026-02-10 12:26:35,263 INFO status has been updated to successful
# cd4b1635d8ee0d0b877e6c0a99830ca9.zip:   0%|          | 0.00/9.63M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2017.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2017.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2018...
# 2026-02-10 12:28:17,354 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:28:17,354 INFO Request ID is fe0de0ed-65cf-4e0a-8ca9-92103243beea
# 2026-02-10 12:28:17,544 INFO status has been updated to accepted
# 2026-02-10 12:28:31,648 INFO status has been updated to running
# 2026-02-10 12:30:12,965 INFO status has been updated to successful
# e2a70a1d69cfd75e7ea70cc40f982606.zip:   0%|          | 0.00/9.67M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2018.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2018.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2019...
# 2026-02-10 12:30:41,880 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:30:41,881 INFO Request ID is a652909e-bd57-4666-93fe-c026964ef437
# 2026-02-10 12:30:42,154 INFO status has been updated to accepted
# 2026-02-10 12:30:56,613 INFO status has been updated to running
# 2026-02-10 12:32:37,998 INFO status has been updated to successful
# b1349894ce38bd470adfa72019011f3e.zip:   0%|          | 0.00/9.68M [00:00<?, ?B/s]
# Downloaded: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2019.zip
# Deleted ZIP file: Onset_PRESAGG_2026_ic_1/Observation/Daily_PRCP_2019.zip
# Attempt 1/3: Downloading precipitation_flux (None) data for 2020...
# 2026-02-10 12:33:18,301 INFO [2025-12-02T00:00:00] Please be aware that from 1st January 2026, scientific and technical support of this dataset will not be available anymore. Therefore, it is not recommended for use in a production environment. For updates please watch the [forum announcement](https://forum.ecmwf.int/t/scientific-and-technical-support-for-agera5-ending-from-31-12-2025/14468)
# 2026-02-10 12:33:18,302 INFO Request ID is 62a2235b-e14e-4802-86a1-dd526471c64e
# 2026-02-10 12:33:18,520 INFO status has been updated to accepted

# %%
#### Process predictant
rainfall = prepare_predictand(dir_to_save_Obs, variables_obs, year_start, year_end, daily=True, ds=False)
rainfall_for_forecast_year = prepare_predictand(dir_to_save_Obs, variables_obs, datetime.datetime.now().year, datetime.datetime.now().year, daily=True, ds=False)
season_str = agrometparam = "Onset"
season_obs = [datetime.datetime.now().month+1]

# %% [markdown]
# ## Compute Onset

# %%
### Choose number of cores according your computer
nb_cores = 4

# %%
## Onset criteria
user_criteria = onset_criteria
user_criteria

# %%
user_criteria[0]["end_search"] = '05-15'
user_criteria[0]["start_search"] = '02-01'

# %% [markdown]
# ##### Compute onset for gridded products

# %%
# load onset class
was_onset = WAS_compute_onset(user_criteria)
onset = was_onset.compute(daily_data=rainfall, nb_cores=nb_cores)

# %%
plot_date(onset.mean(dim='T'))

# %% [markdown]
# #### Process Onset in combining with Ground-Observation

# %%
# ## Path to the CPT file
cpt_input_file_path = "./Onset_2025.csv"

# %%
# Read CSV
df = pd.read_csv(cpt_input_file_path, na_values=-999.0, encoding="latin1")
onset_df = df[(df['STATION'] == 'LAT') | (df['STATION'] == 'LON') | 
                 (pd.to_numeric(df['STATION'], errors='coerce').between(year_start, year_end))]
verify_station_network(onset_df, extent_obs)

# %%
## Instantiate WAS_Merging class
data_merger = WAS_Merging(onset_df, onset, date_month_day= '02-01')
onset_, _ = data_merger.simple_bias_adjustment(do_cross_validation=False)
# Out:
# Year = 1991-02-01T00:00:00.000000000, number in-situ = 391
#
# Year = 1992-02-01T00:00:00.000000000, number in-situ = 378
#
# Year = 1993-02-01T00:00:00.000000000, number in-situ = 387
#
# Year = 1994-02-01T00:00:00.000000000, number in-situ = 388
#
# Year = 1995-02-01T00:00:00.000000000, number in-situ = 386
#
# Year = 1996-02-01T00:00:00.000000000, number in-situ = 393
#
# Year = 1997-02-01T00:00:00.000000000, number in-situ = 384
#
# Year = 1998-02-01T00:00:00.000000000, number in-situ = 379
#
# Year = 1999-02-01T00:00:00.000000000, number in-situ = 382
#
# Year = 2000-02-01T00:00:00.000000000, number in-situ = 384
#
# Year = 2001-02-01T00:00:00.000000000, number in-situ = 378
#
# Year = 2002-02-01T00:00:00.000000000, number in-situ = 379
#
# Year = 2003-02-01T00:00:00.000000000, number in-situ = 387
#
# Year = 2004-02-01T00:00:00.000000000, number in-situ = 376
#
# Year = 2005-02-01T00:00:00.000000000, number in-situ = 378
#
# Year = 2006-02-01T00:00:00.000000000, number in-situ = 385
#
# Year = 2007-02-01T00:00:00.000000000, number in-situ = 390
#
# Year = 2008-02-01T00:00:00.000000000, number in-situ = 390
#
# Year = 2009-02-01T00:00:00.000000000, number in-situ = 398
#
# Year = 2010-02-01T00:00:00.000000000, number in-situ = 386
#
# Year = 2011-02-01T00:00:00.000000000, number in-situ = 386
#
# Year = 2012-02-01T00:00:00.000000000, number in-situ = 371
#
# Year = 2013-02-01T00:00:00.000000000, number in-situ = 377
#
# Year = 2014-02-01T00:00:00.000000000, number in-situ = 381
#
# Year = 2015-02-01T00:00:00.000000000, number in-situ = 380
#
# Year = 2016-02-01T00:00:00.000000000, number in-situ = 384
#
# Year = 2017-02-01T00:00:00.000000000, number in-situ = 395
#
# Year = 2018-02-01T00:00:00.000000000, number in-situ = 393
#
# Year = 2019-02-01T00:00:00.000000000, number in-situ = 394
#
# Year = 2020-02-01T00:00:00.000000000, number in-situ = 386
#
# Year = 2021-02-01T00:00:00.000000000, number in-situ = 376
#
# Year = 2022-02-01T00:00:00.000000000, number in-situ = 377
#
# Year = 2023-02-01T00:00:00.000000000, number in-situ = 353
#
# Year = 2024-02-01T00:00:00.000000000, number in-situ = 344

# %%
data_merger.plot_merging_comparaison(onset_df, onset , onset_)

# %%
#### Verify last year in cpt file matches year_start before uncomment this line below
onset = onset_
onset.name = "Onset"
plot_date(onset.mean(dim='T'))

# %% [markdown]
# #### Identify the parametric distribution that best fits the observations

# %%
if dist_method=="nonparam":
    pass
else:
    transf = WAS_TransformData(rainfall.sel(T=slice(str(clim_year_start),str(clim_year_end))), 
                      distribution_map={'norm': 1, 'lognorm': 2, 'gamma': 4,}, #'norm': 1, 'lognorm': 2, 'expon': 3, 'gamma': 4, 'weibull_min': 5, 't_dist': 6, "poisson":7, "nbinom":8 
                                n_clusters=1000)
    best_code_da, best_shape_da, best_loc_da, best_scale_da, _ = transf.fit_best_distribution(mode="grid")

# %%
if dist_method=="bestfit":
    transf.plot_best_fit_map(best_code_da,
                             {'norm': 1, 'lognorm': 2, 'expon': 3, 'gamma': 4,
                              'weibull_min': 5, 't_dist': 6, "poisson":7, "nbinom":8},
                             show_plot=True)

# %% [markdown]
# # 1st - Approach: Choice of Best Dynamical models and weighted Average

# %%
# Filter model names to identify precipitation-related models
# center_variable = ['NCEP_2.PRCP', 'ECCC_4.PRCP']
center_variable = [key for key in downloader.AgroObsName().keys() if "PRCP" in key]

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/daily_model_data"

# Define the month for model initialization (June)
month_of_initialization = "01"
day_of_initialization ="01"

# Define lead times corresponding to seasonal forecast targets
leadtime_hour = [str(i) for i in range(24, 5161, 24)] 

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent_obs = [12, -3.5, 4, 1.5]  # [Northern, Western, Southern and Eastern] 

# Define if you want to download forecast or hindcast
forecast = None
ensemble_mean = 'mean',
# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
file_path_hdcst = downloader.WAS_Download_Models_Daily(dir_to_save_model,center_variable,month_of_initialization, day_of_initialization, leadtime_hour, year_start_model, year_end_model, extent_obs, forecast, ensemble_mean, force_download,)
# Out:
# Agro_PRESASS_2025/daily_model_data/hindcast_ecmwf51_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/hindcast_meteo_france8_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/hindcast_ukmo604_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/hindcast_dwd21_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/hindcast_dwd22_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/hindcast_cmcc35_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/hindcast_eccc4_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/hindcast_eccc5_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/hindcast_jma3_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/hindcast_ncep2_PRCP_Mar01_1993_2016_24-5160.nc already exists. Skipping download.

# %%
forecast = 2026

# %%
file_path_fcst = downloader.WAS_Download_Models_Daily(dir_to_save_model,center_variable,month_of_initialization, day_of_initialization, leadtime_hour, year_start_model, year_end_model, extent_obs, forecast, ensemble_mean, force_download,)
# Out:
# Agro_PRESASS_2025/daily_model_data/forecast_ecmwf51_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/forecast_meteo_france8_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/forecast_ukmo604_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/forecast_dwd21_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/forecast_dwd22_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/forecast_cmcc35_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/forecast_eccc4_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/forecast_eccc5_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/forecast_jma3_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.
# Agro_PRESASS_2025/daily_model_data/forecast_ncep2_PRCP_Mar01_2025_24-5160.nc already exists. Skipping download.

# %% [markdown]
# #### Models bias correction

# %%
hindcast_files, forecast_files = pre_process_biophysical_model(dir_s2s, file_path_hdcst, 
file_path_fcst, rainfall, rainfall_for_forecast_year, month_of_initialization,
 year_start_model, year_end_model, forecast, param="PRCP")
# Out:
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_ecmwf51_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_meteo_france8_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_ukmo604_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_dwd21_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_dwd22_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_cmcc35_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_eccc4_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_eccc5_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_jma3_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_ncep2_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_ecmwf51_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_meteo_france8_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_ukmo604_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_dwd21_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_dwd22_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_cmcc35_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_eccc4_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_eccc5_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_jma3_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_ncep2_PRCP_MarIc.nc already exists.

# %%
hindcast_files_cor, forecast_files_cor = proceed_seasonal_daily_bias_correction(dir_to_save_model, rainfall, hindcast_files, forecast_files, varname="PRCP", wet_day=0.1)
# Out:
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_ecmwf51_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_ecmwf51_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_meteo_france8_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_meteo_france8_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_ukmo604_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_ukmo604_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_dwd21_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_dwd21_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_dwd22_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_dwd22_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_cmcc35_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_cmcc35_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_eccc4_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_eccc4_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_eccc5_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_eccc5_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_jma3_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_jma3_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/hindcast_ncep2_PRCP_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/daily_model_data/corrected/forecast_ncep2_PRCP_MarIc.nc already exists.

# %% [markdown]
# ## Verify Bias Correction

# %%
import xskillscore as xs
for i in hindcast_files_cor.keys():
    hcst_cor = xr.open_dataset(hindcast_files_cor[i])["corrected"]
    hcst = xr.open_dataset(hindcast_files[i])["PRCP"]
    observation = rainfall.interp(Y=hcst.Y, X=hcst.X, method="linear", kwargs={"fill_value": "extrapolate"})
    dry_wet, extrem = qmap.evaluate_bias_correction(observation,
                                              hcst,
                                              hcst_cor,
                                              wet_threshold=0.1,
                                              extreme_quantiles=[0.95, 0.99])
    print(i)
    mae = xr.concat([xs.mae(observation.sel(T=slice("1993","2016")), hcst, dim="T"),
              xs.mae(observation.sel(T=slice("1993","2016")), hcst_cor, dim="T")],
              dim="mae")
    mae = mae.assign_coords(mae=["model", "model corrigé"])
    mae.plot(col="mae")
    qmap.plot_fraction_group(dry_wet, "dry_fraction_", extent=extent_obs)
    qmap.plot_fraction_group(dry_wet, "wet_fraction_", extent=extent_obs)
    qmap.plot_mean_wet_group(dry_wet, extent=extent_obs)
    qmap.plot_extreme_quantiles_group(extrem, extent=extent_obs)
# Out:
# ecmwf51
# meteo_france8
# ukmo604
# dwd21
# dwd22
# cmcc35
# eccc4
# eccc5
# jma3
# ncep2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 12
#       6 dry_wet, extrem = qmap.evaluate_bias_correction(observation,
#       7                                           hcst,
#       8                                           hcst_cor,
#       9                                           wet_threshold=0.1,
#      10                                           extreme_quantiles=[0.95, 0.99])
#      11 print(i)
# ---> 12 mae = xr.concat([xs.mae(observation.sel(T=slice("1993","2016")), hcst, dim="T"),
#      13           xs.mae(observation.sel(T=slice("1993","2016")), hcst_cor, dim="T")],
#      14           dim="mae")
#      15 mae = mae.assign_coords(mae=["model", "model corrigé"])
#      16 mae.plot(col="mae")
#
# File ~/miniconda3/envs/WASS2S/lib/python3.12/site-packages/xskillscore/core/deterministic.py:1126, in mae(a, b, dim, weights, skipna, keep_attrs)
#    1123 weights = _preprocess_weights(a, dim, dim, weights)
#    1124 input_core_dims = _determine_input_core_dims(dim, weights)
# -> 1126 return xr.apply_ufunc(
#    1127     _mae,
#    1128     a,
#    1129     b,
#    1130     weights,
#    1131     input_core_dims=input_core_dims,
#    1132     kwargs={"axis": axis, "skipna": skipna},
#    1133     dask="parallelized",
#    1134     output_dtypes=[float],
#    1135     keep_attrs=keep_attrs,
#    1136 )
#
# File ~/miniconda3/envs/WASS2S/lib/python3.12/site-packages/xarray/computation/apply_ufunc.py:1268, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1266 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1267 elif any(isinstance(a, DataArray) for a in args):
# -> 1268     return apply_dataarray_vfunc(
#    1269         variables_vfunc,
#    1270         *args,
#    1271         signature=signature,
#    1272         join=join,
#    1273         exclude_dims=exclude_dims,
#    1274         keep_attrs=keep_attrs,
#    1275     )
#    1276 # feed Variables directly through apply_variable_ufunc
#    1277 elif any(isinstance(a, Variable) for a in args):
#
# File ~/miniconda3/envs/WASS2S/lib/python3.12/site-packages/xarray/computation/apply_ufunc.py:289, in apply_dataarray_vfunc(func, signature, join, exclude_dims, keep_attrs, *args)
#     285 from xarray.core.dataarray import DataArray
#     287 if len(args) > 1:
#     288     args = tuple(
# --> 289         deep_align(
#     290             args,
#     291             join=join,
#     292             copy=False,
#     293             exclude=exclude_dims,
#     294             raise_on_invalid=False,
#     295         )
#     296     )
#     298 objs = _all_of_type(args, DataArray)
#     300 if keep_attrs == "drop":
#
# File ~/miniconda3/envs/WASS2S/lib/python3.12/site-packages/xarray/structure/alignment.py:947, in deep_align(objects, join, copy, indexes, exclude, raise_on_invalid, fill_value)
#     944     else:
#     945         out.append(variables)
# --> 947 aligned = align(
#     948     *targets,
#     949     join=join,
#     950     copy=copy,
#     951     indexes=indexes,
#     952     exclude=exclude,
#     953     fill_value=fill_value,
#     954 )
#     956 for position, key, aligned_obj in zip(positions, keys, aligned, strict=True):
#     957     if key is no_key:
#
# File ~/miniconda3/envs/WASS2S/lib/python3.12/site-packages/xarray/structure/alignment.py:883, in align(join, copy, indexes, exclude, fill_value, *objects)
#     687 """
#     688 Given any number of Dataset and/or DataArray objects, returns new
#     689 objects with aligned indexes and dimension sizes.
#    (...)
#     873
#     874 """
#     875 aligner = Aligner(
#     876     objects,
#     877     join=join,
#    (...)
#     881     fill_value=fill_value,
#     882 )
# --> 883 aligner.align()
#     884 return aligner.results
#
# File ~/miniconda3/envs/WASS2S/lib/python3.12/site-packages/xarray/structure/alignment.py:575, in Aligner.align(self)
#     573 self.find_matching_unindexed_dims()
#     574 self.assert_no_index_conflict()
# --> 575 self.align_indexes()
#     576 self.assert_unindexed_dim_sizes_equal()
#     578 if self.join == "override":
#
# File ~/miniconda3/envs/WASS2S/lib/python3.12/site-packages/xarray/structure/alignment.py:422, in Aligner.align_indexes(self)
#     420 if need_reindex:
#     421     if self.join == "exact":
# --> 422         raise ValueError(
#     423             "cannot align objects with join='exact' where "
#     424             "index/labels/sizes are not equal along "
#     425             "these coordinates (dimensions): "
#     426             + ", ".join(f"{name!r} {dims!r}" for name, dims in key[0])
#     427         )
#     428     joiner = self._get_index_joiner(index_cls)
#     429     joined_index = joiner(matching_indexes)
#
# ValueError: cannot align objects with join='exact' where index/labels/sizes are not equal along these coordinates (dimensions): 'T' ('T',)

# %% [markdown]
# #### Compute Onset for models

# %%
hindcast_files, forecast_files = process_model_for_other_params(was_onset, dir_s2s, hindcast_files_cor, forecast_files_cor, rainfall, 
rainfall_for_forecast_year, month_of_initialization, year_start_model, year_end_model, forecast, nb_cores=4, agrometparam=agrometparam)
# Out:
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_ecmwf51_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_meteo_france8_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_ukmo604_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_dwd21_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_dwd22_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_cmcc35_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_eccc4_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_eccc5_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/hindcast_jma3_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_ecmwf51_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_meteo_france8_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_ukmo604_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_dwd21_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_dwd22_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_cmcc35_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_eccc4_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_eccc5_Onset_MarIc.nc already exists.
# [SKIP] Agro_PRESASS_2025/model_data/forecast_jma3_Onset_MarIc.nc already exists.

# %%
was_verify = WAS_Verification(dist_method=dist_method,mae_rmse_crps_thrsd=50)

# %% [markdown]
# #### Validation of GCM

# %%
score = ["Pearson", "MAE"]

# %%
os.makedirs(dir_save_score, exist_ok=True)
scores = {}
for i in score:
    scores[i] = was_verify.gcm_validation_compute(hindcast_files, onset, i, month_of_initialization, clim_year_start, clim_year_end, dir_save_score, lead_time = None, ensemble_mean=None, gridded=True)
    print(was_verify.scores[i][0])
    was_verify.plot_models_score(scores[i], i, dir_save_score)
# Out:
# Pearson Correlation
# Mean Absolute Error
# Generalized Discrimination Score

# %% [markdown]
# ## Choice of best GCM models

# %%
best_models = get_best_models(center_variable, scores, metric='MAE', threshold=10, top_n=5, agroparam=True, gcm=False)
best_models
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 best_models = get_best_models(center_variable, scores, metric='GROC', threshold=0.5, top_n=3, agroparam=True, gcm=False)
#       2 best_models
#
# NameError: name 'get_best_models' is not defined

# %% [markdown]
# ### MLP

# %%
# from scipy.stats import loguniform
model = WAS_mme_MLP(
    hidden_layer_sizes_range=[
        (2,2), (3,2), (2,4), (4,2),
        (5,2), (5,5), (5,5,5),
        (8,4), (16,8), (16,8,4),
        # (15,10,5,2),
        # (30,), (50,),              # Moderate baseline
        # (60, 30), (100, 50),       # Compression funnels
        # (30, 15, 5)                # Deep funnel for complex non-linearities
    ],
    learning_rate_init_range=loguniform(1e-4, 1e-1),
    activation_options=['tanh'],# 'identity'],        
    solver_options=['adam','sgd'],#, 'lbfgs'],  # sgd, lbfgs         
    alpha_range=loguniform(1e-5, 1e-1),   
    search_method='bayesian',                              
    random_state=42,
    n_iter_search=25,  
    max_iter=5000,
    cv_folds=5,
    n_clusters=2,
    dist_method=dist_method,
    optuna_n_jobs=-1,
    optuna_timeout=600
)

# %% [markdown]
# #### Cross-validation

# %%
# all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), gcm=True, ELM_ELR=True, dir_to_save_model=dir_to_save_model, best_models=best_models, scores=scores, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), hdcsted=hindcast_files, fcsted=forecast_files, scores= scores, score_metric='MAE', gcm=True, agroparam=False, ELM_ELR=False, best_models=best_models, dir_to_save_model=dir_to_save_model, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)

# %%
best_params, cluster = model.compute_hyperparameters(all_model_hdcst, obs, clim_year_start, clim_year_end)
# Out:
# [I 2026-02-09 23:44:33,364] A new study created in memory with name: no-name-62796a64-1331-4b77-9368-8355f77d8b58
# [I 2026-02-09 23:44:38,789] Trial 0 finished with value: -1.5925187447099551 and parameters: {'hidden_layer_sizes': (2, 4), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.03789770634065806, 'alpha': 0.05122630868712078}. Best is trial 0 with value: -1.5925187447099551.
# [I 2026-02-09 23:44:45,336] Trial 4 finished with value: -1.446978953500368 and parameters: {'hidden_layer_sizes': (5, 2), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.00644681434199343, 'alpha': 0.0065373953492849695}. Best is trial 4 with value: -1.446978953500368.
# [I 2026-02-09 23:44:57,215] Trial 6 finished with value: -1.5263032406590478 and parameters: {'hidden_layer_sizes': (10, 5), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.09751406691740033, 'alpha': 0.0014391961294740558}. Best is trial 4 with value: -1.446978953500368.
# [I 2026-02-09 23:45:03,871] Trial 3 finished with value: -1.2937774491678113 and parameters: {'hidden_layer_sizes': (2, 4), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.00022137026566380205, 'alpha': 0.0004545181724916395}. Best is trial 3 with value: -1.2937774491678113.
# [I 2026-02-09 23:45:10,044] Trial 5 finished with value: -1.5567171190066191 and parameters: {'hidden_layer_sizes': (8, 4), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.08115089608339206, 'alpha': 0.008978823681526388}. Best is trial 3 with value: -1.2937774491678113.
# [I 2026-02-09 23:45:13,640] Trial 2 finished with value: -1.4124400432271442 and parameters: {'hidden_layer_sizes': (4, 2), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.08622523546629783, 'alpha': 0.0017041622828999393}. Best is trial 3 with value: -1.2937774491678113.
# [I 2026-02-09 23:46:02,093] Trial 7 finished with value: -1.600650725907568 and parameters: {'hidden_layer_sizes': (8, 4, 2), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.00014152799546295443, 'alpha': 0.013837787837671183}. Best is trial 3 with value: -1.2937774491678113.
# [I 2026-02-09 23:46:04,424] Trial 8 finished with value: -1.4135136942971127 and parameters: {'hidden_layer_sizes': (4, 2), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.0020734778533605946, 'alpha': 0.00041558975660708645}. Best is trial 3 with value: -1.2937774491678113.
# [I 2026-02-09 23:46:06,083] Trial 1 finished with value: -1.5916773712997054 and parameters: {'hidden_layer_sizes': (5, 5), 'activation': 'tanh', 'solver': 'adam', 'learning_rate_init': 0.00011559217609248516, 'alpha': 0.017737451833565454}. Best is trial 3 with value: -1.2937774491678113.
# [I 2026-02-09 23:46:21,213] Trial 9 finished with value: -1.5426500071505849 and parameters: {'hidden_layer_sizes': (2, 4), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.009715586056420299, 'alpha': 0.042918785543844595}. Best is trial 3 with value: -1.2937774491678113.
# [I 2026-02-09 23
and parameters: {'hidden_layer_sizes': (3, 2), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.00011129920913114727, 'alpha': 0.06122642861885958}. Best is trial 19 with value: -1.1412002429133756.
# [I 2026-02-09 23:55:21,096] Trial 18 finished with value: -1.1608528586702669 and parameters: {'hidden_layer_sizes': (3, 2), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0001318031337398962, 'alpha': 0.09530535400410067}. Best is trial 19 with value: -1.1412002429133756.
# [I 2026-02-09 23:55:31,194] Trial 20 finished with value: -1.1401636070702725 and parameters: {'hidden_layer_sizes': (3, 2), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.00010297870614074111, 'alpha': 0.04687052171445417}. Best is trial 20 with value: -1.1401636070702725.
# [I 2026-02-09 23:55:49,293] Trial 21 finished with value: -1.1647678653711115 and parameters: {'hidden_layer_sizes': (3, 2), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.00014252802603861463, 'alpha': 0.04799796759282252}. Best is trial 20 with value: -1.1401636070702725.
# [I 2026-02-09 23:55:51,839] Trial 22 finished with value: -1.1400113149650366 and parameters: {'hidden_layer_sizes': (3, 2), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.0001022091278535458, 'alpha': 0.04187195703627464}. Best is trial 22 with value: -1.1400113149650366.
# [I 2026-02-09 23:56:00,501] Trial 23 finished with value: -1.141527218393149 and parameters: {'hidden_layer_sizes': (3, 2), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.00011377793098083743, 'alpha': 0.07372067388071167}. Best is trial 22 with value: -1.1400113149650366.
# [I 2026-02-09 23:56:04,814] Trial 24 finished with value: -1.1393070182371796 and parameters: {'hidden_layer_sizes': (3, 2), 'activation': 'tanh', 'solver': 'sgd', 'learning_rate_init': 0.00010142635857857799, 'alpha': 0.06750503593545387}. Best is trial 24 with value: -1.1393070182371796.

# %%
best_params #= {'activation': 'lin', 'neurons': 200, 'norm': 37.38460883888426}
# Out:
# {0.0: {'hidden_layer_sizes': (2, 2),
#   'learning_rate_init': 0.00043219897910421595,
#   'activation': 'tanh',
#   'solver': 'sgd',
#   'alpha': 4.70416723744954e-05},
#  1.0: {'hidden_layer_sizes': (3, 2),
#   'learning_rate_init': 0.00010142635857857799,
#   'activation': 'tanh',
#   'solver': 'sgd',
#   'alpha': 0.06750503593545387}}

# %%
cluster.plot()

# %%
was_mme_gcm = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start, 
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster,
                                                                  best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start,
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster
                                                                     )    
hdcst_consolidated['SV-ML-CMME_MLP'] = hindcast_det_gcm
hdcst_consolidated_prob['SV-ML-CMME_MLP'] = hindcast_prob_gcm
# Out:
# Cross-validation ongoing
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [05:10<00:00, 12.92s/it]

# %%
was_verify = WAS_Verification(dist_method=dist_method, mae_rmse_crps_thrsd=250)

# %% [markdown]
# #### Verification

# %%
score = ['Pearson', 'MAE']
model_name = "MLP" #"Extreme Learning Machine" # Extreme Learning Machine "MultiLayer Perceptron" XGBoost Random Forest

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det_gcm
    )
    scores_consolidated[i] = {'SV-ML-CMME_MLP': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ##### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob_gcm,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'SV-ML-CMME_MLP': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)
# Out:
# Generalized Discrimination Score
# Ranked Probability Skill Score

# %% [markdown]
# #### Forecast

# %%
if dist_method=="bestfit":
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, all_model_fcst, best_params=best_params, cluster_da=cluster, 
                                                        best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, 
                                                        all_model_fcst, best_params=best_params, cluster_da=cluster
                                                       )
    
fcst_consolidated['SV-ML-CMME_MLP'] = forecast_det_gcm
fcst_consolidated_prob['SV-ML-CMME_MLP'] = forecast_prob_gcm
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_gcm.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels, reverse_cmap=True)
gc.collect()
# Out:
# 99186

# %% [markdown]
# ### Extreme Learning

# %%
model = WAS_mme_hpELM(neurons_range=[5, 10, 25, 50, 100, 200, 400, 600, 800, 1000, 1500],    
                        activation_options=['sigm', 'tanh', 'lin'],# lin, 'rbf_l1', 'rbf_l2' 'rbf_linf'],
                        norm_range=loguniform(1e-2, 1e2),            
                        random_state=42,
                        n_iter_search=500,                             
                        cv_folds=5,
                        dist_method=dist_method,
                        search_method='bayesian',
                        n_clusters=3,
                        n_trials_bayesian=100,
                        bayesian_sampler='tpe', #random or tpe
                        )

# %% [markdown]
# #### Cross-validation

# %%
# all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), gcm=True, ELM_ELR=True, dir_to_save_model=dir_to_save_model, best_models=best_models, scores=scores, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), hdcsted=hindcast_files, fcsted=forecast_files, scores= scores, score_metric='MAE', gcm=True, agroparam=False, ELM_ELR=False, best_models=best_models, dir_to_save_model=dir_to_save_model, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)

# %%
best_params, cluster = model.compute_hyperparameters(all_model_hdcst, obs, clim_year_start, clim_year_end)
# Out:
# [I 2026-02-10 00:01:54,648] A new study created in memory with name: cluster_0.0
# [I 2026-02-10 00:01:57,219] Trial 3 finished with value: -1.1951998553731091 and parameters: {'neurons': 25, 'activation': 'tanh', 'norm': 0.026120417649837118}. Best is trial 3 with value: -1.1951998553731091.
# [I 2026-02-10 00:01:57,275] Trial 1 finished with value: -1.1920982331043923 and parameters: {'neurons': 25, 'activation': 'tanh', 'norm': 16.671063739209554}. Best is trial 1 with value: -1.1920982331043923.
# [I 2026-02-10 00:01:57,865] Trial 5 finished with value: -1.1951748777412536 and parameters: {'neurons': 25, 'activation': 'tanh', 'norm':
and parameters: {'neurons': 1500, 'activation': 'lin', 'norm': 4.166946337110273}. Best is trial 76 with value: -1.0394045863613397.
# [I 2026-02-10 00:08:10,132] Trial 78 finished with value: -1.037372077794793 and parameters: {'neurons': 10, 'activation': 'sigm', 'norm': 74.53335505101352}. Best is trial 78 with value: -1.037372077794793.
# processing batch 33/34, eta 0:00:00
# processing batch 17/34, eta 0:00:10
# [I 2026-02-10 00:08:10,914] Trial 79 finished with value: -1.039479697411711 and parameters: {'neurons': 10, 'activation': 'sigm', 'norm': 62.134781451869365}. Best is trial 78 with value: -1.037372077794793.
# processing batch 24/34, eta 0:00:04
# [I 2026-02-10 00:08:12,147] Trial 80 finished with value: -1.0386702512913433 and parameters: {'neurons': 10, 'activation': 'sigm', 'norm': 66.77155997916255}. Best is trial 78 with value: -1.037372077794793.
# processing batch 20/34, eta 0:00:07
# processing batch 11/34, eta 0:00:11
# processing batch 13/34, eta 0:00:08
# processing batch 28/34, eta 0:00:03
# processing batch 12/34, eta 0:00:09
# processing batch 30/34, eta 0:00:02
# processing batch 21/34, eta 0:00:06
# processing batch 14/34, eta 0:00:07
# processing batch 26/34, eta 0:00:03
# processing batch 8/34, eta 0:00:16
# processing batch 24/34, eta 0:00:04
# [I 2026-02-10 00:08:22,463] Trial 63 finished with value: -5.429515976099101 and parameters: {'neurons': 1500, 'activation': 'sigm', 'norm': 0.6073324995621893}. Best is trial 78 with value: -1.037372077794793.
# processing batch 32/34, eta 0:00:00
# processing batch 14/34, eta 0:00:07
# processing batch 29/34, eta 0:00:01
# processing batch 19/34, eta 0:00:08
# processing batch 11/34, eta 0:00:10
# processing batch 25/34, eta 0:00:01
# processing batch 30/34, eta 0:00:01
# processing batch 15/34, eta 0:00:06
# processing batch 31/34, eta 0:00:01
# processing batch 11/34, eta 0:00:10
# processing batch 14/34, eta 0:00:07
# processing batch 14/34, eta 0:00:07
# processing batch 21/34, eta 0:00:06
# processing batch 29/34, eta 0:00:01
# processing batch 22/34, eta 0:00:05
# processing batch 14/34, eta 0:00:07
# processing batch 23/34, eta 0:00:02
# processing batch 27/34, eta 0:00:02processing batch 28/34, eta 0:00:02
#
# processing batch 31/34, eta 0:00:01
# processing batch 10/34, eta 0:00:12
# processing batch 26/34, eta 0:00:03
# processing batch 33/34, eta 0:00:00
# processing batch 14/34, eta 0:00:07
# processing batch 22/34, eta 0:00:05
# processing batch 24/34, eta 0:00:02
# processing batch 15/34, eta 0:00:06
# processing batch 13/34, eta 0:00:08
# processing batch 10/34, eta 0:00:12
# processing batch 27/34, eta 0:00:02
# processing batch 11/34, eta 0:00:11
# processing batch 32/34, eta 0:00:00
# processing batch 13/34, eta 0:00:08
# processing batch 28/34, eta 0:00:02
# processing batch 28/34, eta 0:00:02
# processing batch 19/34, eta 0:00:08
# [I 2026-02-10 00:08:55,915] Trial 69 finished with value: -3.336810897308262 and parameters: {'neurons': 1500, 'activation': 'sigm', 'norm': 4.037951887171836}. Best is trial 78 with value: -1.037372077794793.
# processing batch 20/34, eta 0:00:03
# processing batch 21/34, eta 0:00:06
# processing batch 26/34, eta 0:00:03
# processing batch 30/34, eta 0:00:02
# processing batch 15/34, eta 0:00:06
# processing batch 14/34, eta 0:00:07
# processing batch 33/34, eta 0:00:00
# processing batch 14/34, eta 0:00:07
. Best is trial 41 with value: -0.9128105304986208.
# processing batch 13/23, eta 0:00:04
# processing batch 18/23, eta 0:00:01
# [I 2026-02-10 00:13:54,506] Trial 47 finished with value: -1.7274967854464855 and parameters: {'neurons': 200, 'activation': 'tanh', 'norm': 51.0131889669479}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 16/23, eta 0:00:02
# processing batch 15/23, eta 0:00:02
# processing batch 17/23, eta 0:00:01
# processing batch 15/23, eta 0:00:02
# processing batch 14/23, eta 0:00:03
# processing batch 17/23, eta 0:00:01
# processing batch 17/23, eta 0:00:01
# processing batch 12/23, eta 0:00:04
# processing batch 13/23, eta 0:00:03
# processing batch 15/23, eta 0:00:02
# processing batch 14/23, eta 0:00:03
# processing batch 15/23, eta 0:00:02
# processing batch 20/23, eta 0:00:00
# processing batch 18/23, eta 0:00:01
# processing batch 15/23, eta 0:00:02
# processing batch 13/23, eta 0:00:03
# processing batch 17/23, eta 0:00:01
# processing batch 18/23, eta 0:00:01
# processing batch 14/23, eta 0:00:03
# processing batch 13/23, eta 0:00:03
# processing batch 14/23, eta 0:00:03
# processing batch 16/23, eta 0:00:02
# processing batch 13/23, eta 0:00:03
# [I 2026-02-10 00:14:20,384] Trial 50 finished with value: -7.204957489240127 and parameters: {'neurons': 600, 'activation': 'tanh', 'norm': 0.02784612744426815}. Best is trial 41 with value: -0.9128105304986208.
# [I 2026-02-10 00:14:21,664] Trial 52 finished with value: -2.6113593653087337 and parameters: {'neurons': 600, 'activation': 'tanh', 'norm': 13.222361149452148}. Best is trial 41 with value: -0.9128105304986208.
# [I 2026-02-10 00:14:21,707] Trial 51 finished with value: -1.9805772580894554 and parameters: {'neurons': 600, 'activation': 'tanh', 'norm': 52.545893829833254}. Best is trial 41 with value: -0.9128105304986208.
# [I 2026-02-10 00:14:22,915] Trial 60 finished with value: -1.0199258046636515 and parameters: {'neurons': 5, 'activation': 'lin', 'norm': 13.281304845574756}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 11/23, eta 0:00:05
# processing batch 15/23, eta 0:00:02
# [I 2026-02-10 00:14:25,453] Trial 53 finished with value: -1.1293512719855592 and parameters: {'neurons': 1500, 'activation': 'lin', 'norm': 50.457697744845746}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 12/23, eta 0:00:04
# processing batch 14/23, eta 0:00:03
# processing batch 10/23, eta 0:00:06
# processing batch 9/23, eta 0:00:07
# processing batch 10/23, eta 0:00:06
# processing batch 22/23, eta 0:00:00
# processing batch 23/23, eta 0:00:00
# [I 2026-02-10 00:14:31,242] Trial 55 finished with value: -1.1293459755923771 and parameters: {'neurons': 600, 'activation': 'lin', 'norm': 57.263063759370795}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 17/23, eta 0:00:01
# [I 2026-02-10 00:14:32,241] Trial 63 finished with value: -0.9128898749679764 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 10.959012207919308}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 21/23, eta 0:00:00
# processing batch 21/23, eta 0:00:01
# processing batch 20/23, eta 0:00:01
# processing batch 13/23, eta 0:00:03
# processing batch 12/23, eta 0:00:04
# processing batch 12/23, eta 0:00:04
# processing batch 17/23, eta 0:00:01
# processing batch 18/23, eta 0:00:01
# [I 2026-02-10 00:14:40,211] Trial 57 finished with value: -1.129352237687316 and parameters: {'neurons': 600, 'activation': 'lin', 'norm': 11.172572320491417}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 11/23, eta 0:00:05
# processing batch 10/23, eta 0:00:06
# processing batch 10/23, eta 0:00:07
# processing batch 22/23, eta 0:00:00
# processing batch 23/23, eta 0:00:00
# [I 2026-02-10 00:14:45,406] Trial 54 finished with value: -1.1293516546214324 and parameters: {'neurons': 1500, 'activation': 'lin', 'norm': 42.684398820157796}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 18/23, eta 0:00:01
# processing batch 22/23, eta 0:00:00
# processing batch 17/23, eta 0:00:01
# processing batch 22/23, eta 0:00:00
# [I 2026-02-10 00:14:48,621] Trial 56 finished with value: -1.1293531710454663 and parameters: {'neurons': 1500, 'activation': 'lin', 'norm': 11.878751463280889}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 19/23, eta 0:00:01
# processing batch 14/23, eta 0:00:03
# processing batch 20/23, eta 0:00:00
# processing batch 13/23, eta 0:00:04
# processing batch 23/23, eta 0:00:00
# processing batch 19/23, eta 0:00:01
# processing batch 12/23, eta 0:00:04
# processing batch 20/23, eta 0:00:00
# processing batch 19/23, eta 0:00:01
# processing batch 19/23, eta 0:00:01
# processing batch 16/23, eta 0:00:02
# processing batch 20/23, eta 0:00:00
# processing batch 20/23, eta 0:00:00
# processing batch 21/23, eta 0:00:00
# processing batch 13/23, eta 0:00:03
# processing batch 18/23, eta 0:00:01
# processing batch 20/23, eta 0:00:00
# processing batch 12/23, eta 0:00:04
# [I 2026-02-10 00:15:05,852] Trial 62 finished with value: -1.9046067815535708 and parameters: {'neurons': 400, 'activation': 'tanh', 'norm': 11.071254143078818}. Best is trial 41 with value: -0.9128105304986208.
# [I 2026-02-10 00:15:07,612] Trial 68 finished with value: -0.9128569420415955 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 16.019216292727158}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 19/23, eta 0:00:01
# [I 2026-02-10 00:15:08,933] Trial 69 finished with value: -0.9129240491900259 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 5.726228130536037}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 20/23, eta 0:00:00
# processing batch 22/23, eta 0:00:00
# [I 2026-02-10 00:15:10,350] Trial 70 finished with value: -0.9128464226019573 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 17.639183497406083}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 14/23, eta 0:00:03
# [I 2026-02-10 00:15:10,817] Trial 64 finished with value: -2.2018998138940633 and parameters: {'neurons': 400, 'activation': 'tanh', 'norm': 5.051476241666831}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 23/23, eta 0:00:00
# processing batch 11/23, eta 0:00:05
# processing batch 21/23, eta 0:00:00
# [I 2026-02-10 00:15:15,921] Trial 58 finished with value: -1.1293530848204958 and parameters: {'neurons': 1500, 'activation': 'lin', 'norm': 13.630352532357806}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 11/23, eta 0:00:05
# processing batch 18/23, eta 0:00:01
# processing batch 12/23, eta 0:00:04
# processing batch 11/23, eta 0:00:05
# [I 2026-02-10 00:15:17,262] Trial 65 finished with value: -2.135378478045261 and parameters: {'neurons': 400, 'activation': 'tanh', 'norm': 5.91596394928265}. Best is trial 41 with value: -0.9128105304986208.
# processing batch 19/23, eta 0:00:01
# [I 2026-02-10 00:15:20,292] Trial 59 finished with value: -1.1293531166982436 and parameters: {'neurons': 1500, 'activation': 'lin', 'norm': 12.982777545821158}. Best is trial 41 with value: -0.9128105304986208.
# [I 2026-02-10 00:15:21,007] Trial 66 finished with value: -2.171727495026566 and parameters: {'neurons': 400, 'activation': 'tanh', 'norm': 5.422589478803936}. Best is trial 41 with value: -0.9128105304986208.
# [I 2026-02-10 00:15:21,603] Trial 75 finished with value: -0.9127666164670734 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm':
and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 73.57000962442935}. Best is trial 86 with value: -0.9124901684911562.
# processing batch 15/23, eta 0:00:02
# processing batch 15/23, eta 0:00:02
# [I 2026-02-10 00:16:07,009] Trial 74 finished with value: -2.66069408727617 and parameters: {'neurons': 1000, 'activation': 'tanh', 'norm': 31.311257770896525}. Best is trial 86 with value: -0.9124901684911562.
# [I 2026-02-10 00:16:07,287] Trial 87 finished with value: -0.9125007413131154 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 71.87946842821508}. Best is trial 86 with value: -0.9124901684911562.
# [I 2026-02-10 00:16:07,390] Trial 88 finished with value: -0.9124935766722624 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 73.02484873736523}. Best is trial 86 with value: -0.9124901684911562.
# [I 2026-02-10 00:16:07,699] Trial 89 finished with value: -0.9125098341091675 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 70.42711071533083}. Best is trial 86 with value: -0.9124901684911562.
# [I 2026-02-10 00:16:08,825] Trial 90 finished with value: -0.9125231387678584 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 68.30455986819138}. Best is trial 86 with value: -0.9124901684911562.
# [I 2026-02-10 00:16:08,831] Trial 92 finished with value: -0.9124923584952034 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 73.219681197551}. Best is trial 86 with value: -0.9124901684911562.
# [I 2026-02-10 00:16:08,838] Trial 91 finished with value: -0.9124741075300268 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 76.14175756579685}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:09,118] Trial 93 finished with value: -0.9124905720214901 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 73.50545187876436}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:09,790] Trial 76 finished with value: -2.6654668386774754 and parameters: {'neurons': 1000, 'activation': 'tanh', 'norm': 31.10170384719887}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:09,792] Trial 77 finished with value: -18.495641250768475 and parameters: {'neurons': 1000, 'activation': 'tanh', 'norm': 0.4451187057223643}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:09,892] Trial 95 finished with value: -0.9245332237489976 and parameters: {'neurons': 5, 'activation': 'sigm', 'norm': 74.59357023179038}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:10,514] Trial 99 finished with value: -0.9124805013096073 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 75.1174263413717}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:10,661] Trial 98 finished with value: -0.9124794050936975 and parameters: {'neurons': 5, 'activation': 'tanh', 'norm': 75.2929982336452}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:10,885] Trial 94 finished with value: -1.1375991173684525 and parameters: {'neurons': 50, 'activation': 'tanh', 'norm': 76.30324190375735}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:11,056] Trial 96 finished with value: -1.119441278443719 and parameters: {'neurons': 50, 'activation': 'sigm', 'norm': 78.76959296592976}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:11,134] Trial 97 finished with value: -1.1205440449835582 and parameters: {'neurons': 50, 'activation': 'sigm', 'norm': 75.90751938930444}. Best is trial 91 with value: -0.9124741075300268.
# processing batch 20/23, eta 0:00:00
# [I 2026-02-10 00:16:12,698] Trial 83 finished with value: -2.655682440858701 and parameters: {'neurons': 1000, 'activation': 'tanh', 'norm': 31.533907948063646}. Best is trial 91 with value: -0.9124741075300268.
# [I 2026-02-10 00:16:12,778] Trial 81 finished with value: -2.7033987113713147 and parameters: {'neurons': 1000, 'activation': 'tanh', 'norm': 29.51820027967454}. Best is trial 91 with value: -0.9124741075300268.

# %%
best_params #= {'activation': 'lin', 'neurons': 200, 'norm': 37.38460883888426}
# Out:
# {0.0: {'neurons': 10, 'activation': 'sigm', 'norm': 75.8012219875167},
#  1.0: {'neurons': 5, 'activation': 'tanh', 'norm': 98.87976099188879},
#  2.0: {'neurons': 5, 'activation': 'tanh', 'norm': 76.14175756579685}}

# %%
cluster.plot()

# %%
was_mme_gcm = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start, 
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster,
                                                                  best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start,
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster
                                                                     )    
hdcst_consolidated['SV-ML-CMME_ELM'] = hindcast_det_gcm
hdcst_consolidated_prob['SV-ML-CMME_ELM'] = hindcast_prob_gcm
# Out:
# Cross-validation ongoing
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24/24 [00:03<00:00,  7.48it/s]

# %% [markdown]
# #### Verification

# %%
score = ['Pearson', 'MAE']
model_name = "Extreme Learning Machine" #"Extreme Learning Machine" # Extreme Learning Machine "MultiLayer Perceptron" XGBoost Random Forest

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det_gcm
    )
    scores_consolidated[i] = {'SV-ML-CMME_ELM': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ##### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob_gcm,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'SV-ML-CMME_ELM': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)
# Out:
# Generalized Discrimination Score
# Ranked Probability Skill Score

# %% [markdown]
# #### Forecast

# %%
if dist_method=="bestfit":
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, all_model_fcst, best_params=best_params, cluster_da=cluster, 
                                                        best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, 
                                                        all_model_fcst, best_params=best_params, cluster_da=cluster
                                                       )
    
fcst_consolidated['SV-ML-CMME_ELM'] = forecast_det_gcm
fcst_consolidated_prob['SV-ML-CMME_ELM'] = forecast_prob_gcm
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_gcm.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels, reverse_cmap=True)
gc.collect()
# Out:
# 24931

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### XGBoost

# %%
model = WAS_mme_XGBoosting(
    search_method='bayesian',#'random',  # Use randomized search for efficiency
    n_estimators_range=[25, 50, 100, 200, 300, 500, 600, 700, 1000, 1500],# 3000, 5000],  # Optimized for climate data
    learning_rate_range=[0.01, 0.05, 0.1],  # Finer low values
    max_depth_range=[2, 3, 4, 5],  # Conservative depths
    min_child_weight_range=[1, 2, 5, 10],
    subsample_range=[0.6, 0.8, 1.0],
    colsample_bytree_range=[0.5, 0.7, 0.9, 1.0],
    gamma_range=[0, 0.001, 0.01, 0.1, 0.5, 1.0],  # ADDED: Regularization
    reg_alpha_range=[0, 0.1, 0.5, 1.0],  # ADDED: L1 regularization
    reg_lambda_range=[1, 3, 5, 10],  # ADDED: L2 regularization
    random_state=42,
    dist_method=dist_method,  # Use non-parametric for probabilities
    n_iter_search=1000,  # Increase iterations for better search
    cv_folds=5,
    n_clusters=3,  # Number of homogeneous zones
    optuna_n_jobs=-1,  # Use all cores if using bayesian optimization
    optuna_timeout=1200  # 20 minute timeout
)

# %% [markdown]
# #### Cross-validation

# %%
# all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), gcm=True, ELM_ELR=True, dir_to_save_model=dir_to_save_model, best_models=best_models, scores=scores, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))), hdcsted=hindcast_files, fcsted=forecast_files, scores= scores, score_metric='MAE', gcm=True, agroparam=False, ELM_ELR=False, best_models=best_models, dir_to_save_model=dir_to_save_model, year_start=year_start_model, year_end=year_end_model, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, year_forecast=forecast)

# %%
best_params, cluster = model.compute_hyperparameters(all_model_hdcst, obs, clim_year_start, clim_year_end)
# Out:
# [I 2026-02-10 00:16:57,953] A new study created in memory with name: no-name-ddcff1c9-e902-4e28-87d6-0efc6be4cde3

# %%
best_params #= {'activation': 'lin', 'neurons': 200, 'norm': 37.38460883888426}

# %%
cluster.plot()

# %%
was_mme_gcm = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start, 
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster,
                                                                  best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_det_gcm, hindcast_prob_gcm, = was_mme_gcm.cross_validate(model, obs, all_model_hdcst, clim_year_start,
                                                                  clim_year_end, best_params=best_params, cluster_da=cluster
                                                                     )    
hdcst_consolidated['SV-ML-CMME_XGBOOST'] = hindcast_det_gcm
hdcst_consolidated_prob['SV-ML-CMME_XGBOOST'] = hindcast_prob_gcm

# %% [markdown]
# #### Verification

# %%
score = ['Pearson', 'MAE']
model_name = "XGBoost" #"Extreme Learning Machine" # Extreme Learning Machine "MultiLayer Perceptron" XGBoost Random Forest

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det_gcm
    )
    scores_consolidated[i] = {'SV-ML-CMME_XGBOOST': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ##### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob_gcm,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'SV-ML-CMME_XGBOOST': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# #### Forecast

# %%
if dist_method=="bestfit":
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, all_model_fcst, best_params=best_params, cluster_da=cluster, 
                                                        best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    forecast_det_gcm, forecast_prob_gcm= model.forecast(obs, clim_year_start, clim_year_end, all_model_hdcst, hindcast_det_gcm, 
                                                        all_model_fcst, best_params=best_params, cluster_da=cluster
                                                       )
    
fcst_consolidated['SV-ML-CMME_XGBOOST'] = forecast_det_gcm
fcst_consolidated_prob['SV-ML-CMME_XGBOOST'] = forecast_prob_gcm
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_gcm.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels, reverse_cmap=True)
gc.collect()

# %% [markdown]
# # 2nd - Approach: CCA-Based Calibration VWIND

# %%
# Filter model names to identify precipitation-related models
center_variable = [key for key in downloader.ModelsName().keys() if "VGRD_850" in key]
center_variable.remove('UKMO_603.VGRD_850')

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/model_data"

# Define the month for model initialization (June)
month_of_initialization = "12"

# Define lead times corresponding to seasonal forecast targets (JAS season in this case)
lead_time = ["01", "02", "03"]  # July-August-September forecast period

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent = [50, -60, 50, 30]  # [Northern, Western, Southern and Eastern] 


# Define if you want to download forecast or hindcast
forecast = None

# Define if you want all members of ensemble or doing an ensemble mean
ensemble_mean = "mean"

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
hindcast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
forecast = 2026

# %%
forecast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
hindcast_files = {k: hindcast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
forecast_files = {k: forecast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
common_keys = {k.lower() for k in hindcast_files} & {k.lower() for k in forecast_files}
center_variable = [
    item
    for item in center_variable
    if any(item.lower().startswith(k) for k in list(common_keys))
                ]

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initialize the WAS_CCA class (default)

# %%
n_modes = 3
# define zone as dict : {'zone_name_key': ('Explicit_Zone_name', lon_min, lon_max, lat_min, lat_max)} 
defined_zone = {'A': ('A', -60, 30, -50, 50)}

# %%
plot_map([extent[1],extent[3],extent[2],extent[0]], sst_indices = defined_zone, title="Predictors Area",fig_size=(6,4))

# %% [markdown]
# ##### Modes of CCA for each model

# %%
was_cca = WAS_CCA(n_modes=n_modes, n_pca_modes=8, dist_method=dist_method)
was_cv = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
predictors = {}
for i in center_variable:
    predictors[i] = retrieve_single_zone_for_PCR(dir_to_save_model, defined_zone, i, year_start_model, year_end_model, clim_year_start=clim_year_start, clim_year_end=clim_year_end, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, standardize=True)
    predictor = predictors[i].isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(f"CCA Modes for model {i}")
    was_cca.plot_cca_results(X=predictor, Y=onset.sel(T=slice(str(year_start_model),str(year_end_model))) , clim_year_start=clim_year_start, clim_year_end=clim_year_end)

# %% [markdown]
# #### Cross validation

# %%
hindcast_det_dynam_all = {}
hindcast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                          predictor, clim_year_start, clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))).sel(T=slice(str(year_start_model),str(year_end_model))), predictor, clim_year_start, clim_year_end)

# %% [markdown]
# #### Verification (individual)

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "CCA-based"

# %%
cca_scores = {}
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_deterministic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_det_dynam_all[key]
        )
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_probabilistic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_prob_dynam_all[key],
            clim_year_start,
            clim_year_end)
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# #### Forecast (individual)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
forecast_det_dynam_all = {}
forecast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor_f = predictor.isel(T=[-1])
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f)
    model_name = f"CCA_{key.split('.')[0]}"    
    plot_prob_forecasts(f"{dir_to_forecast}",
                        forecast_prob_dynam_all[key].drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}", 
                        hspace=0.1, labels=fcst_labels, reverse_cmap=True)

# %% [markdown]
# ### Select best Statistico-Dynamical models

# %%
#### Select some models
best_models = get_best_models(center_variable, cca_scores, metric='GROC', threshold=0.6, top_n=4, gcm=False)
best_models

# %%
for key in best_models:
    hdcst_consolidated[f'{key}_snd.approach'] = hindcast_det_dynam_all[key]
    fcst_consolidated[f'{key}_snd.approach'] = forecast_det_dynam_all[key]
    hdcst_consolidated_prob[f'{key}_snd.approach'] = hindcast_prob_dynam_all[key]
    fcst_consolidated_prob[f'{key}_snd.approach'] = forecast_prob_dynam_all[key]
    
for metric, models in cca_scores.items():
    for model in list(models):                    # list() pour éviter RuntimeError
        if not any(model.startswith(p) for p in best_models):
            del models[model]

for key in cca_scores:
    scores_consolidated.setdefault(key, {}).update(cca_scores[key])

# %% [markdown]
# # 2nd - Approach: CCA-Based Calibration SST

# %%
# Filter model names to identify precipitation-related models
center_variable = [key for key in downloader.ModelsName().keys() if "SST" in key]
# center_variable.remove('NASA_1.SST')
center_variable.remove('UKMO_603.SST')
# center_variable.remove('DWD_21.SST')
# center_variable.remove('CMC2_1.SST')
# center_variable.remove('METEOFRANCE_8.SST')

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/model_data"

# Define the month for model initialization (June)
month_of_initialization = "12"

# Define lead times corresponding to seasonal forecast targets (JAS season in this case)
lead_time = ["01", "02", "03"]  # July-August-September forecast period

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent = [60, -180, -60, 180]  # [Northern, Western, Southern and Eastern] 

# Define if you want to download forecast or hindcast
forecast = None

# Define if you want all members of ensemble or doing an ensemble mean
ensemble_mean = "mean"

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
hindcast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
forecast = 2026

# %%
forecast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
hindcast_files = {k: hindcast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
forecast_files = {k: forecast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
common_keys = {k.lower() for k in hindcast_files} & {k.lower() for k in forecast_files}
center_variable = [
    item
    for item in center_variable
    if any(item.lower().startswith(k) for k in list(common_keys))
                ]

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initialize the WAS_CCA class (default)

# %%
n_modes = 3
# define zone as dict : {'zone_name_key': ('Explicit_Zone_name', lon_min, lon_max, lat_min, lat_max)} 
defined_zone = {'A': ('A', -150, 150, -35, 35)}

# %%
plot_map([extent[1],extent[3],extent[2],extent[0]], sst_indices = defined_zone, title="Predictors Area",fig_size=(6,4))

# %% [markdown]
# ##### Modes of CCA for each model

# %%
was_cca = WAS_CCA(n_modes=n_modes, n_pca_modes=8, dist_method=dist_method)
was_cv = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
predictors = {}
for i in center_variable:
    predictors[i] = retrieve_single_zone_for_PCR(dir_to_save_model, defined_zone, i, year_start_model, year_end_model, clim_year_start=clim_year_start, clim_year_end=clim_year_end, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, standardize=True)
    predictor = predictors[i].isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(f"CCA Modes for model {i}")
    was_cca.plot_cca_results(X=predictor, Y=onset.sel(T=slice(str(year_start_model),str(year_end_model))) , clim_year_start=clim_year_start, clim_year_end=clim_year_end)

# %% [markdown]
# #### Cross validation

# %%
hindcast_det_dynam_all = {}
hindcast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                          predictor, clim_year_start, clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))).sel(T=slice(str(year_start_model),str(year_end_model))), predictor, clim_year_start, clim_year_end)

# %% [markdown]
# #### Verification (individual)

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "CCA-based"

# %%
cca_scores = {}
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_deterministic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_det_dynam_all[key]
        )
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_probabilistic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_prob_dynam_all[key],
            clim_year_start,
            clim_year_end)
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# #### Forecast (individual)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
forecast_det_dynam_all = {}
forecast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor_f = predictor.isel(T=[-1])
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f)
    model_name = f"CCA_{key.split('.')[0]}"    
    plot_prob_forecasts(f"{dir_to_forecast}",
                        forecast_prob_dynam_all[key].drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}", 
                        hspace=0.1, labels=fcst_labels, reverse_cmap=True)

# %% [markdown]
# ### Select best Statistico-Dynamical models

# %%
#### Select some models
best_models = get_best_models(center_variable, cca_scores, metric='GROC', threshold=0.6, top_n=4, gcm=False)
best_models

# %%
for key in best_models:
    hdcst_consolidated[f'{key}_snd.approach'] = hindcast_det_dynam_all[key]
    fcst_consolidated[f'{key}_snd.approach'] = forecast_det_dynam_all[key]
    hdcst_consolidated_prob[f'{key}_snd.approach'] = hindcast_prob_dynam_all[key]
    fcst_consolidated_prob[f'{key}_snd.approach'] = forecast_prob_dynam_all[key]
    
for metric, models in cca_scores.items():
    for model in list(models):                    # list() pour éviter RuntimeError
        if not any(model.startswith(p) for p in best_models):
            del models[model]

for key in cca_scores:
    scores_consolidated.setdefault(key, {}).update(cca_scores[key])

# %% [markdown]
# # 2nd - Approach: CCA-Based Calibration PRCP

# %%
# Filter model names to identify precipitation-related models
center_variable = [key for key in downloader.ModelsName().keys() if "PRCP" in key]
# center_variable.remove('NASA_1.SST')
center_variable.remove('UKMO_603.PRCP')
# center_variable.remove('DWD_21.SST')
# center_variable.remove('CMC2_1.SST')
# center_variable.remove('METEOFRANCE_8.SST')

# Specify the directory to save downloaded model data
dir_to_save_model = f"{dir_s2s}/model_data"

# Define the month for model initialization (June)
month_of_initialization = "12"

# Define lead times corresponding to seasonal forecast targets (JAS season in this case)
lead_time = ["01", "02", "03"]  # July-August-September forecast period

# Define the hindcast period for model data (years 1993 to 2016)
year_start_model = 1993
year_end_model = 2016

# Set the bounding box for the area of interest (latitude and longitude bounds)
extent = [-30, 30, -20, 30]  # [Northern, Western, Southern and Eastern] 

# Define if you want to download forecast or hindcast
forecast = None

# Define if you want all members of ensemble or doing an ensemble mean
ensemble_mean = "mean"

# Specify whether to overwrite existing files when downloading data
force_download = False

# %%
hindcast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
forecast = 2026

# %%
forecast_files = downloader.WAS_Download_Models(
    dir_to_save_model,
    center_variable,
    month_of_initialization,
    lead_time,
    year_start_model,
    year_end_model,
    extent, 
    forecast,
    ensemble_mean,
    force_download)

# %%
hindcast_files = {k: hindcast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
forecast_files = {k: forecast_files[k] for k in hindcast_files.keys() & forecast_files.keys()}
common_keys = {k.lower() for k in hindcast_files} & {k.lower() for k in forecast_files}
center_variable = [
    item
    for item in center_variable
    if any(item.lower().startswith(k) for k in list(common_keys))
                ]

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Initialize the WAS_CCA class (default)

# %%
n_modes = 3
# define zone as dict : {'zone_name_key': ('Explicit_Zone_name', lon_min, lon_max, lat_min, lat_max)} 
defined_zone = {'A': ('A', -20, 30, -30, 30)}

# %%
plot_map([extent[1],extent[3],extent[2],extent[0]], sst_indices = defined_zone, title="Predictors Area",fig_size=(6,4))

# %% [markdown]
# ##### Modes of CCA for each model

# %%
was_cca = WAS_CCA(n_modes=n_modes, n_pca_modes=8, dist_method=dist_method)
was_cv = WAS_Cross_Validator(n_splits=len(onset.sel(T=slice(str(year_start_model),str(year_end_model))).get_index("T")), nb_omit=2)

# %%
predictors = {}
for i in center_variable:
    predictors[i] = retrieve_single_zone_for_PCR(dir_to_save_model, defined_zone, i, year_start_model, year_end_model, clim_year_start=clim_year_start, clim_year_end=clim_year_end, model=True, month_of_initialization=month_of_initialization, lead_time=lead_time, standardize=True)
    predictor = predictors[i].isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(f"CCA Modes for model {i}")
    was_cca.plot_cca_results(X=predictor, Y=onset.sel(T=slice(str(year_start_model),str(year_end_model))) , clim_year_start=clim_year_start, clim_year_end=clim_year_end)

# %% [markdown]
# #### Cross validation

# %%
hindcast_det_dynam_all = {}
hindcast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))), 
                                                                                          predictor, clim_year_start, clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        hindcast_det_dynam_all[key], hindcast_prob_dynam_all[key] = was_cv.cross_validate(was_cca, onset.sel(T=slice(str(year_start_model),str(year_end_model))).sel(T=slice(str(year_start_model),str(year_end_model))), predictor, clim_year_start, clim_year_end)

# %% [markdown]
# #### Verification (individual)

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "CCA-based"

# %%
cca_scores = {}
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_deterministic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_det_dynam_all[key]
        )
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    tmp = {}
    print(was_verify.scores[i][0])
    for key, hdcst in hindcast_det_dynam_all.items():
        tmp[f'{key}_snd.approach'] = was_verify.compute_probabilistic_score(
            was_verify.get_scores_metadata()[i][5],
            onset.sel(T=slice(str(year_start_model),str(year_end_model))),
            hindcast_prob_dynam_all[key],
            clim_year_start,
            clim_year_end)
        was_verify.plot_model_score(tmp[f'{key}_snd.approach'], i, dir_save_score, f"{key}_{model_name}")
    cca_scores[i] = tmp

# %% [markdown]
# #### Forecast (individual)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
forecast_det_dynam_all = {}
forecast_prob_dynam_all = {}
for key, predictor in predictors.items():
    predictor_f = predictor.isel(T=[-1])
    predictor = predictor.isel(T = slice(None,-1))
    predictor['T'] = onset.sel(T=slice(str(year_start_model),str(year_end_model)))['T']
    print(key.split('.')[0])
    if dist_method=="bestfit":
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
    else:
        forecast_det_dynam_all[key], forecast_prob_dynam_all[key] = was_cca.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, predictor, hindcast_det_dynam_all[key], predictor_f)
    model_name = f"CCA_{key.split('.')[0]}"    
    plot_prob_forecasts(f"{dir_to_forecast}",
                        forecast_prob_dynam_all[key].drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}", 
                        hspace=0.1, labels=fcst_labels, reverse_cmap=True)

# %% [markdown]
# ### Select best Statistico-Dynamical models

# %%
#### Select some models
best_models = get_best_models(center_variable, cca_scores, metric='GROC', threshold=0.6, top_n=4, gcm=False)
best_models

# %%
for key in best_models:
    hdcst_consolidated[f'{key}_snd.approach'] = hindcast_det_dynam_all[key]
    fcst_consolidated[f'{key}_snd.approach'] = forecast_det_dynam_all[key]
    hdcst_consolidated_prob[f'{key}_snd.approach'] = hindcast_prob_dynam_all[key]
    fcst_consolidated_prob[f'{key}_snd.approach'] = forecast_prob_dynam_all[key]
    
for metric, models in cca_scores.items():
    for model in list(models):                    # list() pour éviter RuntimeError
        if not any(model.startswith(p) for p in best_models):
            del models[model]

for key in cca_scores:
    scores_consolidated.setdefault(key, {}).update(cca_scores[key])

# %% [markdown]
# # 4th - Analog-based seasonal forecast

# %% [markdown]
# ## Analog bias_based

# %%
# %load_ext autoreload
# %autoreload 2

# %%
model = WAS_Analog(
    dir_to_save=f"{dir_s2s}/analog",
    year_start=1990,
    year_forecast=2026,          # target forecast year
    month_of_initialization=1,   # May initialisation
    predictor_vars=[{'reanalysis_name': 'NOAA', 'model_name': 'ECMWF_51', 'variable': 'SST', 'area': [40, -180, -35, 100]},
                    # {'reanalysis_name': 'ERA5', 'model_name': 'NCEP_2', 'variable': 'SLP', 'area': [80, -60, -80, 60]},
                    # {'reanalysis_name': 'ERA5', 'model_name': 'NCEP_2', 'variable': 'VGRD_850', 'area': [30, -45, -20, 15]}
                   ],
    method_analog="bias_based",
    standardize=True,
    rolling=3,
    lead_time=[1,2,3],
    clim_year_start=clim_year_start, 
    clim_year_end=clim_year_end,
    dist_method=dist_method
)

# %% [markdown]
# #### Cross-validation

# %%
was_analog_cv = WAS_Cross_Validator(n_splits=len(onset.get_index("T")), nb_omit=2)

# %%
if dist_method=="bestfit":
    hindcast_analog_det, hindcast_analog_prob = was_analog_cv.cross_validate(model, onset, clim_year_start=clim_year_start, clim_year_end=clim_year_end, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    hindcast_analog_det, hindcast_analog_prob = was_analog_cv.cross_validate(model, onset, clim_year_start=clim_year_start, clim_year_end=clim_year_end)    
hdcst_consolidated['fourth.approach'] = hindcast_analog_det.sel(T=slice(str(year_start_model),str(year_end_model)))
hdcst_consolidated_prob['fourth.approach'] = hindcast_analog_prob.sel(T=slice(str(year_start_model),str(year_end_model)))

# %% [markdown]
# #### Verification

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "Analogue-Based Forecasting"

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset,
        hindcast_analog_det
    )
    scores_consolidated[i] = {'fourth.approach': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset,
        hindcast_analog_prob,
        clim_year_start,
        clim_year_end)
    scores_consolidated[i] = {'fourth.approach': r}
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# #### Forecast

# %%
## Analysis SST evolution
model.composite_plot(onset, clim_year_start, clim_year_end, 
                     hindcast_analog_det, plot_predictor=True,
                    variable="SST", best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)

# %%
## Plot silimar years behavior
model.composite_plot(onset, clim_year_start, clim_year_end, hindcast_analog_det, plot_predictor=False, best_code_da=best_code_da,
                     best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)

# %%
if dist_method=="bestfit":
    similar_years, forecast_det_analog, forecast_prob_analog = model.forecast(onset, clim_year_start, clim_year_end, hindcast_analog_det, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
else:
    similar_years, forecast_det_analog, forecast_prob_analog = model.forecast(onset, clim_year_start, clim_year_end, hindcast_analog_det)    
fcst_consolidated['fourth.approach'] = forecast_det_analog
fcst_consolidated_prob['fourth.approach'] = forecast_prob_analog
plot_prob_forecasts(f"{dir_to_forecast}", forecast_prob_analog.drop_vars('T').squeeze(), f"{model_name} {season_str}-{forecast} Initial conditions of {calendar.month_name[int(month_of_initialization)]}",
                    hspace=0.1, labels=fcst_labels,
                    reverse_cmap=True)

# %% [markdown]
# # Consolidated Forecasts

# %%
best_models = list(hdcst_consolidated.keys())
best_models

# %% [markdown]
# #### Cross-validation

# %%
all_model_hdcst, all_model_fcst, obs, best_score = process_datasets_for_mme(onset.sel(T=slice(str(year_start_model),str(year_end_model))),hdcsted=hdcst_consolidated, fcsted=fcst_consolidated, gcm=False, ELM_ELR=False,  Prob=False, best_models=best_models, scores=scores_consolidated, model=False, score_metric="GROC")

# %%
was_mme = WAS_mme_Weighted(equal_weighted=True, dist_method=dist_method, metric="GROC", threshold=0.6)

# %%
hindcast_det, forecast_det  = was_mme.compute(obs, all_model_hdcst, all_model_fcst, best_score, complete=True)
hindcast_prob = was_mme.compute_prob(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, hindcast_det, best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)

# %% [markdown]
# #### Verification

# %% [markdown]
# ###### Deterministic

# %%
score = ['Pearson','MAE']
model_name = "Consolidated Forecast"

# %%
for i in score:
    r = was_verify.compute_deterministic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_det
    )
    
    r.to_dataset(name="Equaly weigthed")
    r.to_netcdf(f"{dir_s2s}/equaly_{i}.nc")
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ###### Probabilistic

# %%
score = ['GROC', 'RPSS']

# %%
score = score.append('GROC') if 'GROC' not in score else score
for i in score:
    print(was_verify.scores[i][0])
    r = was_verify.compute_probabilistic_score(
        was_verify.get_scores_metadata()[i][5],
        onset.sel(T=slice(str(year_start_model),str(year_end_model))),
        hindcast_prob,
        clim_year_start,
        clim_year_end)
    r.to_dataset(name="Equaly weigthed")
    r.to_netcdf(f"{dir_s2s}/equaly_{i}.nc")
    was_verify.plot_model_score(r, i, dir_save_score, model_name)

# %% [markdown]
# ### Forecast

# %%
_,forecast_prob = was_mme.forecast(onset.sel(T=slice(str(year_start_model),str(year_end_model))), clim_year_start, clim_year_end, hindcast_det, forecast_det,best_code_da=best_code_da, best_shape_da=best_shape_da, best_loc_da=best_loc_da, best_scale_da=best_scale_da)
plot_prob_forecasts(dir_to_forecast, forecast_prob.drop_vars('T').squeeze(),
                    f"{model_name} {season_str}-{forecast}" ,#issued {datetime.datetime.today().strftime("%Y-%m-%d")}", 
                    reverse_cmap=True,  hspace=0.1, labels=fcst_labels, logo=logopath, logo_size=0.1)
gc.collect()

# %%
plot_det_forecasts(forecast_det.drop_vars('T').squeeze(),
                    f"{model_name} Deterministic {season_str}-{forecast}", f"{dir_to_forecast}/{model_name} {season_str}-{forecast}.png")
gc.collect()

# %%
forecast_det.to_netcdf(f'{dir_to_forecast}/Forecast_Det_PRCP{season_str}_{forecast}.nc')

# %%
forecast_prob.to_netcdf(f'{dir_to_forecast}/Forecast_Prob_PRCP{season_str}_{forecast}.nc')
